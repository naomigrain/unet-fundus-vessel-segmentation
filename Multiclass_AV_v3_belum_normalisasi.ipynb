# %% [markdown]
# **VESSEL SEGMENTATION**

# %%
# !pip install patchify

import os
import glob
import cv2
import numpy as np
import skimage.io
from matplotlib import pyplot as plt
from patchify import patchify, unpatchify
from PIL import Image
import tensorflow as tf
import random

np.random.seed(0)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.9/dist-packages (from patchify) (1.22.4)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3

# %%
PATH = '/content/drive/MyDrive/AV_split/'
TRAIN_PATH = PATH+'train_vessel/'
TRAIN_IMAGE_PATH = TRAIN_PATH + 'images/'
TRAIN_VESSEL_MASK_PATH = TRAIN_PATH + 'GT_vessel/'

TEST_PATH = PATH+'test/'
TEST_IMAGE_PATH = TEST_PATH + 'images/'
TEST_VESSEL_MASK_PATH = TEST_PATH + 'GT_vessel/'

PATCH_SIZE = 512

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def clahe_equalized(image):    
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))    
    image_equalized = clahe.apply(image)

    return image_equalized

def preprocess_image(image, patch_size):
    image = image[70:970, 200:1255]

    image = image[:,:,1]
    image = clahe_equalized(image)

    SIZE_X = (image.shape[1]//patch_size)*patch_size 
    SIZE_Y = (image.shape[0]//patch_size)*patch_size     
    image = cv2.resize(image, (SIZE_X, SIZE_Y))
    
    image = image / 255.
    image = np.array(image)

    return image

# %%
def preprocess_vessel_mask(mask, patch_size):
    thresh = 128
    mask = cv2.threshold(mask, thresh, 255, cv2.THRESH_BINARY)[1]

    mask = mask[70:970, 200:1255]
    
    SIZE_X = (mask.shape[1]//patch_size)*patch_size 
    SIZE_Y = (mask.shape[0]//patch_size)*patch_size     
    mask = cv2.resize(mask, (SIZE_X, SIZE_Y))
  
    mask = 255 - mask
    mask = mask / 255.

    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0

    return mask

# %%
def image_to_patch(image_path, image_type, image_preprocessing, patch_size):
    image_dataset = unpatched_image = []

    if image_type == "IMAGE":
        image = cv2.imread(image_path)
    if image_type == "VESSEL_MASK":
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    image = image_preprocessing(image, patch_size)
    patches_image = patchify(image, (patch_size, patch_size), step=patch_size)
    unpatched_image = unpatchify(patches_image, image.shape)
    
    for i in range(patches_image.shape[0]):
        for j in range(patches_image.shape[1]):
            single_patch = patches_image[i,j,:,:]
            single_patch = (single_patch).astype('float32')
            image_dataset.append(single_patch)

    return image_dataset, unpatched_image

# %%
train_image_list = glob.glob(TRAIN_IMAGE_PATH + '/*.JPG')
train_image_list.sort()

train_vessel_mask_list = glob.glob(TRAIN_VESSEL_MASK_PATH + '/*.jpg')
train_vessel_mask_list.sort()

# %%
image_path = train_image_list[10]

original_image = cv2.imread(image_path)
patched_image_list, unpatched_image = image_to_patch(image_path, "IMAGE", preprocess_image, PATCH_SIZE)
patched_image = np.array(patched_image_list)

print(patched_image.min(), patched_image.max())
print(patched_image.shape)

plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.title(image_path)
plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))
plt.subplot(122)
plt.imshow(unpatched_image, cmap='gray')

plt.show()

rows = 1
columns = patched_image.shape[0]

fig = plt.figure(figsize=(5, 5))
for i in range(1, (rows * columns + 1)):
    fig.add_subplot(rows, columns, i)
    img = patched_image[i-1]
    plt.imshow(img,cmap='gray')

plt.show()
# Out:
# 0.007843138 0.9843137
# (2, 512, 512)

# %%
vessel_mask_path = train_vessel_mask_list[10]
original_vessel_mask = cv2.imread(vessel_mask_path, cv2.IMREAD_GRAYSCALE)

patched_mask_list, unpatcified_mask = image_to_patch(vessel_mask_path, "VESSEL_MASK", preprocess_vessel_mask, PATCH_SIZE)
patched_mask = np.array(patched_mask_list)

plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.title(vessel_mask_path)
plt.imshow(cv2.cvtColor(original_vessel_mask, cv2.COLOR_BGR2RGB))
plt.subplot(122)
plt.imshow(unpatcified_mask, cmap='gray')

plt.show()

print(patched_mask.min(), patched_mask.max())
print(patched_mask.shape)
print(np.unique(patched_mask))

rows = 1
columns = patched_image.shape[0]

fig = plt.figure(figsize=(5, 5))
for i in range(1, (rows * columns + 1)):
    fig.add_subplot(rows, columns, i)
    img = patched_mask[i-1]
    plt.imshow(img,cmap='gray')

plt.show()
# Out:
# 0.0 1.0
# (2, 512, 512)
# [0. 1.]

# %%
train_image_dataset = []
train_vessel_mask_dataset = []

for image_path in train_image_list:
    patched_image, unpatched_image = image_to_patch(image_path, "IMAGE", preprocess_image, PATCH_SIZE)
    train_image_dataset += patched_image

for vessel_mask_path in train_vessel_mask_list:
    patched_mask, unpatched_mask = image_to_patch(vessel_mask_path, "VESSEL_MASK", preprocess_vessel_mask, PATCH_SIZE)
    train_vessel_mask_dataset += patched_mask

train_image_dataset = np.array(train_image_dataset)
train_image_dataset = np.expand_dims(train_image_dataset, axis=-1)
train_vessel_mask_dataset = np.array(train_vessel_mask_dataset)
train_vessel_mask_dataset = np.expand_dims(train_vessel_mask_dataset, axis=-1)

print(train_image_dataset.shape)
print(train_vessel_mask_dataset.shape)
print(train_image_dataset.max(), train_vessel_mask_dataset.max())
print(train_image_dataset.min(), train_vessel_mask_dataset.min())
# Out:
# (72, 512, 512, 1)
# (72, 512, 512, 1)
# 1.0 1.0
# 0.003921569 0.0

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train_image_dataset, train_vessel_mask_dataset, test_size=0.3, random_state=0)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (50, 512, 512, 1) (50, 512, 512, 1)
# (22, 512, 512, 1) (22, 512, 512, 1)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K

def IoU_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

def IoU_loss(y_true, y_pred):
    return -IoU_coef(y_true, y_pred)

# %%
import tensorflow as tf
from keras.models import Model, load_model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.optimizers import Adam
from keras.layers import Activation, MaxPool2D, Concatenate

def unet(pretrained_weights = None,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    drop4 = Dropout(0.5)(conv4, training=True)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    conv5 = BatchNormalization()(conv5)
    drop5 = Dropout(0.5)(conv5, training=True)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)

    model = tf.keras.Model(inputs = inputs, outputs = conv10)

    model.compile(optimizer = Adam(lr = 1e-4), loss = IoU_loss, metrics = ['accuracy', IoU_coef])
    

    if(pretrained_weights):
    	  model=keras.models.load_model(pretrained_weights)

    return model

# %%
model = unet(input_size=(PATCH_SIZE, PATCH_SIZE, 1))
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
history = model.fit(x_train, y_train, 
                    verbose = 1,
                    batch_size = 3,
                    validation_data = (x_test, y_test), 
                    shuffle = False,
                    epochs = 150,
                    steps_per_epoch = 10)
# Out:
# Epoch 1/150
# 10/10 [==============================] - 50s 2s/step - loss: -0.2099 - accuracy: 0.6110 - IoU_coef: 0.2099 - val_loss: -0.0642 - val_accuracy: 0.8682 - val_IoU_coef: 0.0654
# Epoch 2/150
# 10/10 [==============================] - 27s 3s/step - loss: -0.3813 - accuracy: 0.8776 - IoU_coef: 0.3804 - val_loss: -0.0784 - val_accuracy: 0.8884 - val_IoU_coef: 0.0802
# Epoch 3/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4627 - accuracy: 0.9102 - IoU_coef: 0.4627 - val_loss: -0.0162 - val_accuracy: 0.8907 - val_IoU_coef: 0.0165
# Epoch 4/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4747 - accuracy: 0.9171 - IoU_coef: 0.4729 - val_loss: -0.0036 - val_accuracy: 0.8907 - val_IoU_coef: 0.0036
# Epoch 5/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4977 - accuracy: 0.9203 - IoU_coef: 0.4977 - val_loss: -0.0018 - val_accuracy: 0.8925 - val_IoU_coef: 0.0019
# Epoch 6/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5130 - accuracy: 0.9216 - IoU_coef: 0.5104 - val_loss: -0.0015 - val_accuracy: 0.8925 - val_IoU_coef: 0.0016
# Epoch 7/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4922 - accuracy: 0.9196 - IoU_coef: 0.4910 - val_loss: -0.0012 - val_accuracy: 0.8924 - val_IoU_coef: 0.0012
# Epoch 8/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.5220 - accuracy: 0.9239 - IoU_coef: 0.5220 - val_loss: -0.0011 - val_accuracy: 0.8916 - val_IoU_coef: 0.0011
# Epoch 9/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5297 - accuracy: 0.9249 - IoU_coef: 0.5281 - val_loss: -6.9093e-04 - val_accuracy: 0.8919 - val_IoU_coef: 7.3978e-04
# Epoch 10/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5248 - accuracy: 0.9266 - IoU_coef: 0.5248 - val_loss: -4.3569e-04 - val_accuracy: 0.8924 - val_IoU_coef: 4.6626e-04
# Epoch 11/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5512 - accuracy: 0.9307 - IoU_coef: 0.5493 - val_loss: -2.6932e-04 - val_accuracy: 0.8925 - val_IoU_coef: 2.8997e-04
# Epoch 12/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5330 - accuracy: 0.9270 - IoU_coef: 0.5322 - val_loss: -1.9342e-04 - val_accuracy: 0.8925 - val_IoU_coef: 2.1453e-04
# Epoch 13/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5546 - accuracy: 0.9305 - IoU_coef: 0.5546 - val_loss: -2.7349e-04 - val_accuracy: 0.8922 - val_IoU_coef: 2.8909e-04
# Epoch 14/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5537 - accuracy: 0.9316 - IoU_coef: 0.5528 - val_loss: -1.3193e-04 - val_accuracy: 0.8924 - val_IoU_coef: 1.4824e-04
# Epoch 15/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.5585 - accuracy: 0.9326 - IoU_coef: 0.5585 - val_loss: -0.0014 - val_accuracy: 0.8902 - val_IoU_coef: 0.0013
# Epoch 16/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5700 - accuracy: 0.9346 - IoU_coef: 0.5688 - val_loss: -1.3784e-04 - val_accuracy: 0.8922 - val_IoU_coef: 1.6003e-04
# Epoch 17/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5651 - accuracy: 0.9326 - IoU_coef: 0.5645 - val_loss: -0.0097 - val_accuracy: 0.8913 - val_IoU_coef: 0.0089
# Epoch 18/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.5869 - accuracy: 0.9369 - IoU_coef: 0.5869 - val_loss: -9.6238e-05 - val_accuracy: 0.8925 - val_IoU_coef: 1.0695e-04
# Epoch 19/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5794 - accuracy: 0.9367 - IoU_coef: 0.5789 - val_loss: -0.0069 - val_accuracy: 0.8926 - val_IoU_coef: 0.0064
# Epoch 20/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.5898 - accuracy: 0.9372 - IoU_coef: 0.5898 - val_loss: -0.0064 - val_accuracy: 0.8926 - val_IoU_coef: 0.0059
# Epoch 21/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5900 - accuracy: 0.9400 - IoU_coef: 0.5894 - val_loss: -0.0359 - val_accuracy: 0.8938 - val_IoU_coef: 0.0353
# Epoch 22/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.5974 - accuracy: 0.9391 - IoU_coef: 0.5974 - val_loss: -0.0737 - val_accuracy: 0.8986 - val_IoU_coef: 0.0714
# Epoch 23/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6150 - accuracy: 0.9422 - IoU_coef: 0.6138 - val_loss: -0.0584 - val_accuracy: 0.8960 - val_IoU_coef: 0.0557
# Epoch 24/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5946 - accuracy: 0.9405 - IoU_coef: 0.5946 - val_loss: -0.1398 - val_accuracy: 0.9038 - val_IoU_coef: 0.1355
# Epoch 25/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6104 - accuracy: 0.9403 - IoU_coef: 0.6104 - val_loss: -0.0680 - val_accuracy: 0.8967 - val_IoU_coef: 0.0639
# Epoch 26/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6224 - accuracy: 0.9442 - IoU_coef: 0.6217 - val_loss: -0.1180 - val_accuracy: 0.9025 - val_IoU_coef: 0.1147
# Epoch 27/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6139 - accuracy: 0.9439 - IoU_coef: 0.6139 - val_loss: -0.1056 - val_accuracy: 0.9015 - val_IoU_coef: 0.1010
# Epoch 28/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6323 - accuracy: 0.9465 - IoU_coef: 0.6315 - val_loss: -0.1535 - val_accuracy: 0.9056 - val_IoU_coef: 0.1490
# Epoch 29/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6230 - accuracy: 0.9441 - IoU_coef: 0.6229 - val_loss: -0.2846 - val_accuracy: 0.9170 - val_IoU_coef: 0.2835
# Epoch 30/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6358 - accuracy: 0.9454 - IoU_coef: 0.6358 - val_loss: -0.2599 - val_accuracy: 0.9145 - val_IoU_coef: 0.2562
# Epoch 31/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6449 - accuracy: 0.9490 - IoU_coef: 0.6443 - val_loss: -0.2828 - val_accuracy: 0.9167 - val_IoU_coef: 0.2814
# Epoch 32/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6338 - accuracy: 0.9464 - IoU_coef: 0.6338 - val_loss: -0.2858 - val_accuracy: 0.9176 - val_IoU_coef: 0.2833
# Epoch 33/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6443 - accuracy: 0.9489 - IoU_coef: 0.6434 - val_loss: -0.2479 - val_accuracy: 0.9138 - val_IoU_coef: 0.2466
# Epoch 34/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6332 - accuracy: 0.9462 - IoU_coef: 0.6333 - val_loss: -0.3206 - val_accuracy: 0.9220 - val_IoU_coef: 0.3199
# Epoch 35/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6395 - accuracy: 0.9470 - IoU_coef: 0.6395 - val_loss: -0.2797 - val_accuracy: 0.9165 - val_IoU_coef: 0.2785
# Epoch 36/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6335 - accuracy: 0.9463 - IoU_coef: 0.6330 - val_loss: -0.3653 - val_accuracy: 0.9242 - val_IoU_coef: 0.3654
# Epoch 37/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6334 - accuracy: 0.9451 - IoU_coef: 0.6334 - val_loss: -0.4050 - val_accuracy: 0.9217 - val_IoU_coef: 0.4100
# Epoch 38/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6245 - accuracy: 0.9457 - IoU_coef: 0.6250 - val_loss: -0.3735 - val_accuracy: 0.9245 - val_IoU_coef: 0.3751
# Epoch 39/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6329 - accuracy: 0.9455 - IoU_coef: 0.6329 - val_loss: -0.3878 - val_accuracy: 0.9245 - val_IoU_coef: 0.3879
# Epoch 40/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6551 - accuracy: 0.9499 - IoU_coef: 0.6540 - val_loss: -0.3530 - val_accuracy: 0.9237 - val_IoU_coef: 0.3541
# Epoch 41/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6473 - accuracy: 0.9502 - IoU_coef: 0.6479 - val_loss: -0.4338 - val_accuracy: 0.9303 - val_IoU_coef: 0.4344
# Epoch 42/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6646 - accuracy: 0.9510 - IoU_coef: 0.6646 - val_loss: -0.4108 - val_accuracy: 0.9268 - val_IoU_coef: 0.4134
# Epoch 43/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6766 - accuracy: 0.9535 - IoU_coef: 0.6769 - val_loss: -0.4599 - val_accuracy: 0.9281 - val_IoU_coef: 0.4641
# Epoch 44/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6540 - accuracy: 0.9510 - IoU_coef: 0.6540 - val_loss: -0.4378 - val_accuracy: 0.9280 - val_IoU_coef: 0.4413
# Epoch 45/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6756 - accuracy: 0.9539 - IoU_coef: 0.6751 - val_loss: -0.4518 - val_accuracy: 0.9308 - val_IoU_coef: 0.4571
# Epoch 46/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6565 - accuracy: 0.9497 - IoU_coef: 0.6562 - val_loss: -0.4563 - val_accuracy: 0.9320 - val_IoU_coef: 0.4589
# Epoch 47/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6719 - accuracy: 0.9522 - IoU_coef: 0.6719 - val_loss: -0.4529 - val_accuracy: 0.9329 - val_IoU_coef: 0.4591
# Epoch 48/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6859 - accuracy: 0.9562 - IoU_coef: 0.6852 - val_loss: -0.4486 - val_accuracy: 0.9321 - val_IoU_coef: 0.4522
# Epoch 49/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6779 - accuracy: 0.9542 - IoU_coef: 0.6779 - val_loss: -0.4494 - val_accuracy: 0.9322 - val_IoU_coef: 0.4555
# Epoch 50/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6900 - accuracy: 0.9569 - IoU_coef: 0.6898 - val_loss: -0.4498 - val_accuracy: 0.9324 - val_IoU_coef: 0.4526
# Epoch 51/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6671 - accuracy: 0.9519 - IoU_coef: 0.6674 - val_loss: -0.4504 - val_accuracy: 0.9327 - val_IoU_coef: 0.4554
# Epoch 52/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6865 - accuracy: 0.9553 - IoU_coef: 0.6865 - val_loss: -0.4325 - val_accuracy: 0.9305 - val_IoU_coef: 0.4356
# Epoch 53/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6656 - accuracy: 0.9521 - IoU_coef: 0.6649 - val_loss: -0.4344 - val_accuracy: 0.9307 - val_IoU_coef: 0.4380
# Epoch 54/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6722 - accuracy: 0.9519 - IoU_coef: 0.6722 - val_loss: -0.4636 - val_accuracy: 0.9329 - val_IoU_coef: 0.4673
# Epoch 55/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6875 - accuracy: 0.9571 - IoU_coef: 0.6875 - val_loss: -0.4674 - val_accuracy: 0.9338 - val_IoU_coef: 0.4717
# Epoch 56/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6952 - accuracy: 0.9568 - IoU_coef: 0.6952 - val_loss: -0.4747 - val_accuracy: 0.9340 - val_IoU_coef: 0.4793
# Epoch 57/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7188 - accuracy: 0.9606 - IoU_coef: 0.7183 - val_loss: -0.4703 - val_accuracy: 0.9348 - val_IoU_coef: 0.4733
# Epoch 58/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6995 - accuracy: 0.9591 - IoU_coef: 0.6998 - val_loss: -0.4592 - val_accuracy: 0.9352 - val_IoU_coef: 0.4653
# Epoch 59/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7062 - accuracy: 0.9580 - IoU_coef: 0.7062 - val_loss: -0.4714 - val_accuracy: 0.9340 - val_IoU_coef: 0.4749
# Epoch 60/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7071 - accuracy: 0.9588 - IoU_coef: 0.7063 - val_loss: -0.4788 - val_accuracy: 0.9352 - val_IoU_coef: 0.4827
# Epoch 61/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6829 - accuracy: 0.9555 - IoU_coef: 0.6829 - val_loss: -0.4842 - val_accuracy: 0.9344 - val_IoU_coef: 0.4884
# Epoch 62/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7023 - accuracy: 0.9583 - IoU_coef: 0.7023 - val_loss: -0.4751 - val_accuracy: 0.9352 - val_IoU_coef: 0.4806
# Epoch 63/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6929 - accuracy: 0.9565 - IoU_coef: 0.6934 - val_loss: -0.4990 - val_accuracy: 0.9360 - val_IoU_coef: 0.5046
# Epoch 64/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6950 - accuracy: 0.9564 - IoU_coef: 0.6950 - val_loss: -0.5002 - val_accuracy: 0.9345 - val_IoU_coef: 0.5050
# Epoch 65/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7154 - accuracy: 0.9609 - IoU_coef: 0.7150 - val_loss: -0.5041 - val_accuracy: 0.9363 - val_IoU_coef: 0.5093
# Epoch 66/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6995 - accuracy: 0.9578 - IoU_coef: 0.6995 - val_loss: -0.4915 - val_accuracy: 0.9326 - val_IoU_coef: 0.4969
# Epoch 67/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7090 - accuracy: 0.9599 - IoU_coef: 0.7088 - val_loss: -0.4840 - val_accuracy: 0.9347 - val_IoU_coef: 0.4882
# Epoch 68/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6801 - accuracy: 0.9536 - IoU_coef: 0.6811 - val_loss: -0.4736 - val_accuracy: 0.9321 - val_IoU_coef: 0.4797
# Epoch 69/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6888 - accuracy: 0.9553 - IoU_coef: 0.6888 - val_loss: -0.4952 - val_accuracy: 0.9367 - val_IoU_coef: 0.4998
# Epoch 70/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6924 - accuracy: 0.9564 - IoU_coef: 0.6924 - val_loss: -0.4819 - val_accuracy: 0.9347 - val_IoU_coef: 0.4880
# Epoch 71/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6977 - accuracy: 0.9564 - IoU_coef: 0.6977 - val_loss: -0.5062 - val_accuracy: 0.9371 - val_IoU_coef: 0.5112
# Epoch 72/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7220 - accuracy: 0.9627 - IoU_coef: 0.7220 - val_loss: -0.4963 - val_accuracy: 0.9360 - val_IoU_coef: 0.5020
# Epoch 73/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7091 - accuracy: 0.9592 - IoU_coef: 0.7091 - val_loss: -0.5052 - val_accuracy: 0.9357 - val_IoU_coef: 0.5114
# Epoch 74/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7320 - accuracy: 0.9624 - IoU_coef: 0.7320 - val_loss: -0.4924 - val_accuracy: 0.9336 - val_IoU_coef: 0.4985
# Epoch 75/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7077 - accuracy: 0.9604 - IoU_coef: 0.7088 - val_loss: -0.5019 - val_accuracy: 0.9341 - val_IoU_coef: 0.5086
# Epoch 76/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7120 - accuracy: 0.9587 - IoU_coef: 0.7120 - val_loss: -0.5056 - val_accuracy: 0.9343 - val_IoU_coef: 0.5093
# Epoch 77/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7229 - accuracy: 0.9614 - IoU_coef: 0.7226 - val_loss: -0.5111 - val_accuracy: 0.9342 - val_IoU_coef: 0.5174
# Epoch 78/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7051 - accuracy: 0.9596 - IoU_coef: 0.7051 - val_loss: -0.5167 - val_accuracy: 0.9349 - val_IoU_coef: 0.5216
# Epoch 79/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7348 - accuracy: 0.9636 - IoU_coef: 0.7346 - val_loss: -0.5150 - val_accuracy: 0.9351 - val_IoU_coef: 0.5204
# Epoch 80/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7143 - accuracy: 0.9599 - IoU_coef: 0.7152 - val_loss: -0.5105 - val_accuracy: 0.9332 - val_IoU_coef: 0.5162
# Epoch 81/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7243 - accuracy: 0.9608 - IoU_coef: 0.7243 - val_loss: -0.4966 - val_accuracy: 0.9330 - val_IoU_coef: 0.4999
# Epoch 82/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7369 - accuracy: 0.9645 - IoU_coef: 0.7367 - val_loss: -0.4894 - val_accuracy: 0.9332 - val_IoU_coef: 0.4968
# Epoch 83/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7158 - accuracy: 0.9604 - IoU_coef: 0.7158 - val_loss: -0.4891 - val_accuracy: 0.9323 - val_IoU_coef: 0.4929
# Epoch 84/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7206 - accuracy: 0.9620 - IoU_coef: 0.7205 - val_loss: -0.4840 - val_accuracy: 0.9325 - val_IoU_coef: 0.4913
# Epoch 85/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6993 - accuracy: 0.9568 - IoU_coef: 0.6995 - val_loss: -0.4955 - val_accuracy: 0.9327 - val_IoU_coef: 0.4983
# Epoch 86/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7093 - accuracy: 0.9590 - IoU_coef: 0.7093 - val_loss: -0.4901 - val_accuracy: 0.9348 - val_IoU_coef: 0.4958
# Epoch 87/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7064 - accuracy: 0.9587 - IoU_coef: 0.7074 - val_loss: -0.5081 - val_accuracy: 0.9336 - val_IoU_coef: 0.5132
# Epoch 88/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7146 - accuracy: 0.9595 - IoU_coef: 0.7146 - val_loss: -0.5106 - val_accuracy: 0.9342 - val_IoU_coef: 0.5151
# Epoch 89/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7314 - accuracy: 0.9640 - IoU_coef: 0.7315 - val_loss: -0.5112 - val_accuracy: 0.9338 - val_IoU_coef: 0.5179
# Epoch 90/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7270 - accuracy: 0.9616 - IoU_coef: 0.7270 - val_loss: -0.5098 - val_accuracy: 0.9323 - val_IoU_coef: 0.5151
# Epoch 91/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7565 - accuracy: 0.9665 - IoU_coef: 0.7562 - val_loss: -0.5108 - val_accuracy: 0.9338 - val_IoU_coef: 0.5161
# Epoch 92/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7433 - accuracy: 0.9657 - IoU_coef: 0.7441 - val_loss: -0.5124 - val_accuracy: 0.9354 - val_IoU_coef: 0.5173
# Epoch 93/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7546 - accuracy: 0.9656 - IoU_coef: 0.7546 - val_loss: -0.5077 - val_accuracy: 0.9328 - val_IoU_coef: 0.5130
# Epoch 94/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7660 - accuracy: 0.9683 - IoU_coef: 0.7664 - val_loss: -0.5143 - val_accuracy: 0.9351 - val_IoU_coef: 0.5201
# Epoch 95/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7512 - accuracy: 0.9671 - IoU_coef: 0.7512 - val_loss: -0.4994 - val_accuracy: 0.9322 - val_IoU_coef: 0.5043
# Epoch 96/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7703 - accuracy: 0.9693 - IoU_coef: 0.7701 - val_loss: -0.5129 - val_accuracy: 0.9373 - val_IoU_coef: 0.5181
# Epoch 97/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7579 - accuracy: 0.9671 - IoU_coef: 0.7587 - val_loss: -0.5104 - val_accuracy: 0.9347 - val_IoU_coef: 0.5154
# Epoch 98/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7584 - accuracy: 0.9665 - IoU_coef: 0.7584 - val_loss: -0.5080 - val_accuracy: 0.9356 - val_IoU_coef: 0.5128
# Epoch 99/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7798 - accuracy: 0.9712 - IoU_coef: 0.7797 - val_loss: -0.5124 - val_accuracy: 0.9359 - val_IoU_coef: 0.5178
# Epoch 100/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7578 - accuracy: 0.9671 - IoU_coef: 0.7578 - val_loss: -0.4894 - val_accuracy: 0.9304 - val_IoU_coef: 0.4935
# Epoch 101/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7701 - accuracy: 0.9695 - IoU_coef: 0.7697 - val_loss: -0.4952 - val_accuracy: 0.9343 - val_IoU_coef: 0.5002
# Epoch 102/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7448 - accuracy: 0.9646 - IoU_coef: 0.7454 - val_loss: -0.4901 - val_accuracy: 0.9300 - val_IoU_coef: 0.4942
# Epoch 103/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7474 - accuracy: 0.9651 - IoU_coef: 0.7474 - val_loss: -0.4883 - val_accuracy: 0.9344 - val_IoU_coef: 0.4943
# Epoch 104/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7359 - accuracy: 0.9637 - IoU_coef: 0.7369 - val_loss: -0.5007 - val_accuracy: 0.9320 - val_IoU_coef: 0.5057
# Epoch 105/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7190 - accuracy: 0.9601 - IoU_coef: 0.7190 - val_loss: -0.5030 - val_accuracy: 0.9342 - val_IoU_coef: 0.5076
# Epoch 106/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7260 - accuracy: 0.9633 - IoU_coef: 0.7268 - val_loss: -0.4959 - val_accuracy: 0.9340 - val_IoU_coef: 0.5022
# Epoch 107/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7091 - accuracy: 0.9587 - IoU_coef: 0.7091 - val_loss: -0.4965 - val_accuracy: 0.9301 - val_IoU_coef: 0.5014
# Epoch 108/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7289 - accuracy: 0.9620 - IoU_coef: 0.7287 - val_loss: -0.4888 - val_accuracy: 0.9319 - val_IoU_coef: 0.4965
# Epoch 109/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7130 - accuracy: 0.9604 - IoU_coef: 0.7145 - val_loss: -0.4863 - val_accuracy: 0.9311 - val_IoU_coef: 0.4909
# Epoch 110/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7186 - accuracy: 0.9599 - IoU_coef: 0.7186 - val_loss: -0.4830 - val_accuracy: 0.9326 - val_IoU_coef: 0.4908
# Epoch 111/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7328 - accuracy: 0.9628 - IoU_coef: 0.7325 - val_loss: -0.4892 - val_accuracy: 0.9328 - val_IoU_coef: 0.4931
# Epoch 112/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7130 - accuracy: 0.9607 - IoU_coef: 0.7130 - val_loss: -0.4936 - val_accuracy: 0.9338 - val_IoU_coef: 0.5012
# Epoch 113/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7414 - accuracy: 0.9647 - IoU_coef: 0.7405 - val_loss: -0.4953 - val_accuracy: 0.9356 - val_IoU_coef: 0.4989
# Epoch 114/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7266 - accuracy: 0.9615 - IoU_coef: 0.7265 - val_loss: -0.5136 - val_accuracy: 0.9355 - val_IoU_coef: 0.5196
# Epoch 115/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7340 - accuracy: 0.9625 - IoU_coef: 0.7340 - val_loss: -0.5150 - val_accuracy: 0.9370 - val_IoU_coef: 0.5199
# Epoch 116/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7566 - accuracy: 0.9673 - IoU_coef: 0.7564 - val_loss: -0.5159 - val_accuracy: 0.9373 - val_IoU_coef: 0.5205
# Epoch 117/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7492 - accuracy: 0.9655 - IoU_coef: 0.7492 - val_loss: -0.5167 - val_accuracy: 0.9358 - val_IoU_coef: 0.5230
# Epoch 118/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7772 - accuracy: 0.9706 - IoU_coef: 0.7772 - val_loss: -0.5043 - val_accuracy: 0.9353 - val_IoU_coef: 0.5084
# Epoch 119/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7603 - accuracy: 0.9668 - IoU_coef: 0.7613 - val_loss: -0.5142 - val_accuracy: 0.9355 - val_IoU_coef: 0.5204
# Epoch 120/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7845 - accuracy: 0.9710 - IoU_coef: 0.7845 - val_loss: -0.5044 - val_accuracy: 0.9352 - val_IoU_coef: 0.5091
# Epoch 121/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7841 - accuracy: 0.9712 - IoU_coef: 0.7847 - val_loss: -0.5131 - val_accuracy: 0.9363 - val_IoU_coef: 0.5192
# Epoch 122/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7809 - accuracy: 0.9700 - IoU_coef: 0.7809 - val_loss: -0.5152 - val_accuracy: 0.9352 - val_IoU_coef: 0.5201
# Epoch 123/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7917 - accuracy: 0.9732 - IoU_coef: 0.7922 - val_loss: -0.5186 - val_accuracy: 0.9365 - val_IoU_coef: 0.5243
# Epoch 124/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7756 - accuracy: 0.9697 - IoU_coef: 0.7756 - val_loss: -0.5121 - val_accuracy: 0.9336 - val_IoU_coef: 0.5169
# Epoch 125/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7942 - accuracy: 0.9722 - IoU_coef: 0.7943 - val_loss: -0.5117 - val_accuracy: 0.9368 - val_IoU_coef: 0.5166
# Epoch 126/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7741 - accuracy: 0.9705 - IoU_coef: 0.7744 - val_loss: -0.5064 - val_accuracy: 0.9347 - val_IoU_coef: 0.5120
# Epoch 127/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7799 - accuracy: 0.9695 - IoU_coef: 0.7799 - val_loss: -0.5031 - val_accuracy: 0.9360 - val_IoU_coef: 0.5079
# Epoch 128/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7873 - accuracy: 0.9715 - IoU_coef: 0.7868 - val_loss: -0.4977 - val_accuracy: 0.9349 - val_IoU_coef: 0.5041
# Epoch 129/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7618 - accuracy: 0.9683 - IoU_coef: 0.7618 - val_loss: -0.5014 - val_accuracy: 0.9356 - val_IoU_coef: 0.5054
# Epoch 130/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7820 - accuracy: 0.9709 - IoU_coef: 0.7817 - val_loss: -0.4852 - val_accuracy: 0.9359 - val_IoU_coef: 0.4918
# Epoch 131/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7602 - accuracy: 0.9674 - IoU_coef: 0.7611 - val_loss: -0.5055 - val_accuracy: 0.9352 - val_IoU_coef: 0.5092
# Epoch 132/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7705 - accuracy: 0.9681 - IoU_coef: 0.7705 - val_loss: -0.4943 - val_accuracy: 0.9358 - val_IoU_coef: 0.4997
# Epoch 133/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7822 - accuracy: 0.9715 - IoU_coef: 0.7827 - val_loss: -0.5095 - val_accuracy: 0.9361 - val_IoU_coef: 0.5139
# Epoch 134/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7723 - accuracy: 0.9694 - IoU_coef: 0.7723 - val_loss: -0.5004 - val_accuracy: 0.9354 - val_IoU_coef: 0.5054
# Epoch 135/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7906 - accuracy: 0.9726 - IoU_coef: 0.7908 - val_loss: -0.5024 - val_accuracy: 0.9364 - val_IoU_coef: 0.5076
# Epoch 136/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7687 - accuracy: 0.9684 - IoU_coef: 0.7693 - val_loss: -0.4952 - val_accuracy: 0.9335 - val_IoU_coef: 0.4996
# Epoch 137/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7833 - accuracy: 0.9707 - IoU_coef: 0.7833 - val_loss: -0.4835 - val_accuracy: 0.9343 - val_IoU_coef: 0.4896
# Epoch 138/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7745 - accuracy: 0.9697 - IoU_coef: 0.7754 - val_loss: -0.4881 - val_accuracy: 0.9331 - val_IoU_coef: 0.4926
# Epoch 139/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7665 - accuracy: 0.9678 - IoU_coef: 0.7665 - val_loss: -0.4818 - val_accuracy: 0.9332 - val_IoU_coef: 0.4886
# Epoch 140/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7751 - accuracy: 0.9708 - IoU_coef: 0.7751 - val_loss: -0.4845 - val_accuracy: 0.9344 - val_IoU_coef: 0.4893
# Epoch 141/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7634 - accuracy: 0.9675 - IoU_coef: 0.7634 - val_loss: -0.4941 - val_accuracy: 0.9347 - val_IoU_coef: 0.5002
# Epoch 142/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7814 - accuracy: 0.9703 - IoU_coef: 0.7806 - val_loss: -0.4836 - val_accuracy: 0.9351 - val_IoU_coef: 0.4889
# Epoch 143/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7643 - accuracy: 0.9690 - IoU_coef: 0.7647 - val_loss: -0.5076 - val_accuracy: 0.9327 - val_IoU_coef: 0.5143
# Epoch 144/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7684 - accuracy: 0.9679 - IoU_coef: 0.7684 - val_loss: -0.5037 - val_accuracy: 0.9361 - val_IoU_coef: 0.5095
# Epoch 145/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7834 - accuracy: 0.9708 - IoU_coef: 0.7842 - val_loss: -0.5145 - val_accuracy: 0.9332 - val_IoU_coef: 0.5200
# Epoch 146/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7713 - accuracy: 0.9700 - IoU_coef: 0.7713 - val_loss: -0.5130 - val_accuracy: 0.9341 - val_IoU_coef: 0.5180
# Epoch 147/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.8010 - accuracy: 0.9738 - IoU_coef: 0.8011 - val_loss: -0.5068 - val_accuracy: 0.9344 - val_IoU_coef: 0.5116
# Epoch 148/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7789 - accuracy: 0.9699 - IoU_coef: 0.7798 - val_loss: -0.5169 - val_accuracy: 0.9359 - val_IoU_coef: 0.5224
# Epoch 149/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7936 - accuracy: 0.9718 - IoU_coef: 0.7936 - val_loss: -0.4998 - val_accuracy: 0.9339 - val_IoU_coef: 0.5040
# Epoch 150/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.8097 - accuracy: 0.9754 - IoU_coef: 0.8097 - val_loss: -0.5106 - val_accuracy: 0.9354 - val_IoU_coef: 0.5171

# %%
test_image_list = glob.glob(TEST_IMAGE_PATH + '/*.JPG')
test_image_list.sort()

test_vessel_mask_list = glob.glob(TEST_VESSEL_MASK_PATH + '/*.jpg')
test_vessel_mask_list.sort()

# %%
test_image_list = glob.glob(TEST_IMAGE_PATH + '/*.JPG')
test_image_list.sort()

test_vessel_mask_list = glob.glob(TEST_VESSEL_MASK_PATH + '/*.jpg')
test_vessel_mask_list.sort()

# %%
from datetime import datetime 

test_image_number = random.randint(0, len(test_image_list)-1)

reconstructed_image = []
test_img = cv2.imread(test_image_list[test_image_number])
gt = cv2.imread(test_vessel_mask_list[test_image_number])

predicted_patches = []
start = datetime.now()   

test = preprocess_image(test_img, PATCH_SIZE)
patches = patchify(test, (PATCH_SIZE, PATCH_SIZE), step=PATCH_SIZE) 

for i in range(patches.shape[0]):
      for j in range(patches.shape[1]):
          single_patch = patches[i,j,:,:]
          single_patch_norm = (single_patch.astype('float32')) 
          single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
          single_patch_input = np.expand_dims(single_patch_norm, 0)
          single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8)
          predicted_patches.append(single_patch_prediction)
          
predicted_patches = np.array(predicted_patches)
predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], PATCH_SIZE, PATCH_SIZE))

reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape) 
reconstructed_image = cv2.resize(reconstructed_image, (512, 512))

stop = datetime.now()
print('Execution time: ',(stop-start)) #computation time

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title(test_image_list[test_image_number])
plt.imshow(cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB))
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(gt, cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(reconstructed_image, cmap='gray')
plt.show()
# Out:
# 1/1 [==============================] - 1s 752ms/step
# 1/1 [==============================] - 0s 33ms/step
# Execution time:  0:00:01.193908

# %%
print(reconstructed_image.shape)
print(reconstructed_image.max(), reconstructed_image.min())
print(np.unique(reconstructed_image))

predicted_image = np.expand_dims(reconstructed_image, axis=-1)

plt.figure(figsize=(16, 8))
plt.imshow(predicted_image, cmap='gray')
plt.show()

print(predicted_image.shape)
print(predicted_image.max(), predicted_image.min())
print(np.unique(predicted_image))
# Out:
# (512, 512)
# 1 0
# [0 1]
# (512, 512, 1)
# 1 0
# [0 1]

# %% [markdown]
# **PREDICT THE NEXT 20 DATASET**

# %%
PATH = '/content/drive/MyDrive/AV_split/'

TRAIN_PATH = PATH+'train_av/'
TRAIN_IMAGE_PATH = TRAIN_PATH + 'images/'
TRAIN_VESSEL_MASK_PATH = TRAIN_PATH + 'GT_vessel/'
TRAIN_ARTERY_MASK_PATH = TRAIN_PATH + 'GT_artery/'
TRAIN_VEIN_MASK_PATH = TRAIN_PATH + 'GT_vein/'

TEST_PATH = PATH+'test_av/'
TEST_IMAGE_PATH = TEST_PATH + 'images/'
TEST_VESSEL_MASK_PATH = TEST_PATH + 'GT_vessel/'
TEST_ARTERY_MASK_PATH = TEST_PATH + 'GT_artery/'
TEST_VEIN_MASK_PATH = TEST_PATH + 'GT_vein/'

PATCH_SIZE = 512

VEIN_COLOR = [0, 0, 255]      
ARTERY_COLOR = [255, 0, 0]     
BLACK_BG_COLOR = [0, 0, 0]
VESSEL_COLOR = [255, 255, 255]

# %%
train_av_image_paths = glob.glob(TRAIN_IMAGE_PATH + "/*.JPG")
train_av_image_paths.sort()

train_av_vessel_paths = glob.glob(TRAIN_VESSEL_MASK_PATH + "/*.jpg")
train_av_vessel_paths.sort()

train_av_artery_paths = glob.glob(TRAIN_ARTERY_MASK_PATH + "/*.jpg")
train_av_artery_paths.sort()

train_av_vein_paths = glob.glob(TRAIN_VEIN_MASK_PATH + "/*.jpg")
train_av_vein_paths.sort()

predicted_vessel_dataset = []
gt_vessel_dataset = []

# %%
for image_path, vessel_path in zip(train_av_image_paths, train_av_vessel_paths):
      image_patch_list, _ = image_to_patch(image_path, "IMAGE", preprocess_image, PATCH_SIZE)
      gt_vessel = cv2.imread(vessel_path)
      gt_vessel = preprocess_vessel_mask(gt_vessel, PATCH_SIZE)

      predicted_patches = []

      for patch in image_patch_list:
          patch = np.array(patch)
          patch = patch.astype(np.float32)
          patch = np.expand_dims(np.array(patch), axis=-1)
          single_patch_input = np.expand_dims(patch, 0)
          single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8)
          predicted_patches.append(single_patch_prediction)

      predicted_patches = np.array(predicted_patches)
      predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], PATCH_SIZE, PATCH_SIZE))
      reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape)

      predicted_vessel_dataset.append(reconstructed_image)
      gt_vessel_dataset.append(gt_vessel)
  
predicted_vessel_dataset = np.array(predicted_vessel_dataset)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
for i in range(1, 4):
    plt.figure(figsize=(16, 8))
    plt.subplot(121)
    plt.title(train_av_image_paths[i])
    plt.imshow(predicted_vessel_dataset[i])
    plt.subplot(122)
    plt.title('Testing Label')
    plt.imshow(gt_vessel_dataset[i], cmap='gray')
    plt.show()

# %% [markdown]
# **TRAIN PREDICTED VESSEL TO ARTERY VEIN**

# %%
def vessel_image_to_patch(image, patch_size):
    image_dataset = unpatched_image = []

    image = (image).astype('uint8')
    rgb_image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB) * 255

    patches_image = patchify(rgb_image, (patch_size, patch_size, 3), step=patch_size)
    unpatched_image = unpatchify(patches_image, rgb_image.shape)
    
    for i in range(patches_image.shape[0]):
        for j in range(patches_image.shape[1]):
            single_patch = patches_image[i,j,:,:]
            single_patch = (single_patch).astype('float32')
            image_dataset.append(single_patch[0])

    return image_dataset, unpatched_image

# %%
def preprocess_vessel_mask(mask, patch_size):
    thresh = 128
    mask = cv2.threshold(mask, thresh, 255, cv2.THRESH_BINARY)[1]

    mask = mask[70:970, 200:1255]
    
    SIZE_X = (mask.shape[1]//patch_size)*patch_size 
    SIZE_Y = (mask.shape[0]//patch_size)*patch_size     

    mask = cv2.resize(mask, (SIZE_X, SIZE_Y))
  
    mask = 255 - mask
    mask = mask / 255

    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0

    return mask

def preprocess_vein_mask(image, patch_size):
    mask = preprocess_vessel_mask(image, patch_size)

    mask = (mask).astype('uint8')
    mask = cv2.cvtColor(mask, cv2.COLOR_GRAY2RGB) * 255

    mask[np.all(mask == VESSEL_COLOR, axis=-1)] = VEIN_COLOR

    return (mask).astype('float32')

def preprocess_artery_mask(image, patch_size):
    mask = preprocess_vessel_mask(image, patch_size)

    mask = (mask).astype('uint8')
    mask = cv2.cvtColor(mask, cv2.COLOR_GRAY2RGB) * 255

    mask[np.all(mask == VESSEL_COLOR, axis=-1)] = ARTERY_COLOR

    return (mask).astype('float32')

def merge_and_mask_labeling(vein_mask, artery_mask):
    result = cv2.add(vein_mask, artery_mask)

    mask_label = np.zeros(result.shape, dtype=np.uint8)
    mask_label[np.all(result == ARTERY_COLOR, axis=-1)] = 1
    mask_label[np.all(result == VEIN_COLOR, axis=-1)] = 2                                   

    return result, mask_label[:,:,0]                                            

def mask_to_patch(vein_path, artery_path, patch_size, visualize = False):
    mask_dataset = []

    vein_image = cv2.imread(vein_path, cv2.IMREAD_GRAYSCALE)
    vein_mask = preprocess_vein_mask(vein_image, patch_size)

    artery_image = cv2.imread(artery_path, cv2.IMREAD_GRAYSCALE)
    artery_mask = preprocess_artery_mask(artery_image, patch_size)

    if visualize:
        merged_mask, _ = merge_and_mask_labeling(vein_mask, artery_mask)
    else:
        _, merged_mask = merge_and_mask_labeling(vein_mask, artery_mask)

    patches_mask = patchify(merged_mask, (patch_size, patch_size), step=patch_size)
    unpatched_mask = unpatchify(patches_mask, merged_mask.shape)
    
    for i in range(patches_mask.shape[0]):
        for j in range(patches_mask.shape[1]):
            single_patch = patches_mask[i,j,:,:]
            single_patch = (single_patch).astype('float32')
            mask_dataset.append(single_patch)

    return mask_dataset, unpatched_mask

# %%
train_image_dataset = []
train_mask_dataset = []

for image_path in predicted_vessel_dataset:
    patched_image, predicted_vessel_dataset = vessel_image_to_patch(image_path, PATCH_SIZE)
    train_image_dataset += patched_image

for (vein_mask_path, artery_mask_path) in zip(train_av_vein_paths, train_av_artery_paths):
    patched_mask, unpatched_mask = mask_to_patch(vein_mask_path, artery_mask_path, PATCH_SIZE, visualize = False)
    train_mask_dataset += patched_mask

train_image_dataset = np.array(train_image_dataset)
train_mask_dataset = np.array(train_mask_dataset)

print(train_image_dataset.shape)
print(train_mask_dataset.shape)
print(train_image_dataset.max(), train_mask_dataset.max())
print(train_image_dataset.min(), train_mask_dataset.min())
# Out:
# (40, 512, 512, 3)
# (40, 512, 512)
# 255.0 2.0
# 0.0 0.0

# %%
from tensorflow.keras.utils import to_categorical

n_classes = len(np.unique(train_mask_dataset))
mask_categories = to_categorical(train_mask_dataset, num_classes=n_classes)

print(np.unique(mask_categories))
print(mask_categories.shape)
# Out:
# [0. 1.]
# (40, 512, 512, 3)

# %%
rows = 3
columns = 2

fig = plt.figure(figsize=(5, 5))
for i in range(1, (rows * columns + 1)):
    plt.figure(figsize=(12, 6))

    plt.subplot(121)
    plt.imshow(train_image_dataset[i-1])

    plt.subplot(122)
    plt.imshow(mask_categories[i-1])
    
    plt.show()
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train_image_dataset, mask_categories, test_size=0.2, random_state=0)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (32, 512, 512, 3) (32, 512, 512, 3)
# (8, 512, 512, 3) (8, 512, 512, 3)

# %%
IMG_HEIGHT = x_train.shape[1]
IMG_WIDTH  = x_train.shape[2]
IMG_CHANNELS = x_train.shape[3]

print(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
# Out:
# 512 512 3

# %%
import tensorflow as tf
from keras.models import Model, load_model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.optimizers import Adam
from keras.layers import Activation, MaxPool2D, Concatenate

def dice_coef(y_true, y_pred, smooth = 1):
    intersection = K.sum(y_true * y_pred, axis = [1,2,3])
    union = K.sum(y_true, axis = [1,2,3]) + K.sum(y_pred, axis = [1,2,3])
    return K.mean( (2. * intersection + smooth) / (union + smooth), axis = 0)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def unet_multi(pretrained_weights = None, input_size = (512,512,3), n_class = 3):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    drop4 = Dropout(0.5)(conv4, training=True)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    conv5 = BatchNormalization()(conv5)
    drop5 = Dropout(0.5)(conv5, training=True)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
       
    conv10 = Conv2D(n_class, (1,1), activation = 'softmax')(conv9)
    
 
    model = tf.keras.Model(inputs = inputs, outputs = conv10)

    model.compile(optimizer = Adam(lr = 0.0001), loss = ['binary_crossentropy'], metrics = ['accuracy'])    

    if(pretrained_weights):
    	model = keras.models.load_model(pretrained_weights)

    return model

# %%
model = unet_multi(n_class = n_classes)
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
model_checkpoint = tf.keras.callbacks.ModelCheckpoint('unet_DB1_multi.hdf5', monitor = 'loss', verbose = 0)

model = unet_multi(n_class = n_classes)
history = model.fit(x_train, y_train, 
                    batch_size = 3, 
                    verbose = 1, 
                    epochs = 150, 
                    validation_data = (x_test, y_test), 
                    steps_per_epoch = 10,
                    shuffle = False,
                    callbacks = [model_checkpoint])
# Out:
# Epoch 1/150
# 10/10 [==============================] - 15s 1s/step - loss: 0.3201 - accuracy: 0.8069 - val_loss: 2.5054 - val_accuracy: 0.8850
# Epoch 2/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1952 - accuracy: 0.8924 - val_loss: 0.6407 - val_accuracy: 0.8863
# Epoch 3/150
# 10/10 [==============================] - 12s 1s/step - loss: 0.1825 - accuracy: 0.8953 - val_loss: 0.3190 - val_accuracy: 0.8918
# Epoch 4/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1765 - accuracy: 0.8966 - val_loss: 0.2309 - val_accuracy: 0.8968
# Epoch 5/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1727 - accuracy: 0.8979 - val_loss: 0.1997 - val_accuracy: 0.8979
# Epoch 6/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1737 - accuracy: 0.8957 - val_loss: 0.1870 - val_accuracy: 0.9001
# Epoch 7/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1717 - accuracy: 0.8975 - val_loss: 0.1828 - val_accuracy: 0.9008
# Epoch 8/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1690 - accuracy: 0.8990 - val_loss: 0.1800 - val_accuracy: 0.9020
# Epoch 9/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1683 - accuracy: 0.8987 - val_loss: 0.1785 - val_accuracy: 0.9034
# Epoch 10/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1660 - accuracy: 0.9007 - val_loss: 0.1751 - val_accuracy: 0.9047
# Epoch 11/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1654 - accuracy: 0.9000 - val_loss: 0.1707 - val_accuracy: 0.9055
# Epoch 12/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1634 - accuracy: 0.9010 - val_loss: 0.1677 - val_accuracy: 0.9066
# Epoch 13/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1632 - accuracy: 0.9018 - val_loss: 0.1709 - val_accuracy: 0.9066
# Epoch 14/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1606 - accuracy: 0.9034 - val_loss: 0.1665 - val_accuracy: 0.9063
# Epoch 15/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1596 - accuracy: 0.9046 - val_loss: 0.1585 - val_accuracy: 0.9067
# Epoch 16/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1564 - accuracy: 0.9061 - val_loss: 0.1607 - val_accuracy: 0.9055
# Epoch 17/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1576 - accuracy: 0.9050 - val_loss: 0.1829 - val_accuracy: 0.8954
# Epoch 18/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1539 - accuracy: 0.9091 - val_loss: 0.2180 - val_accuracy: 0.8925
# Epoch 19/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1525 - accuracy: 0.9118 - val_loss: 0.2490 - val_accuracy: 0.8797
# Epoch 20/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1524 - accuracy: 0.9106 - val_loss: 0.1964 - val_accuracy: 0.8897
# Epoch 21/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1476 - accuracy: 0.9138 - val_loss: 0.2255 - val_accuracy: 0.8854
# Epoch 22/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1452 - accuracy: 0.9142 - val_loss: 0.2576 - val_accuracy: 0.8857
# Epoch 23/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1417 - accuracy: 0.9163 - val_loss: 0.2632 - val_accuracy: 0.8879
# Epoch 24/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1369 - accuracy: 0.9190 - val_loss: 0.2570 - val_accuracy: 0.8841
# Epoch 25/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1337 - accuracy: 0.9210 - val_loss: 0.2496 - val_accuracy: 0.8858
# Epoch 26/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1338 - accuracy: 0.9209 - val_loss: 0.2550 - val_accuracy: 0.8848
# Epoch 27/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1345 - accuracy: 0.9200 - val_loss: 0.2555 - val_accuracy: 0.8928
# Epoch 28/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1367 - accuracy: 0.9188 - val_loss: 0.2063 - val_accuracy: 0.8969
# Epoch 29/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1287 - accuracy: 0.9227 - val_loss: 0.2669 - val_accuracy: 0.8866
# Epoch 30/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1231 - accuracy: 0.9258 - val_loss: 0.2804 - val_accuracy: 0.8870
# Epoch 31/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1213 - accuracy: 0.9264 - val_loss: 0.2546 - val_accuracy: 0.8918
# Epoch 32/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1174 - accuracy: 0.9285 - val_loss: 0.3073 - val_accuracy: 0.8840
# Epoch 33/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1149 - accuracy: 0.9293 - val_loss: 0.2526 - val_accuracy: 0.8868
# Epoch 34/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1128 - accuracy: 0.9307 - val_loss: 0.2407 - val_accuracy: 0.8946
# Epoch 35/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1115 - accuracy: 0.9303 - val_loss: 0.2735 - val_accuracy: 0.8950
# Epoch 36/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1090 - accuracy: 0.9314 - val_loss: 0.2777 - val_accuracy: 0.8854
# Epoch 37/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1087 - accuracy: 0.9320 - val_loss: 0.2766 - val_accuracy: 0.9008
# Epoch 38/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1070 - accuracy: 0.9324 - val_loss: 0.2626 - val_accuracy: 0.8877
# Epoch 39/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1052 - accuracy: 0.9334 - val_loss: 0.2429 - val_accuracy: 0.8967
# Epoch 40/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1005 - accuracy: 0.9356 - val_loss: 0.2906 - val_accuracy: 0.8919
# Epoch 41/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0979 - accuracy: 0.9376 - val_loss: 0.2828 - val_accuracy: 0.8867
# Epoch 42/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0975 - accuracy: 0.9377 - val_loss: 0.2695 - val_accuracy: 0.8893
# Epoch 43/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0952 - accuracy: 0.9393 - val_loss: 0.2462 - val_accuracy: 0.9010
# Epoch 44/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0973 - accuracy: 0.9377 - val_loss: 0.2775 - val_accuracy: 0.8836
# Epoch 45/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0944 - accuracy: 0.9401 - val_loss: 0.2759 - val_accuracy: 0.9000
# Epoch 46/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0924 - accuracy: 0.9412 - val_loss: 0.2782 - val_accuracy: 0.8939
# Epoch 47/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0888 - accuracy: 0.9434 - val_loss: 0.2710 - val_accuracy: 0.9014
# Epoch 48/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0889 - accuracy: 0.9436 - val_loss: 0.2922 - val_accuracy: 0.8981
# Epoch 49/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0862 - accuracy: 0.9447 - val_loss: 0.2699 - val_accuracy: 0.8946
# Epoch 50/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0866 - accuracy: 0.9441 - val_loss: 0.2947 - val_accuracy: 0.8882
# Epoch 51/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0846 - accuracy: 0.9451 - val_loss: 0.3069 - val_accuracy: 0.8865
# Epoch 52/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0829 - accuracy: 0.9465 - val_loss: 0.2432 - val_accuracy: 0.8943
# Epoch 53/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0828 - accuracy: 0.9463 - val_loss: 0.2865 - val_accuracy: 0.8860
# Epoch 54/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0806 - accuracy: 0.9474 - val_loss: 0.3190 - val_accuracy: 0.8984
# Epoch 55/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0810 - accuracy: 0.9471 - val_loss: 0.2888 - val_accuracy: 0.8892
# Epoch 56/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0823 - accuracy: 0.9466 - val_loss: 0.2535 - val_accuracy: 0.9009
# Epoch 57/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0835 - accuracy: 0.9459 - val_loss: 0.2671 - val_accuracy: 0.9007
# Epoch 58/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0904 - accuracy: 0.9415 - val_loss: 0.2292 - val_accuracy: 0.8994
# Epoch 59/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0892 - accuracy: 0.9423 - val_loss: 0.2745 - val_accuracy: 0.8921
# Epoch 60/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0853 - accuracy: 0.9447 - val_loss: 0.2225 - val_accuracy: 0.9012
# Epoch 61/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0779 - accuracy: 0.9496 - val_loss: 0.2931 - val_accuracy: 0.8918
# Epoch 62/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0755 - accuracy: 0.9505 - val_loss: 0.2759 - val_accuracy: 0.8902
# Epoch 63/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0786 - accuracy: 0.9485 - val_loss: 0.2511 - val_accuracy: 0.9009
# Epoch 64/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.0777 - accuracy: 0.9491 - val_loss: 0.2820 - val_accuracy: 0.9032
# Epoch 65/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0759 - accuracy: 0.9505 - val_loss: 0.2489 - val_accuracy: 0.9019
# Epoch 66/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0716 - accuracy: 0.9532 - val_loss: 0.2633 - val_accuracy: 0.9023
# Epoch 67/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.0665 - accuracy: 0.9565 - val_loss: 0.3183 - val_accuracy: 0.9008
# Epoch 68/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0664 - accuracy: 0.9566 - val_loss: 0.2852 - val_accuracy: 0.9030
# Epoch 69/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0631 - accuracy: 0.9584 - val_loss: 0.2748 - val_accuracy: 0.8994
# Epoch 70/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0656 - accuracy: 0.9569 - val_loss: 0.2948 - val_accuracy: 0.8910
# Epoch 71/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0651 - accuracy: 0.9570 - val_loss: 0.3096 - val_accuracy: 0.8850
# Epoch 72/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0682 - accuracy: 0.9552 - val_loss: 0.2959 - val_accuracy: 0.8876
# Epoch 73/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0717 - accuracy: 0.9527 - val_loss: 0.2783 - val_accuracy: 0.9033
# Epoch 74/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0729 - accuracy: 0.9522 - val_loss: 0.2784 - val_accuracy: 0.9011
# Epoch 75/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0724 - accuracy: 0.9528 - val_loss: 0.2843 - val_accuracy: 0.9043
# Epoch 76/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0716 - accuracy: 0.9533 - val_loss: 0.2571 - val_accuracy: 0.9025
# Epoch 77/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0691 - accuracy: 0.9547 - val_loss: 0.3076 - val_accuracy: 0.8851
# Epoch 78/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.0668 - accuracy: 0.9562 - val_loss: 0.2599 - val_accuracy: 0.8856
# Epoch 79/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0654 - accuracy: 0.9571 - val_loss: 0.2840 - val_accuracy: 0.9054
# Epoch 80/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0618 - accuracy: 0.9594 - val_loss: 0.2749 - val_accuracy: 0.8992
# Epoch 81/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0602 - accuracy: 0.9604 - val_loss: 0.2561 - val_accuracy: 0.8995
# Epoch 82/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0572 - accuracy: 0.9624 - val_loss: 0.2741 - val_accuracy: 0.8984
# Epoch 83/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0559 - accuracy: 0.9633 - val_loss: 0.3083 - val_accuracy: 0.8987
# Epoch 84/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0566 - accuracy: 0.9628 - val_loss: 0.2766 - val_accuracy: 0.9042
# Epoch 85/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0565 - accuracy: 0.9626 - val_loss: 0.2850 - val_accuracy: 0.9038
# Epoch 86/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0574 - accuracy: 0.9622 - val_loss: 0.3137 - val_accuracy: 0.8975
# Epoch 87/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0562 - accuracy: 0.9631 - val_loss: 0.2626 - val_accuracy: 0.8985
# Epoch 88/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0555 - accuracy: 0.9633 - val_loss: 0.2781 - val_accuracy: 0.9033
# Epoch 89/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.0544 - accuracy: 0.9643 - val_loss: 0.2891 - val_accuracy: 0.8970
# Epoch 90/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0536 - accuracy: 0.9646 - val_loss: 0.2745 - val_accuracy: 0.8992
# Epoch 91/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0501 - accuracy: 0.9669 - val_loss: 0.3136 - val_accuracy: 0.8982
# Epoch 92/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0504 - accuracy: 0.9668 - val_loss: 0.2819 - val_accuracy: 0.9020
# Epoch 93/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0476 - accuracy: 0.9687 - val_loss: 0.3080 - val_accuracy: 0.9022
# Epoch 94/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0492 - accuracy: 0.9676 - val_loss: 0.2923 - val_accuracy: 0.9003
# Epoch 95/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0486 - accuracy: 0.9681 - val_loss: 0.2953 - val_accuracy: 0.8968
# Epoch 96/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0500 - accuracy: 0.9671 - val_loss: 0.3094 - val_accuracy: 0.9027
# Epoch 97/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0506 - accuracy: 0.9666 - val_loss: 0.3121 - val_accuracy: 0.9050
# Epoch 98/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0496 - accuracy: 0.9672 - val_loss: 0.3254 - val_accuracy: 0.9053
# Epoch 99/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0498 - accuracy: 0.9672 - val_loss: 0.3217 - val_accuracy: 0.8985
# Epoch 100/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0471 - accuracy: 0.9691 - val_loss: 0.3277 - val_accuracy: 0.8972
# Epoch 101/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0469 - accuracy: 0.9692 - val_loss: 0.3091 - val_accuracy: 0.9036
# Epoch 102/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0449 - accuracy: 0.9706 - val_loss: 0.3217 - val_accuracy: 0.9027
# Epoch 103/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0453 - accuracy: 0.9703 - val_loss: 0.3053 - val_accuracy: 0.9005
# Epoch 104/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0435 - accuracy: 0.9715 - val_loss: 0.3243 - val_accuracy: 0.8997
# Epoch 105/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0451 - accuracy: 0.9705 - val_loss: 0.3148 - val_accuracy: 0.9035
# Epoch 106/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0461 - accuracy: 0.9696 - val_loss: 0.3104 - val_accuracy: 0.9035
# Epoch 107/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0460 - accuracy: 0.9698 - val_loss: 0.3551 - val_accuracy: 0.8990
# Epoch 108/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0464 - accuracy: 0.9694 - val_loss: 0.3882 - val_accuracy: 0.8919
# Epoch 109/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0448 - accuracy: 0.9707 - val_loss: 0.3175 - val_accuracy: 0.9009
# Epoch 110/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0447 - accuracy: 0.9707 - val_loss: 0.3609 - val_accuracy: 0.9075
# Epoch 111/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0449 - accuracy: 0.9708 - val_loss: 0.3232 - val_accuracy: 0.9039
# Epoch 112/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0447 - accuracy: 0.9708 - val_loss: 0.3173 - val_accuracy: 0.9014
# Epoch 113/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0426 - accuracy: 0.9720 - val_loss: 0.3299 - val_accuracy: 0.8916
# Epoch 114/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0429 - accuracy: 0.9720 - val_loss: 0.3301 - val_accuracy: 0.9038
# Epoch 115/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0403 - accuracy: 0.9737 - val_loss: 0.3454 - val_accuracy: 0.9019
# Epoch 116/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0402 - accuracy: 0.9738 - val_loss: 0.3476 - val_accuracy: 0.9026
# Epoch 117/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0387 - accuracy: 0.9747 - val_loss: 0.3590 - val_accuracy: 0.9035
# Epoch 118/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0409 - accuracy: 0.9732 - val_loss: 0.3502 - val_accuracy: 0.9062
# Epoch 119/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0428 - accuracy: 0.9719 - val_loss: 0.3366 - val_accuracy: 0.9011
# Epoch 120/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0438 - accuracy: 0.9712 - val_loss: 0.3213 - val_accuracy: 0.8958
# Epoch 121/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0437 - accuracy: 0.9715 - val_loss: 0.3158 - val_accuracy: 0.8969
# Epoch 122/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0428 - accuracy: 0.9721 - val_loss: 0.3330 - val_accuracy: 0.9001
# Epoch 123/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0418 - accuracy: 0.9726 - val_loss: 0.3306 - val_accuracy: 0.9036
# Epoch 124/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0394 - accuracy: 0.9744 - val_loss: 0.3372 - val_accuracy: 0.8921
# Epoch 125/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0413 - accuracy: 0.9731 - val_loss: 0.3347 - val_accuracy: 0.8953
# Epoch 126/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0393 - accuracy: 0.9744 - val_loss: 0.3448 - val_accuracy: 0.9042
# Epoch 127/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0412 - accuracy: 0.9732 - val_loss: 0.3629 - val_accuracy: 0.9041
# Epoch 128/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0409 - accuracy: 0.9734 - val_loss: 0.3791 - val_accuracy: 0.9034
# Epoch 129/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0415 - accuracy: 0.9731 - val_loss: 0.3553 - val_accuracy: 0.9029
# Epoch 130/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0429 - accuracy: 0.9719 - val_loss: 0.3431 - val_accuracy: 0.8936
# Epoch 131/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0416 - accuracy: 0.9728 - val_loss: 0.3125 - val_accuracy: 0.8999
# Epoch 132/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0414 - accuracy: 0.9732 - val_loss: 0.3120 - val_accuracy: 0.8946
# Epoch 133/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.0434 - accuracy: 0.9720 - val_loss: 0.3001 - val_accuracy: 0.8951
# Epoch 134/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0456 - accuracy: 0.9703 - val_loss: 0.3455 - val_accuracy: 0.8929
# Epoch 135/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0445 - accuracy: 0.9711 - val_loss: 0.3431 - val_accuracy: 0.9002
# Epoch 136/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0438 - accuracy: 0.9716 - val_loss: 0.3783 - val_accuracy: 0.9079
# Epoch 137/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0444 - accuracy: 0.9712 - val_loss: 0.3275 - val_accuracy: 0.9049
# Epoch 138/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0439 - accuracy: 0.9716 - val_loss: 0.2844 - val_accuracy: 0.8988
# Epoch 139/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0405 - accuracy: 0.9739 - val_loss: 0.3214 - val_accuracy: 0.8981
# Epoch 140/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0384 - accuracy: 0.9749 - val_loss: 0.3168 - val_accuracy: 0.8997
# Epoch 141/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0373 - accuracy: 0.9757 - val_loss: 0.3450 - val_accuracy: 0.9033
# Epoch 142/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0340 - accuracy: 0.9779 - val_loss: 0.3692 - val_accuracy: 0.9052
# Epoch 143/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0330 - accuracy: 0.9786 - val_loss: 0.3891 - val_accuracy: 0.9020
# Epoch 144/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0331 - accuracy: 0.9785 - val_loss: 0.4015 - val_accuracy: 0.8968
# Epoch 145/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0347 - accuracy: 0.9774 - val_loss: 0.3956 - val_accuracy: 0.9022
# Epoch 146/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0338 - accuracy: 0.9780 - val_loss: 0.3657 - val_accuracy: 0.9063
# Epoch 147/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0350 - accuracy: 0.9772 - val_loss: 0.3524 - val_accuracy: 0.9003
# Epoch 148/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0328 - accuracy: 0.9788 - val_loss: 0.3882 - val_accuracy: 0.8968
# Epoch 149/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0341 - accuracy: 0.9778 - val_loss: 0.3584 - val_accuracy: 0.9020
# Epoch 150/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0320 - accuracy: 0.9793 - val_loss: 0.3903 - val_accuracy: 0.9017

# %%
# IOU
y_pred = model.predict(x_test)
y_pred_argmax = np.argmax(y_pred, axis=3)
y_test_argmax = np.argmax(y_test, axis=3)

# Using built in keras function for IoU
from tensorflow.keras.metrics import MeanIoU

n_classes = len(np.unique(train_mask_dataset))
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(y_test_argmax, y_pred_argmax)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# 1/1 [==============================] - 13s 13s/step
# Mean IoU = 0.45813075

# %%
test_image_list = glob.glob(TEST_IMAGE_PATH + '/*.JPG')
test_image_list.sort()

test_vein_mask_list = glob.glob(TEST_VEIN_MASK_PATH + '/*.jpg')
test_vein_mask_list.sort()

test_artery_mask_list = glob.glob(TEST_ARTERY_MASK_PATH + '/*.jpg')
test_artery_mask_list.sort()

# %%
import random

test_img_number = random.randint(0, len(x_test))
test_img = x_test[test_img_number]
ground_truth = y_test_argmax[test_img_number]

test_img_input = np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input))
predicted_img = np.argmax(prediction, axis=3)[0,:,:]

print(predicted_img.shape)
print(np.unique(predicted_img))

plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img)
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth)
plt.subplot(233)
plt.title('Prediction on Test Image')
plt.imshow(predicted_img)
plt.show()
# Out:
# 1/1 [==============================] - 0s 23ms/step
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (512, 512)
# [0 1 2]
