# %% [markdown]
# **TRAIN THE VESSEL SEGMENTATION MODEL**

# %%
# !pip install patchify

import os
import glob
import cv2
import numpy as np
import skimage.io
from matplotlib import pyplot as plt
from patchify import patchify, unpatchify
from PIL import Image
import tensorflow as tf
import random
from tensorflow.keras.utils import to_categorical

np.random.seed(0)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.9/dist-packages (from patchify) (1.22.4)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3

# %%
PATH = '/content/drive/MyDrive/AV_split/'
TRAIN_PATH = PATH+'train_vessel/'
TRAIN_IMAGE_PATH = TRAIN_PATH + 'images/'
TRAIN_VESSEL_MASK_PATH = TRAIN_PATH + 'GT_vessel/'

TEST_PATH = PATH+'test/'
TEST_IMAGE_PATH = TEST_PATH + 'images/'
TEST_VESSEL_MASK_PATH = TEST_PATH + 'GT_vessel/'

PATCH_SIZE = 512
SAVE_MODEL = PATH + 'model/'
SAVE_VESSEL_MODEL_NAME = SAVE_MODEL + 'unet-vessel.h5'
SAVE_PREDICTED_VESSEL = PATH + 'predicted_vessel/'

TRAIN_AV_PATH = PATH+'train_av/'
TRAIN_AV_IMAGE_PATH = TRAIN_PATH + 'images/'
TRAIN_AV_VESSEL_MASK_PATH = TRAIN_PATH + 'GT_vessel/'

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def clahe_equalized(image):    
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))    
    image_equalized = clahe.apply(image)

    return image_equalized

def preprocess_image(image, patch_size):
    image = image[70:970, 200:1255]

    image = image[:,:,1]
    image = clahe_equalized(image)

    SIZE_X = (image.shape[1]//patch_size)*patch_size 
    SIZE_Y = (image.shape[0]//patch_size)*patch_size     
    image = cv2.resize(image, (SIZE_X, SIZE_Y))
    
    image = image / 255.
    image = np.array(image)

    return image

# %%
def preprocess_vessel_mask(mask, patch_size):
    thresh = 128
    mask = cv2.threshold(mask, thresh, 255, cv2.THRESH_BINARY)[1]

    mask = mask[70:970, 200:1255]
    
    SIZE_X = (mask.shape[1]//patch_size)*patch_size 
    SIZE_Y = (mask.shape[0]//patch_size)*patch_size     
    mask = cv2.resize(mask, (SIZE_X, SIZE_Y))
  
    mask = 255 - mask
    mask = mask / 255.

    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0

    return mask

# %%
def image_to_patch(image_path, image_type, image_preprocessing, patch_size):
    image_dataset = unpatched_image = []

    if image_type == "IMAGE":
        image = cv2.imread(image_path)
    if image_type == "VESSEL_MASK":
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    image = image_preprocessing(image, patch_size)
    patches_image = patchify(image, (patch_size, patch_size), step=patch_size)
    unpatched_image = unpatchify(patches_image, image.shape)
    
    for i in range(patches_image.shape[0]):
        for j in range(patches_image.shape[1]):
            single_patch = patches_image[i,j,:,:]
            single_patch = (single_patch).astype('float32')
            image_dataset.append(single_patch)

    return image_dataset, unpatched_image

# %%
train_image_list = glob.glob(TRAIN_IMAGE_PATH + '/*.JPG')
train_image_list.sort()

train_vessel_mask_list = glob.glob(TRAIN_VESSEL_MASK_PATH + '/*.jpg')
train_vessel_mask_list.sort()

# %%
image_path = train_image_list[10]

original_image = cv2.imread(image_path)
patched_image_list, unpatched_image = image_to_patch(image_path, "IMAGE", preprocess_image, PATCH_SIZE)
patched_image = np.array(patched_image_list)

print(patched_image.min(), patched_image.max())
print(patched_image.shape)

plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.title(image_path)
plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))
plt.subplot(122)
plt.imshow(unpatched_image, cmap='gray')

plt.show()

rows = 1
columns = patched_image.shape[0]

fig = plt.figure(figsize=(5, 5))
for i in range(1, (rows * columns + 1)):
    fig.add_subplot(rows, columns, i)
    img = patched_image[i-1]
    plt.imshow(img,cmap='gray')

plt.show()
# Out:
# 0.007843138 0.9843137
# (2, 512, 512)

# %%
vessel_mask_path = train_vessel_mask_list[10]
original_vessel_mask = cv2.imread(vessel_mask_path, cv2.IMREAD_GRAYSCALE)

patched_mask_list, unpatcified_mask = image_to_patch(vessel_mask_path, "VESSEL_MASK", preprocess_vessel_mask, PATCH_SIZE)
patched_mask = np.array(patched_mask_list)

plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.title(vessel_mask_path)
plt.imshow(cv2.cvtColor(original_vessel_mask, cv2.COLOR_BGR2RGB))
plt.subplot(122)
plt.imshow(unpatcified_mask, cmap='gray')

plt.show()

print(patched_mask.min(), patched_mask.max())
print(patched_mask.shape)
print(np.unique(patched_mask))

rows = 1
columns = patched_image.shape[0]

fig = plt.figure(figsize=(5, 5))
for i in range(1, (rows * columns + 1)):
    fig.add_subplot(rows, columns, i)
    img = patched_mask[i-1]
    plt.imshow(img,cmap='gray')

plt.show()
# Out:
# 0.0 1.0
# (2, 512, 512)
# [0. 1.]

# %%
train_image_dataset = []
train_vessel_mask_dataset = []

for image_path in train_image_list:
    patched_image, unpatched_image = image_to_patch(image_path, "IMAGE", preprocess_image, PATCH_SIZE)
    train_image_dataset += patched_image

for vessel_mask_path in train_vessel_mask_list:
    patched_mask, unpatched_mask = image_to_patch(vessel_mask_path, "VESSEL_MASK", preprocess_vessel_mask, PATCH_SIZE)
    train_vessel_mask_dataset += patched_mask

train_image_dataset = np.array(train_image_dataset)
train_image_dataset = np.expand_dims(train_image_dataset, axis=-1)
train_vessel_mask_dataset = np.array(train_vessel_mask_dataset)
train_vessel_mask_dataset = np.expand_dims(train_vessel_mask_dataset, axis=-1)

print(train_image_dataset.shape)
print(train_vessel_mask_dataset.shape)
print(train_image_dataset.max(), train_vessel_mask_dataset.max())
print(train_image_dataset.min(), train_vessel_mask_dataset.min())
# Out:
# (80, 512, 512, 1)
# (80, 512, 512, 1)
# 1.0 1.0
# 0.003921569 0.0

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train_image_dataset, train_vessel_mask_dataset, test_size=0.2, random_state=0)

# %%
fig = plt.figure(figsize=(5, 5))
for i in range(1, 4):
    plt.figure(figsize=(12, 6))

    plt.subplot(121)
    plt.imshow(x_train[i-1])

    plt.subplot(122)
    plt.imshow(y_train[i-1])
    
    plt.show()
plt.show()

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (64, 512, 512, 1) (64, 512, 512, 1)
# (16, 512, 512, 1) (16, 512, 512, 1)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K

def IoU_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

def IoU_loss(y_true, y_pred):
    return -IoU_coef(y_true, y_pred)

# %%
import tensorflow as tf
from keras.models import Model, load_model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.optimizers import Adam
from keras.layers import Activation, MaxPool2D, Concatenate

def unet(pretrained_weights = None,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    drop4 = Dropout(0.5)(conv4, training=True)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    conv5 = BatchNormalization()(conv5)
    drop5 = Dropout(0.5)(conv5, training=True)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)

    model = tf.keras.Model(inputs = inputs, outputs = conv10)

    model.compile(optimizer = Adam(lr = 1e-4), loss = IoU_loss, metrics = ['accuracy', IoU_coef])
    

    if(pretrained_weights):
    	  model = keras.models.load_model(pretrained_weights)

    return model

# %%
model = unet(input_size=(PATCH_SIZE, PATCH_SIZE, 1))
history = model.fit(x_train, y_train, 
                    verbose = 1,
                    batch_size = 3,
                    validation_data = (x_test, y_test), 
                    shuffle = False,
                    epochs = 150,
                    steps_per_epoch = 10)
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# Epoch 1/150
# 10/10 [==============================] - 49s 2s/step - loss: -0.1485 - accuracy: 0.8854 - IoU_coef: 0.1485 - val_loss: -0.1030 - val_accuracy: 0.8710 - val_IoU_coef: 0.0964
# Epoch 2/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.2542 - accuracy: 0.9094 - IoU_coef: 0.2542 - val_loss: -0.1174 - val_accuracy: 0.8837 - val_IoU_coef: 0.1100
# Epoch 3/150
# 10/10 [==============================] - 18s 2s/step - loss: -0.2714 - accuracy: 0.9114 - IoU_coef: 0.2706 - val_loss: -0.0625 - val_accuracy: 0.8809 - val_IoU_coef: 0.0592
# Epoch 4/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.2980 - accuracy: 0.9173 - IoU_coef: 0.2980 - val_loss: -0.0338 - val_accuracy: 0.8802 - val_IoU_coef: 0.0324
# Epoch 5/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2818 - accuracy: 0.9155 - IoU_coef: 0.2817 - val_loss: -0.0063 - val_accuracy: 0.8817 - val_IoU_coef: 0.0062
# Epoch 6/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3060 - accuracy: 0.9197 - IoU_coef: 0.3060 - val_loss: -0.0086 - val_accuracy: 0.8797 - val_IoU_coef: 0.0083
# Epoch 7/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2951 - accuracy: 0.9184 - IoU_coef: 0.2951 - val_loss: -0.0018 - val_accuracy: 0.8813 - val_IoU_coef: 0.0018
# Epoch 8/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3062 - accuracy: 0.9214 - IoU_coef: 0.3062 - val_loss: -0.0040 - val_accuracy: 0.8800 - val_IoU_coef: 0.0038
# Epoch 9/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.3096 - accuracy: 0.9213 - IoU_coef: 0.3098 - val_loss: -7.2305e-04 - val_accuracy: 0.8819 - val_IoU_coef: 7.3359e-04
# Epoch 10/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3062 - accuracy: 0.9198 - IoU_coef: 0.3062 - val_loss: -0.0015 - val_accuracy: 0.8819 - val_IoU_coef: 0.0015
# Epoch 11/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3198 - accuracy: 0.9240 - IoU_coef: 0.3197 - val_loss: -0.0011 - val_accuracy: 0.8820 - val_IoU_coef: 9.7853e-04
# Epoch 12/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3110 - accuracy: 0.9224 - IoU_coef: 0.3110 - val_loss: -0.0065 - val_accuracy: 0.8814 - val_IoU_coef: 0.0059
# Epoch 13/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3263 - accuracy: 0.9272 - IoU_coef: 0.3263 - val_loss: -0.0121 - val_accuracy: 0.8818 - val_IoU_coef: 0.0108
# Epoch 14/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3173 - accuracy: 0.9250 - IoU_coef: 0.3183 - val_loss: -0.0287 - val_accuracy: 0.8842 - val_IoU_coef: 0.0256
# Epoch 15/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3331 - accuracy: 0.9291 - IoU_coef: 0.3331 - val_loss: -0.0444 - val_accuracy: 0.8853 - val_IoU_coef: 0.0404
# Epoch 16/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3182 - accuracy: 0.9280 - IoU_coef: 0.3197 - val_loss: -0.1231 - val_accuracy: 0.8974 - val_IoU_coef: 0.1157
# Epoch 17/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3357 - accuracy: 0.9291 - IoU_coef: 0.3357 - val_loss: -0.1126 - val_accuracy: 0.8931 - val_IoU_coef: 0.1072
# Epoch 18/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.3275 - accuracy: 0.9306 - IoU_coef: 0.3287 - val_loss: -0.0698 - val_accuracy: 0.8912 - val_IoU_coef: 0.0634
# Epoch 19/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3340 - accuracy: 0.9311 - IoU_coef: 0.3340 - val_loss: -0.1321 - val_accuracy: 0.8963 - val_IoU_coef: 0.1257
# Epoch 20/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.3354 - accuracy: 0.9299 - IoU_coef: 0.3362 - val_loss: -0.0723 - val_accuracy: 0.8914 - val_IoU_coef: 0.0659
# Epoch 21/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3295 - accuracy: 0.9295 - IoU_coef: 0.3295 - val_loss: -0.1366 - val_accuracy: 0.9027 - val_IoU_coef: 0.1304
# Epoch 22/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.3430 - accuracy: 0.9318 - IoU_coef: 0.3441 - val_loss: -0.1418 - val_accuracy: 0.9017 - val_IoU_coef: 0.1344
# Epoch 23/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3327 - accuracy: 0.9313 - IoU_coef: 0.3327 - val_loss: -0.1241 - val_accuracy: 0.9011 - val_IoU_coef: 0.1154
# Epoch 24/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3471 - accuracy: 0.9343 - IoU_coef: 0.3471 - val_loss: -0.1405 - val_accuracy: 0.9000 - val_IoU_coef: 0.1340
# Epoch 25/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.3388 - accuracy: 0.9342 - IoU_coef: 0.3405 - val_loss: -0.1274 - val_accuracy: 0.8971 - val_IoU_coef: 0.1183
# Epoch 26/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3509 - accuracy: 0.9346 - IoU_coef: 0.3509 - val_loss: -0.2138 - val_accuracy: 0.9044 - val_IoU_coef: 0.2045
# Epoch 27/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3410 - accuracy: 0.9368 - IoU_coef: 0.3428 - val_loss: -0.1888 - val_accuracy: 0.9044 - val_IoU_coef: 0.1794
# Epoch 28/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3533 - accuracy: 0.9364 - IoU_coef: 0.3533 - val_loss: -0.1984 - val_accuracy: 0.9060 - val_IoU_coef: 0.1883
# Epoch 29/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.3473 - accuracy: 0.9356 - IoU_coef: 0.3488 - val_loss: -0.1954 - val_accuracy: 0.9035 - val_IoU_coef: 0.1856
# Epoch 30/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3538 - accuracy: 0.9385 - IoU_coef: 0.3538 - val_loss: -0.1763 - val_accuracy: 0.9081 - val_IoU_coef: 0.1681
# Epoch 31/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3499 - accuracy: 0.9363 - IoU_coef: 0.3514 - val_loss: -0.2175 - val_accuracy: 0.9135 - val_IoU_coef: 0.2090
# Epoch 32/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3483 - accuracy: 0.9352 - IoU_coef: 0.3483 - val_loss: -0.1773 - val_accuracy: 0.9107 - val_IoU_coef: 0.1672
# Epoch 33/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.3571 - accuracy: 0.9369 - IoU_coef: 0.3581 - val_loss: -0.2202 - val_accuracy: 0.9152 - val_IoU_coef: 0.2126
# Epoch 34/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3476 - accuracy: 0.9365 - IoU_coef: 0.3476 - val_loss: -0.1991 - val_accuracy: 0.9096 - val_IoU_coef: 0.1904
# Epoch 35/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3614 - accuracy: 0.9413 - IoU_coef: 0.3614 - val_loss: -0.2493 - val_accuracy: 0.9153 - val_IoU_coef: 0.2404
# Epoch 36/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3524 - accuracy: 0.9389 - IoU_coef: 0.3544 - val_loss: -0.2612 - val_accuracy: 0.9046 - val_IoU_coef: 0.2511
# Epoch 37/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3611 - accuracy: 0.9399 - IoU_coef: 0.3611 - val_loss: -0.2665 - val_accuracy: 0.9100 - val_IoU_coef: 0.2553
# Epoch 38/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.3502 - accuracy: 0.9400 - IoU_coef: 0.3519 - val_loss: -0.2590 - val_accuracy: 0.9165 - val_IoU_coef: 0.2497
# Epoch 39/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3597 - accuracy: 0.9364 - IoU_coef: 0.3597 - val_loss: -0.2447 - val_accuracy: 0.9182 - val_IoU_coef: 0.2356
# Epoch 40/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3513 - accuracy: 0.9359 - IoU_coef: 0.3525 - val_loss: -0.2443 - val_accuracy: 0.9208 - val_IoU_coef: 0.2358
# Epoch 41/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3555 - accuracy: 0.9372 - IoU_coef: 0.3555 - val_loss: -0.2584 - val_accuracy: 0.9212 - val_IoU_coef: 0.2490
# Epoch 42/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.3541 - accuracy: 0.9362 - IoU_coef: 0.3557 - val_loss: -0.2728 - val_accuracy: 0.9105 - val_IoU_coef: 0.2624
# Epoch 43/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3519 - accuracy: 0.9390 - IoU_coef: 0.3519 - val_loss: -0.2712 - val_accuracy: 0.9163 - val_IoU_coef: 0.2622
# Epoch 44/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3660 - accuracy: 0.9399 - IoU_coef: 0.3674 - val_loss: -0.2819 - val_accuracy: 0.9231 - val_IoU_coef: 0.2716
# Epoch 45/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3644 - accuracy: 0.9425 - IoU_coef: 0.3644 - val_loss: -0.2738 - val_accuracy: 0.9210 - val_IoU_coef: 0.2623
# Epoch 46/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3745 - accuracy: 0.9454 - IoU_coef: 0.3745 - val_loss: -0.2921 - val_accuracy: 0.9293 - val_IoU_coef: 0.2829
# Epoch 47/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3728 - accuracy: 0.9464 - IoU_coef: 0.3742 - val_loss: -0.2835 - val_accuracy: 0.9227 - val_IoU_coef: 0.2732
# Epoch 48/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3785 - accuracy: 0.9458 - IoU_coef: 0.3785 - val_loss: -0.2854 - val_accuracy: 0.9300 - val_IoU_coef: 0.2772
# Epoch 49/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3729 - accuracy: 0.9475 - IoU_coef: 0.3745 - val_loss: -0.2806 - val_accuracy: 0.9303 - val_IoU_coef: 0.2726
# Epoch 50/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3809 - accuracy: 0.9453 - IoU_coef: 0.3809 - val_loss: -0.2780 - val_accuracy: 0.9309 - val_IoU_coef: 0.2711
# Epoch 51/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3779 - accuracy: 0.9480 - IoU_coef: 0.3795 - val_loss: -0.2953 - val_accuracy: 0.9302 - val_IoU_coef: 0.2881
# Epoch 52/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3834 - accuracy: 0.9499 - IoU_coef: 0.3834 - val_loss: -0.2945 - val_accuracy: 0.9236 - val_IoU_coef: 0.2847
# Epoch 53/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.3840 - accuracy: 0.9491 - IoU_coef: 0.3854 - val_loss: -0.3112 - val_accuracy: 0.9261 - val_IoU_coef: 0.3015
# Epoch 54/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3814 - accuracy: 0.9493 - IoU_coef: 0.3814 - val_loss: -0.3001 - val_accuracy: 0.9243 - val_IoU_coef: 0.2900
# Epoch 55/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.3860 - accuracy: 0.9490 - IoU_coef: 0.3875 - val_loss: -0.3048 - val_accuracy: 0.9309 - val_IoU_coef: 0.2954
# Epoch 56/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3829 - accuracy: 0.9497 - IoU_coef: 0.3829 - val_loss: -0.2992 - val_accuracy: 0.9317 - val_IoU_coef: 0.2904
# Epoch 57/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3862 - accuracy: 0.9480 - IoU_coef: 0.3862 - val_loss: -0.2981 - val_accuracy: 0.9309 - val_IoU_coef: 0.2900
# Epoch 58/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3784 - accuracy: 0.9466 - IoU_coef: 0.3802 - val_loss: -0.3098 - val_accuracy: 0.9316 - val_IoU_coef: 0.3015
# Epoch 59/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3839 - accuracy: 0.9476 - IoU_coef: 0.3839 - val_loss: -0.3072 - val_accuracy: 0.9294 - val_IoU_coef: 0.2982
# Epoch 60/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3761 - accuracy: 0.9491 - IoU_coef: 0.3785 - val_loss: -0.3047 - val_accuracy: 0.9274 - val_IoU_coef: 0.2968
# Epoch 61/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3832 - accuracy: 0.9444 - IoU_coef: 0.3832 - val_loss: -0.2989 - val_accuracy: 0.9334 - val_IoU_coef: 0.2901
# Epoch 62/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.3812 - accuracy: 0.9474 - IoU_coef: 0.3829 - val_loss: -0.3000 - val_accuracy: 0.9340 - val_IoU_coef: 0.2920
# Epoch 63/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3849 - accuracy: 0.9489 - IoU_coef: 0.3849 - val_loss: -0.3098 - val_accuracy: 0.9321 - val_IoU_coef: 0.3015
# Epoch 64/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.3869 - accuracy: 0.9495 - IoU_coef: 0.3884 - val_loss: -0.3221 - val_accuracy: 0.9310 - val_IoU_coef: 0.3129
# Epoch 65/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3834 - accuracy: 0.9498 - IoU_coef: 0.3834 - val_loss: -0.3203 - val_accuracy: 0.9285 - val_IoU_coef: 0.3109
# Epoch 66/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.3880 - accuracy: 0.9470 - IoU_coef: 0.3891 - val_loss: -0.3079 - val_accuracy: 0.9318 - val_IoU_coef: 0.2999
# Epoch 67/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3835 - accuracy: 0.9477 - IoU_coef: 0.3835 - val_loss: -0.3090 - val_accuracy: 0.9327 - val_IoU_coef: 0.3009
# Epoch 68/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3904 - accuracy: 0.9497 - IoU_coef: 0.3904 - val_loss: -0.3149 - val_accuracy: 0.9345 - val_IoU_coef: 0.3068
# Epoch 69/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.3879 - accuracy: 0.9510 - IoU_coef: 0.3898 - val_loss: -0.3166 - val_accuracy: 0.9308 - val_IoU_coef: 0.3065
# Epoch 70/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.3942 - accuracy: 0.9502 - IoU_coef: 0.3942 - val_loss: -0.3136 - val_accuracy: 0.9324 - val_IoU_coef: 0.3044
# Epoch 71/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3939 - accuracy: 0.9553 - IoU_coef: 0.3957 - val_loss: -0.3213 - val_accuracy: 0.9308 - val_IoU_coef: 0.3122
# Epoch 72/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4004 - accuracy: 0.9530 - IoU_coef: 0.4004 - val_loss: -0.3156 - val_accuracy: 0.9289 - val_IoU_coef: 0.3067
# Epoch 73/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4000 - accuracy: 0.9557 - IoU_coef: 0.4018 - val_loss: -0.3166 - val_accuracy: 0.9349 - val_IoU_coef: 0.3079
# Epoch 74/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4052 - accuracy: 0.9574 - IoU_coef: 0.4052 - val_loss: -0.3132 - val_accuracy: 0.9338 - val_IoU_coef: 0.3051
# Epoch 75/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.4035 - accuracy: 0.9550 - IoU_coef: 0.4052 - val_loss: -0.3020 - val_accuracy: 0.9341 - val_IoU_coef: 0.2948
# Epoch 76/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4012 - accuracy: 0.9553 - IoU_coef: 0.4012 - val_loss: -0.3118 - val_accuracy: 0.9345 - val_IoU_coef: 0.3039
# Epoch 77/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.4055 - accuracy: 0.9562 - IoU_coef: 0.4065 - val_loss: -0.3145 - val_accuracy: 0.9323 - val_IoU_coef: 0.3056
# Epoch 78/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4017 - accuracy: 0.9560 - IoU_coef: 0.4017 - val_loss: -0.3178 - val_accuracy: 0.9310 - val_IoU_coef: 0.3086
# Epoch 79/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4018 - accuracy: 0.9546 - IoU_coef: 0.4018 - val_loss: -0.3128 - val_accuracy: 0.9289 - val_IoU_coef: 0.3034
# Epoch 80/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3952 - accuracy: 0.9521 - IoU_coef: 0.3972 - val_loss: -0.3170 - val_accuracy: 0.9285 - val_IoU_coef: 0.3072
# Epoch 81/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4034 - accuracy: 0.9540 - IoU_coef: 0.4034 - val_loss: -0.3176 - val_accuracy: 0.9318 - val_IoU_coef: 0.3091
# Epoch 82/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3995 - accuracy: 0.9566 - IoU_coef: 0.4010 - val_loss: -0.3213 - val_accuracy: 0.9300 - val_IoU_coef: 0.3129
# Epoch 83/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4087 - accuracy: 0.9548 - IoU_coef: 0.4087 - val_loss: -0.3139 - val_accuracy: 0.9336 - val_IoU_coef: 0.3059
# Epoch 84/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4064 - accuracy: 0.9578 - IoU_coef: 0.4082 - val_loss: -0.3113 - val_accuracy: 0.9337 - val_IoU_coef: 0.3037
# Epoch 85/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4132 - accuracy: 0.9593 - IoU_coef: 0.4132 - val_loss: -0.3186 - val_accuracy: 0.9340 - val_IoU_coef: 0.3093
# Epoch 86/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.4108 - accuracy: 0.9575 - IoU_coef: 0.4124 - val_loss: -0.3112 - val_accuracy: 0.9324 - val_IoU_coef: 0.3021
# Epoch 87/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4080 - accuracy: 0.9575 - IoU_coef: 0.4080 - val_loss: -0.3253 - val_accuracy: 0.9297 - val_IoU_coef: 0.3153
# Epoch 88/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.4098 - accuracy: 0.9573 - IoU_coef: 0.4108 - val_loss: -0.3165 - val_accuracy: 0.9257 - val_IoU_coef: 0.3071
# Epoch 89/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4024 - accuracy: 0.9557 - IoU_coef: 0.4024 - val_loss: -0.3172 - val_accuracy: 0.9271 - val_IoU_coef: 0.3084
# Epoch 90/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4033 - accuracy: 0.9536 - IoU_coef: 0.4033 - val_loss: -0.3154 - val_accuracy: 0.9332 - val_IoU_coef: 0.3073
# Epoch 91/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.4003 - accuracy: 0.9520 - IoU_coef: 0.4025 - val_loss: -0.3111 - val_accuracy: 0.9339 - val_IoU_coef: 0.3024
# Epoch 92/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4072 - accuracy: 0.9539 - IoU_coef: 0.4072 - val_loss: -0.3216 - val_accuracy: 0.9319 - val_IoU_coef: 0.3119
# Epoch 93/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.4082 - accuracy: 0.9593 - IoU_coef: 0.4101 - val_loss: -0.3225 - val_accuracy: 0.9301 - val_IoU_coef: 0.3129
# Epoch 94/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4169 - accuracy: 0.9587 - IoU_coef: 0.4169 - val_loss: -0.3272 - val_accuracy: 0.9277 - val_IoU_coef: 0.3172
# Epoch 95/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.4145 - accuracy: 0.9596 - IoU_coef: 0.4161 - val_loss: -0.3278 - val_accuracy: 0.9313 - val_IoU_coef: 0.3173
# Epoch 96/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4215 - accuracy: 0.9626 - IoU_coef: 0.4215 - val_loss: -0.3181 - val_accuracy: 0.9302 - val_IoU_coef: 0.3094
# Epoch 97/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4152 - accuracy: 0.9578 - IoU_coef: 0.4169 - val_loss: -0.3062 - val_accuracy: 0.9321 - val_IoU_coef: 0.2982
# Epoch 98/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4133 - accuracy: 0.9585 - IoU_coef: 0.4133 - val_loss: -0.3219 - val_accuracy: 0.9333 - val_IoU_coef: 0.3131
# Epoch 99/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4185 - accuracy: 0.9591 - IoU_coef: 0.4195 - val_loss: -0.3185 - val_accuracy: 0.9315 - val_IoU_coef: 0.3093
# Epoch 100/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4141 - accuracy: 0.9595 - IoU_coef: 0.4141 - val_loss: -0.3182 - val_accuracy: 0.9267 - val_IoU_coef: 0.3077
# Epoch 101/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4146 - accuracy: 0.9577 - IoU_coef: 0.4146 - val_loss: -0.3232 - val_accuracy: 0.9320 - val_IoU_coef: 0.3135
# Epoch 102/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4129 - accuracy: 0.9586 - IoU_coef: 0.4147 - val_loss: -0.3225 - val_accuracy: 0.9289 - val_IoU_coef: 0.3137
# Epoch 103/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4200 - accuracy: 0.9590 - IoU_coef: 0.4200 - val_loss: -0.3145 - val_accuracy: 0.9304 - val_IoU_coef: 0.3058
# Epoch 104/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4133 - accuracy: 0.9595 - IoU_coef: 0.4151 - val_loss: -0.3221 - val_accuracy: 0.9354 - val_IoU_coef: 0.3135
# Epoch 105/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4232 - accuracy: 0.9594 - IoU_coef: 0.4232 - val_loss: -0.3193 - val_accuracy: 0.9332 - val_IoU_coef: 0.3101
# Epoch 106/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4167 - accuracy: 0.9593 - IoU_coef: 0.4184 - val_loss: -0.3213 - val_accuracy: 0.9323 - val_IoU_coef: 0.3117
# Epoch 107/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4225 - accuracy: 0.9622 - IoU_coef: 0.4225 - val_loss: -0.3272 - val_accuracy: 0.9288 - val_IoU_coef: 0.3174
# Epoch 108/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4237 - accuracy: 0.9605 - IoU_coef: 0.4253 - val_loss: -0.3127 - val_accuracy: 0.9288 - val_IoU_coef: 0.3039
# Epoch 109/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4193 - accuracy: 0.9600 - IoU_coef: 0.4193 - val_loss: -0.3230 - val_accuracy: 0.9325 - val_IoU_coef: 0.3141
# Epoch 110/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.4226 - accuracy: 0.9590 - IoU_coef: 0.4237 - val_loss: -0.3060 - val_accuracy: 0.9307 - val_IoU_coef: 0.2969
# Epoch 111/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4240 - accuracy: 0.9626 - IoU_coef: 0.4240 - val_loss: -0.3248 - val_accuracy: 0.9318 - val_IoU_coef: 0.3152
# Epoch 112/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4242 - accuracy: 0.9606 - IoU_coef: 0.4242 - val_loss: -0.3246 - val_accuracy: 0.9299 - val_IoU_coef: 0.3143
# Epoch 113/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4204 - accuracy: 0.9611 - IoU_coef: 0.4222 - val_loss: -0.3289 - val_accuracy: 0.9282 - val_IoU_coef: 0.3194
# Epoch 114/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4250 - accuracy: 0.9610 - IoU_coef: 0.4250 - val_loss: -0.3254 - val_accuracy: 0.9289 - val_IoU_coef: 0.3167
# Epoch 115/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4161 - accuracy: 0.9600 - IoU_coef: 0.4179 - val_loss: -0.3116 - val_accuracy: 0.9342 - val_IoU_coef: 0.3032
# Epoch 116/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4281 - accuracy: 0.9601 - IoU_coef: 0.4281 - val_loss: -0.3166 - val_accuracy: 0.9345 - val_IoU_coef: 0.3077
# Epoch 117/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4221 - accuracy: 0.9605 - IoU_coef: 0.4238 - val_loss: -0.3090 - val_accuracy: 0.9296 - val_IoU_coef: 0.3001
# Epoch 118/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4276 - accuracy: 0.9636 - IoU_coef: 0.4276 - val_loss: -0.3247 - val_accuracy: 0.9273 - val_IoU_coef: 0.3148
# Epoch 119/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.4225 - accuracy: 0.9597 - IoU_coef: 0.4245 - val_loss: -0.3176 - val_accuracy: 0.9220 - val_IoU_coef: 0.3073
# Epoch 120/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4223 - accuracy: 0.9608 - IoU_coef: 0.4223 - val_loss: -0.3277 - val_accuracy: 0.9275 - val_IoU_coef: 0.3176
# Epoch 121/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4238 - accuracy: 0.9588 - IoU_coef: 0.4253 - val_loss: -0.3216 - val_accuracy: 0.9327 - val_IoU_coef: 0.3122
# Epoch 122/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4217 - accuracy: 0.9606 - IoU_coef: 0.4217 - val_loss: -0.3141 - val_accuracy: 0.9262 - val_IoU_coef: 0.3044
# Epoch 123/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4213 - accuracy: 0.9575 - IoU_coef: 0.4213 - val_loss: -0.3236 - val_accuracy: 0.9332 - val_IoU_coef: 0.3142
# Epoch 124/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4215 - accuracy: 0.9595 - IoU_coef: 0.4228 - val_loss: -0.3127 - val_accuracy: 0.9319 - val_IoU_coef: 0.3038
# Epoch 125/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4216 - accuracy: 0.9580 - IoU_coef: 0.4216 - val_loss: -0.3327 - val_accuracy: 0.9255 - val_IoU_coef: 0.3210
# Epoch 126/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4167 - accuracy: 0.9600 - IoU_coef: 0.4191 - val_loss: -0.3212 - val_accuracy: 0.9321 - val_IoU_coef: 0.3117
# Epoch 127/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4266 - accuracy: 0.9594 - IoU_coef: 0.4266 - val_loss: -0.3236 - val_accuracy: 0.9251 - val_IoU_coef: 0.3135
# Epoch 128/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.4214 - accuracy: 0.9585 - IoU_coef: 0.4234 - val_loss: -0.3139 - val_accuracy: 0.9339 - val_IoU_coef: 0.3051
# Epoch 129/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4295 - accuracy: 0.9620 - IoU_coef: 0.4295 - val_loss: -0.3189 - val_accuracy: 0.9310 - val_IoU_coef: 0.3110
# Epoch 130/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4255 - accuracy: 0.9599 - IoU_coef: 0.4272 - val_loss: -0.3248 - val_accuracy: 0.9331 - val_IoU_coef: 0.3158
# Epoch 131/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4266 - accuracy: 0.9619 - IoU_coef: 0.4266 - val_loss: -0.3314 - val_accuracy: 0.9300 - val_IoU_coef: 0.3219
# Epoch 132/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.4311 - accuracy: 0.9611 - IoU_coef: 0.4328 - val_loss: -0.3318 - val_accuracy: 0.9252 - val_IoU_coef: 0.3218
# Epoch 133/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4310 - accuracy: 0.9637 - IoU_coef: 0.4310 - val_loss: -0.3273 - val_accuracy: 0.9328 - val_IoU_coef: 0.3175
# Epoch 134/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4336 - accuracy: 0.9618 - IoU_coef: 0.4336 - val_loss: -0.3240 - val_accuracy: 0.9298 - val_IoU_coef: 0.3146
# Epoch 135/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4344 - accuracy: 0.9639 - IoU_coef: 0.4360 - val_loss: -0.3071 - val_accuracy: 0.9327 - val_IoU_coef: 0.2993
# Epoch 136/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4356 - accuracy: 0.9628 - IoU_coef: 0.4356 - val_loss: -0.3202 - val_accuracy: 0.9275 - val_IoU_coef: 0.3099
# Epoch 137/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.4303 - accuracy: 0.9633 - IoU_coef: 0.4321 - val_loss: -0.3179 - val_accuracy: 0.9297 - val_IoU_coef: 0.3082
# Epoch 138/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4375 - accuracy: 0.9638 - IoU_coef: 0.4375 - val_loss: -0.3245 - val_accuracy: 0.9287 - val_IoU_coef: 0.3150
# Epoch 139/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4323 - accuracy: 0.9625 - IoU_coef: 0.4342 - val_loss: -0.3255 - val_accuracy: 0.9323 - val_IoU_coef: 0.3156
# Epoch 140/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4344 - accuracy: 0.9642 - IoU_coef: 0.4344 - val_loss: -0.3277 - val_accuracy: 0.9331 - val_IoU_coef: 0.3187
# Epoch 141/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4305 - accuracy: 0.9602 - IoU_coef: 0.4321 - val_loss: -0.3230 - val_accuracy: 0.9306 - val_IoU_coef: 0.3134
# Epoch 142/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4281 - accuracy: 0.9606 - IoU_coef: 0.4281 - val_loss: -0.3123 - val_accuracy: 0.9301 - val_IoU_coef: 0.3032
# Epoch 143/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4294 - accuracy: 0.9599 - IoU_coef: 0.4313 - val_loss: -0.3157 - val_accuracy: 0.9277 - val_IoU_coef: 0.3057
# Epoch 144/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4240 - accuracy: 0.9585 - IoU_coef: 0.4240 - val_loss: -0.3154 - val_accuracy: 0.9296 - val_IoU_coef: 0.3056
# Epoch 145/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4211 - accuracy: 0.9566 - IoU_coef: 0.4211 - val_loss: -0.3305 - val_accuracy: 0.9303 - val_IoU_coef: 0.3201
# Epoch 146/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4192 - accuracy: 0.9575 - IoU_coef: 0.4219 - val_loss: -0.3343 - val_accuracy: 0.9277 - val_IoU_coef: 0.3232
# Epoch 147/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4279 - accuracy: 0.9591 - IoU_coef: 0.4279 - val_loss: -0.3321 - val_accuracy: 0.9262 - val_IoU_coef: 0.3213
# Epoch 148/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4209 - accuracy: 0.9588 - IoU_coef: 0.4232 - val_loss: -0.3256 - val_accuracy: 0.9318 - val_IoU_coef: 0.3157
# Epoch 149/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.4346 - accuracy: 0.9602 - IoU_coef: 0.4346 - val_loss: -0.3180 - val_accuracy: 0.9303 - val_IoU_coef: 0.3101
# Epoch 150/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4305 - accuracy: 0.9613 - IoU_coef: 0.4325 - val_loss: -0.3215 - val_accuracy: 0.9320 - val_IoU_coef: 0.3116

# %%
test_image_list = glob.glob(TEST_IMAGE_PATH + '/*.JPG')
test_image_list.sort()

test_vessel_mask_list = glob.glob(TEST_VESSEL_MASK_PATH + '/*.jpg')
test_vessel_mask_list.sort()

# %%
from datetime import datetime 

test_image_number = random.randint(0, len(test_image_list)-1)

reconstructed_image = []
test_img = cv2.imread(test_image_list[test_image_number])
gt = cv2.imread(test_vessel_mask_list[test_image_number])

predicted_patches = []
start = datetime.now()   

test = preprocess_image(test_img, PATCH_SIZE)
patches = patchify(test, (PATCH_SIZE, PATCH_SIZE), step=PATCH_SIZE) 

for i in range(patches.shape[0]):
      for j in range(patches.shape[1]):
          single_patch = patches[i,j,:,:]
          single_patch_norm = (single_patch.astype('float32')) 
          single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
          single_patch_input = np.expand_dims(single_patch_norm, 0)
          single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8)
          predicted_patches.append(single_patch_prediction)
          
predicted_patches = np.array(predicted_patches)
predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], PATCH_SIZE, PATCH_SIZE))

reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape) 
reconstructed_image = cv2.resize(reconstructed_image, (512, 512))

stop = datetime.now()
print('Execution time: ',(stop-start)) #computation time

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title(test_image_list[test_image_number])
plt.imshow(cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB))
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(gt, cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(reconstructed_image, cmap='gray')
plt.show()
# Out:
# 1/1 [==============================] - 1s 560ms/step
# 1/1 [==============================] - 0s 32ms/step
# Execution time:  0:00:01.290053

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
if not os.path.exists(SAVE_MODEL):
      os.makedirs(SAVE_MODEL)

model.save(SAVE_VESSEL_MODEL_NAME)

# %% [markdown]
# **GENERATE THE VESSEL SEGMENTATION FOR ARTERY VEIN DATASET**

# %%
train_av_image_paths = glob.glob(TRAIN_AV_IMAGE_PATH + "/*.JPG")
train_av_image_paths.sort()

train_av_vessel_paths = glob.glob(TRAIN_AV_VESSEL_MASK_PATH + "/*.jpg")
train_av_vessel_paths.sort()

predicted_vessel_dataset = []
gt_vessel_dataset = []

# %%
from pathlib import Path    

if not os.path.exists(SAVE_PREDICTED_VESSEL):
      os.makedirs(SAVE_PREDICTED_VESSEL)

for image_path, vessel_path in zip(train_av_image_paths, train_av_vessel_paths):
      image_patch_list, _ = image_to_patch(image_path, "IMAGE", preprocess_image, PATCH_SIZE)
      gt_vessel = cv2.imread(vessel_path)
      gt_vessel = preprocess_vessel_mask(gt_vessel, PATCH_SIZE)

      predicted_patches = []

      for patch in image_patch_list:
          patch = np.array(patch)
          patch = patch.astype(np.float32)
          patch = np.expand_dims(np.array(patch), axis=-1)
          single_patch_input = np.expand_dims(patch, 0)
          single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8)
          predicted_patches.append(single_patch_prediction)

      predicted_patches = np.array(predicted_patches)
      predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], PATCH_SIZE, PATCH_SIZE))
      reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape)

      save_to_path = SAVE_PREDICTED_VESSEL + Path(image_path).name
      cv2.imwrite(save_to_path, reconstructed_image * 255)

      predicted_vessel_dataset.append(reconstructed_image)
      gt_vessel_dataset.append(gt_vessel)
  
predicted_vessel_dataset = np.array(predicted_vessel_dataset)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
