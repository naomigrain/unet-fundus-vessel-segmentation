# %%
# !pip install patchify

import os
import glob
import cv2
import numpy as np
import skimage.io
from matplotlib import pyplot as plt
from patchify import patchify, unpatchify
from PIL import Image
import tensorflow as tf
import random

np.random.seed(0)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.8/dist-packages (from patchify) (1.22.4)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3

# %%
PATH = '/content/drive/MyDrive/AV_split/'
TRAIN_PATH = PATH+'train/'
TRAIN_IMAGE_PATH = TRAIN_PATH + 'images/'
TRAIN_VESSEL_MASK_PATH = TRAIN_PATH + 'GT_vessel/'

TEST_PATH = PATH+'test/'
TEST_IMAGE_PATH = TEST_PATH + 'images/'
TEST_VESSEL_MASK_PATH = TEST_PATH + 'GT_vessel/'

TARGET_SIZE = 512
PATCH_SIZE = 512

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def clahe_equalized(imgs):    
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))    
    imgs_equalized = clahe.apply(imgs)

    return imgs_equalized

def preprocess_img(image, patch_size):
    image = image[70:970, 200:1255]

    image = image[:,:,1]
    image = clahe_equalized(image)

    SIZE_X = (image.shape[1]//patch_size)*patch_size 
    SIZE_Y = (image.shape[0]//patch_size)*patch_size     
    image = cv2.resize(image, (SIZE_X, SIZE_Y))
    
    image = np.array(image)

    return image

# %%
def preprocess_mask(mask, patch_size):
    thresh = 128
    mask = cv2.threshold(mask, thresh, 255, cv2.THRESH_BINARY)[1]

    mask = mask[70:970, 200:1255]
    
    SIZE_X = (mask.shape[1]//patch_size)*patch_size 
    SIZE_Y = (mask.shape[0]//patch_size)*patch_size     
    mask = cv2.resize(mask, (SIZE_X, SIZE_Y))
  
    mask = 255 - mask

    return mask

# %%
def create_patch_image_list(preprocessed_img, patch_size, type):
    patches_img = patchify(preprocessed_img, (patch_size,patch_size), step=patch_size) 
    img_patches_list = []

    for i in range(patches_img.shape[0]):
        for j in range(patches_img.shape[1]):
            single_patched_img = patches_img[i,j,:,:]
            single_patched_img = (single_patched_img).astype('float32') / 255.
            if type == "MASK":
                single_patched_img[single_patched_img > 0.5] = 1
                single_patched_img[single_patched_img <= 0.5] = 0
            img_patches_list.append(single_patched_img) 

    unpatched_img = unpatchify(patches_img, preprocessed_img.shape)

    return img_patches_list, unpatched_img

# %%
train_image_list = glob.glob(TRAIN_IMAGE_PATH + '/*.JPG')
train_image_list.sort()

train_vessel_mask_list = glob.glob(TRAIN_VESSEL_MASK_PATH + '/*.jpg')
train_vessel_mask_list.sort()

# %%
image = cv2.imread(train_image_list[10])

preprocessed_image = preprocess_img(image, PATCH_SIZE)
patched_image, unpatchifed_image = create_patch_image_list(preprocessed_image, PATCH_SIZE, "IMAGE")
patched_image = np.array(patched_image)

print(patched_image.min(), patched_image.max())
print(patched_image.shape)

plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.title(train_image_list[10])
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.subplot(122)
plt.imshow(unpatchifed_image, cmap='gray')

plt.show()

rows = 1
columns = patched_image.shape[0]

fig = plt.figure(figsize=(5, 5))
for i in range(1, (rows * columns + 1)):
    fig.add_subplot(rows, columns, i)
    img = patched_image[i-1]
    plt.imshow(img,cmap='gray')

plt.show()
# Out:
# 0.007843138 0.9843137
# (2, 512, 512)

# %%
vessel_mask = cv2.imread(train_vessel_mask_list[10], cv2.IMREAD_GRAYSCALE)

preprocessed_vessel_mask = preprocess_mask(vessel_mask, PATCH_SIZE)
patched_mask, unpatcified_mask = create_patch_image_list(preprocessed_vessel_mask, PATCH_SIZE, "MASK")
patched_mask = np.array(patched_mask)

plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.title(train_vessel_mask_list[10])
plt.imshow(cv2.cvtColor(vessel_mask, cv2.COLOR_BGR2RGB))
plt.subplot(122)
plt.imshow(unpatcified_mask, cmap='gray')

plt.show()

print(patched_mask.min(), patched_mask.max())
print(patched_mask.shape)
print(np.unique(patched_mask))

rows = 1
columns = patched_image.shape[0]

fig = plt.figure(figsize=(5, 5))
for i in range(1, (rows * columns + 1)):
    fig.add_subplot(rows, columns, i)
    img = patched_mask[i-1]
    plt.imshow(img,cmap='gray')

plt.show()
# Out:
# 0.0 1.0
# (2, 512, 512)
# [0. 1.]

# %%
train_image_dataset = []
train_vessel_mask_dataset = []

for image_name in train_image_list:
    image = cv2.imread(image_name)
    preprocessed_image = preprocess_img(image, PATCH_SIZE)
    patched_image, unpatchifed_image = create_patch_image_list(preprocessed_image, PATCH_SIZE, "IMAGE")
    train_image_dataset += patched_image

for mask_name in train_vessel_mask_list:
    mask = cv2.imread(mask_name, cv2.IMREAD_GRAYSCALE)
    preprocessed_mask = preprocess_mask(mask, PATCH_SIZE)
    patched_mask, unpatcified_mask = create_patch_image_list(preprocessed_mask, PATCH_SIZE, "MASK")
    train_vessel_mask_dataset += patched_mask

train_image_dataset = np.array(train_image_dataset)
train_image_dataset = np.expand_dims(train_image_dataset, axis=-1)
train_vessel_mask_dataset = np.array(train_vessel_mask_dataset)
train_vessel_mask_dataset = np.expand_dims(train_vessel_mask_dataset, axis=-1)

print(train_image_dataset.shape)
print(train_vessel_mask_dataset.shape)
print(train_image_dataset.max(), train_vessel_mask_dataset.max())
print(train_image_dataset.min(), train_vessel_mask_dataset.min())
# Out:
# (50, 512, 512, 1)
# (50, 512, 512, 1)
# 1.0 1.0
# 0.003921569 0.0

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train_image_dataset, train_vessel_mask_dataset, test_size=0.3, random_state=0)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (35, 512, 512, 1) (35, 512, 512, 1)
# (15, 512, 512, 1) (15, 512, 512, 1)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K

def IoU_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

def IoU_loss(y_true, y_pred):
    return -IoU_coef(y_true, y_pred)

# %%
import tensorflow as tf
from keras.models import Model, load_model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.optimizers import Adam
from keras.layers import Activation, MaxPool2D, Concatenate


def unet(pretrained_weights = None,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    drop4 = Dropout(0.5)(conv4, training=True)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    conv5 = BatchNormalization()(conv5)
    drop5 = Dropout(0.5)(conv5, training=True)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)

    model = tf.keras.Model(inputs = inputs, outputs = conv10)

    model.compile(optimizer = Adam(lr = 1e-4), loss = IoU_loss, metrics = ['accuracy', IoU_coef])
    

    if(pretrained_weights):
    	  model=keras.models.load_model(pretrained_weights)

    return model

# %%
model = unet(input_size=(PATCH_SIZE, PATCH_SIZE, 1))
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
history = model.fit(x_train, y_train, 
                    verbose = 1,
                    batch_size = 3,
                    validation_data = (x_test, y_test), 
                    shuffle = False,
                    epochs = 150,
                    steps_per_epoch = 10)
# Out:
# Epoch 1/150
# 10/10 [==============================] - 42s 1s/step - loss: -0.1482 - accuracy: 0.6091 - IoU_coef: 0.1482 - val_loss: -0.0915 - val_accuracy: 0.8897 - val_IoU_coef: 0.0915
# Epoch 2/150
# 10/10 [==============================] - 26s 3s/step - loss: -0.3682 - accuracy: 0.9034 - IoU_coef: 0.3647 - val_loss: -0.0746 - val_accuracy: 0.8936 - val_IoU_coef: 0.0746
# Epoch 3/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.4152 - accuracy: 0.9102 - IoU_coef: 0.4132 - val_loss: -0.0123 - val_accuracy: 0.8966 - val_IoU_coef: 0.0123
# Epoch 4/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.4553 - accuracy: 0.9149 - IoU_coef: 0.4538 - val_loss: -0.0022 - val_accuracy: 0.8979 - val_IoU_coef: 0.0022
# Epoch 5/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4836 - accuracy: 0.9232 - IoU_coef: 0.4821 - val_loss: -0.0085 - val_accuracy: 0.8951 - val_IoU_coef: 0.0085
# Epoch 6/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.4947 - accuracy: 0.9265 - IoU_coef: 0.4935 - val_loss: -0.0031 - val_accuracy: 0.8955 - val_IoU_coef: 0.0031
# Epoch 7/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.5035 - accuracy: 0.9300 - IoU_coef: 0.5035 - val_loss: -6.0036e-04 - val_accuracy: 0.8976 - val_IoU_coef: 6.0036e-04
# Epoch 8/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5165 - accuracy: 0.9303 - IoU_coef: 0.5153 - val_loss: -2.4062e-04 - val_accuracy: 0.8983 - val_IoU_coef: 2.4062e-04
# Epoch 9/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.5190 - accuracy: 0.9285 - IoU_coef: 0.5183 - val_loss: -1.6341e-04 - val_accuracy: 0.8986 - val_IoU_coef: 1.6341e-04
# Epoch 10/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5164 - accuracy: 0.9307 - IoU_coef: 0.5160 - val_loss: -2.6364e-04 - val_accuracy: 0.8980 - val_IoU_coef: 2.6364e-04
# Epoch 11/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.5357 - accuracy: 0.9346 - IoU_coef: 0.5346 - val_loss: -2.3044e-04 - val_accuracy: 0.8979 - val_IoU_coef: 2.3044e-04
# Epoch 12/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5373 - accuracy: 0.9332 - IoU_coef: 0.5360 - val_loss: -0.0010 - val_accuracy: 0.8980 - val_IoU_coef: 0.0010
# Epoch 13/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.5451 - accuracy: 0.9355 - IoU_coef: 0.5451 - val_loss: -1.2205e-04 - val_accuracy: 0.8980 - val_IoU_coef: 1.2205e-04
# Epoch 14/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5589 - accuracy: 0.9380 - IoU_coef: 0.5578 - val_loss: -8.7841e-05 - val_accuracy: 0.8983 - val_IoU_coef: 8.7841e-05
# Epoch 15/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.5678 - accuracy: 0.9396 - IoU_coef: 0.5671 - val_loss: -5.1502e-04 - val_accuracy: 0.8986 - val_IoU_coef: 5.1502e-04
# Epoch 16/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5759 - accuracy: 0.9416 - IoU_coef: 0.5753 - val_loss: -0.0126 - val_accuracy: 0.8988 - val_IoU_coef: 0.0126
# Epoch 17/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.5817 - accuracy: 0.9415 - IoU_coef: 0.5814 - val_loss: -0.0641 - val_accuracy: 0.9031 - val_IoU_coef: 0.0641
# Epoch 18/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5881 - accuracy: 0.9430 - IoU_coef: 0.5877 - val_loss: -0.0090 - val_accuracy: 0.8991 - val_IoU_coef: 0.0090
# Epoch 19/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5860 - accuracy: 0.9433 - IoU_coef: 0.5860 - val_loss: -0.0341 - val_accuracy: 0.9003 - val_IoU_coef: 0.0341
# Epoch 20/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.5930 - accuracy: 0.9442 - IoU_coef: 0.5924 - val_loss: -0.1666 - val_accuracy: 0.9084 - val_IoU_coef: 0.1666
# Epoch 21/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.5956 - accuracy: 0.9444 - IoU_coef: 0.5955 - val_loss: -0.1938 - val_accuracy: 0.9103 - val_IoU_coef: 0.1938
# Epoch 22/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6049 - accuracy: 0.9471 - IoU_coef: 0.6045 - val_loss: -0.0717 - val_accuracy: 0.9032 - val_IoU_coef: 0.0717
# Epoch 23/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6110 - accuracy: 0.9460 - IoU_coef: 0.6109 - val_loss: -0.1248 - val_accuracy: 0.9071 - val_IoU_coef: 0.1248
# Epoch 24/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6137 - accuracy: 0.9474 - IoU_coef: 0.6135 - val_loss: -0.2102 - val_accuracy: 0.9113 - val_IoU_coef: 0.2102
# Epoch 25/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6132 - accuracy: 0.9484 - IoU_coef: 0.6132 - val_loss: -0.1796 - val_accuracy: 0.9092 - val_IoU_coef: 0.1796
# Epoch 26/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.6274 - accuracy: 0.9498 - IoU_coef: 0.6271 - val_loss: -0.1628 - val_accuracy: 0.9082 - val_IoU_coef: 0.1628
# Epoch 27/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6353 - accuracy: 0.9514 - IoU_coef: 0.6354 - val_loss: -0.1721 - val_accuracy: 0.9101 - val_IoU_coef: 0.1721
# Epoch 28/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6369 - accuracy: 0.9520 - IoU_coef: 0.6370 - val_loss: -0.2281 - val_accuracy: 0.9146 - val_IoU_coef: 0.2281
# Epoch 29/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.6393 - accuracy: 0.9513 - IoU_coef: 0.6396 - val_loss: -0.2429 - val_accuracy: 0.9159 - val_IoU_coef: 0.2429
# Epoch 30/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.6504 - accuracy: 0.9534 - IoU_coef: 0.6503 - val_loss: -0.2453 - val_accuracy: 0.9145 - val_IoU_coef: 0.2453
# Epoch 31/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6447 - accuracy: 0.9532 - IoU_coef: 0.6447 - val_loss: -0.3116 - val_accuracy: 0.9188 - val_IoU_coef: 0.3116
# Epoch 32/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.6552 - accuracy: 0.9547 - IoU_coef: 0.6555 - val_loss: -0.3189 - val_accuracy: 0.9204 - val_IoU_coef: 0.3189
# Epoch 33/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6558 - accuracy: 0.9549 - IoU_coef: 0.6558 - val_loss: -0.2201 - val_accuracy: 0.9119 - val_IoU_coef: 0.2201
# Epoch 34/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.6625 - accuracy: 0.9560 - IoU_coef: 0.6622 - val_loss: -0.2793 - val_accuracy: 0.9165 - val_IoU_coef: 0.2793
# Epoch 35/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.6507 - accuracy: 0.9531 - IoU_coef: 0.6514 - val_loss: -0.3434 - val_accuracy: 0.9244 - val_IoU_coef: 0.3434
# Epoch 36/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6545 - accuracy: 0.9542 - IoU_coef: 0.6540 - val_loss: -0.3038 - val_accuracy: 0.9193 - val_IoU_coef: 0.3038
# Epoch 37/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6529 - accuracy: 0.9547 - IoU_coef: 0.6529 - val_loss: -0.3685 - val_accuracy: 0.9213 - val_IoU_coef: 0.3685
# Epoch 38/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6594 - accuracy: 0.9552 - IoU_coef: 0.6599 - val_loss: -0.3434 - val_accuracy: 0.9210 - val_IoU_coef: 0.3434
# Epoch 39/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.6586 - accuracy: 0.9548 - IoU_coef: 0.6586 - val_loss: -0.3395 - val_accuracy: 0.9225 - val_IoU_coef: 0.3395
# Epoch 40/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6618 - accuracy: 0.9558 - IoU_coef: 0.6617 - val_loss: -0.3401 - val_accuracy: 0.9213 - val_IoU_coef: 0.3401
# Epoch 41/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6532 - accuracy: 0.9531 - IoU_coef: 0.6533 - val_loss: -0.3632 - val_accuracy: 0.9246 - val_IoU_coef: 0.3632
# Epoch 42/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6615 - accuracy: 0.9552 - IoU_coef: 0.6619 - val_loss: -0.3863 - val_accuracy: 0.9215 - val_IoU_coef: 0.3863
# Epoch 43/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.6479 - accuracy: 0.9539 - IoU_coef: 0.6479 - val_loss: -0.4253 - val_accuracy: 0.9288 - val_IoU_coef: 0.4253
# Epoch 44/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.6630 - accuracy: 0.9553 - IoU_coef: 0.6633 - val_loss: -0.4081 - val_accuracy: 0.9283 - val_IoU_coef: 0.4081
# Epoch 45/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6630 - accuracy: 0.9554 - IoU_coef: 0.6627 - val_loss: -0.3851 - val_accuracy: 0.9266 - val_IoU_coef: 0.3851
# Epoch 46/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.6666 - accuracy: 0.9565 - IoU_coef: 0.6665 - val_loss: -0.4105 - val_accuracy: 0.9279 - val_IoU_coef: 0.4105
# Epoch 47/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6494 - accuracy: 0.9527 - IoU_coef: 0.6502 - val_loss: -0.4247 - val_accuracy: 0.9294 - val_IoU_coef: 0.4247
# Epoch 48/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.6501 - accuracy: 0.9534 - IoU_coef: 0.6500 - val_loss: -0.4326 - val_accuracy: 0.9301 - val_IoU_coef: 0.4326
# Epoch 49/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6621 - accuracy: 0.9557 - IoU_coef: 0.6621 - val_loss: -0.4617 - val_accuracy: 0.9363 - val_IoU_coef: 0.4617
# Epoch 50/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.6803 - accuracy: 0.9583 - IoU_coef: 0.6795 - val_loss: -0.4512 - val_accuracy: 0.9332 - val_IoU_coef: 0.4512
# Epoch 51/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6938 - accuracy: 0.9601 - IoU_coef: 0.6933 - val_loss: -0.4555 - val_accuracy: 0.9365 - val_IoU_coef: 0.4555
# Epoch 52/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7134 - accuracy: 0.9638 - IoU_coef: 0.7133 - val_loss: -0.4799 - val_accuracy: 0.9387 - val_IoU_coef: 0.4799
# Epoch 53/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7121 - accuracy: 0.9629 - IoU_coef: 0.7124 - val_loss: -0.4935 - val_accuracy: 0.9375 - val_IoU_coef: 0.4935
# Epoch 54/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7274 - accuracy: 0.9652 - IoU_coef: 0.7277 - val_loss: -0.4878 - val_accuracy: 0.9371 - val_IoU_coef: 0.4878
# Epoch 55/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7256 - accuracy: 0.9660 - IoU_coef: 0.7256 - val_loss: -0.5091 - val_accuracy: 0.9401 - val_IoU_coef: 0.5091
# Epoch 56/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7320 - accuracy: 0.9663 - IoU_coef: 0.7322 - val_loss: -0.4982 - val_accuracy: 0.9403 - val_IoU_coef: 0.4982
# Epoch 57/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7327 - accuracy: 0.9665 - IoU_coef: 0.7330 - val_loss: -0.4879 - val_accuracy: 0.9404 - val_IoU_coef: 0.4879
# Epoch 58/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7303 - accuracy: 0.9663 - IoU_coef: 0.7302 - val_loss: -0.4904 - val_accuracy: 0.9382 - val_IoU_coef: 0.4904
# Epoch 59/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7074 - accuracy: 0.9619 - IoU_coef: 0.7073 - val_loss: -0.5025 - val_accuracy: 0.9403 - val_IoU_coef: 0.5025
# Epoch 60/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.6955 - accuracy: 0.9604 - IoU_coef: 0.6952 - val_loss: -0.4861 - val_accuracy: 0.9353 - val_IoU_coef: 0.4861
# Epoch 61/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6742 - accuracy: 0.9581 - IoU_coef: 0.6742 - val_loss: -0.5218 - val_accuracy: 0.9395 - val_IoU_coef: 0.5218
# Epoch 62/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.6909 - accuracy: 0.9599 - IoU_coef: 0.6911 - val_loss: -0.5092 - val_accuracy: 0.9396 - val_IoU_coef: 0.5092
# Epoch 63/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7034 - accuracy: 0.9616 - IoU_coef: 0.7032 - val_loss: -0.5125 - val_accuracy: 0.9425 - val_IoU_coef: 0.5125
# Epoch 64/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7249 - accuracy: 0.9654 - IoU_coef: 0.7244 - val_loss: -0.5088 - val_accuracy: 0.9421 - val_IoU_coef: 0.5088
# Epoch 65/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7204 - accuracy: 0.9639 - IoU_coef: 0.7207 - val_loss: -0.5078 - val_accuracy: 0.9408 - val_IoU_coef: 0.5078
# Epoch 66/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7289 - accuracy: 0.9652 - IoU_coef: 0.7286 - val_loss: -0.5243 - val_accuracy: 0.9416 - val_IoU_coef: 0.5243
# Epoch 67/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7207 - accuracy: 0.9652 - IoU_coef: 0.7207 - val_loss: -0.5110 - val_accuracy: 0.9382 - val_IoU_coef: 0.5110
# Epoch 68/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.6960 - accuracy: 0.9608 - IoU_coef: 0.6964 - val_loss: -0.4871 - val_accuracy: 0.9404 - val_IoU_coef: 0.4871
# Epoch 69/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.6772 - accuracy: 0.9573 - IoU_coef: 0.6787 - val_loss: -0.5367 - val_accuracy: 0.9419 - val_IoU_coef: 0.5367
# Epoch 70/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7120 - accuracy: 0.9637 - IoU_coef: 0.7105 - val_loss: -0.5227 - val_accuracy: 0.9409 - val_IoU_coef: 0.5227
# Epoch 71/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7203 - accuracy: 0.9637 - IoU_coef: 0.7205 - val_loss: -0.5378 - val_accuracy: 0.9432 - val_IoU_coef: 0.5378
# Epoch 72/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7512 - accuracy: 0.9685 - IoU_coef: 0.7515 - val_loss: -0.5341 - val_accuracy: 0.9405 - val_IoU_coef: 0.5341
# Epoch 73/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7594 - accuracy: 0.9706 - IoU_coef: 0.7594 - val_loss: -0.5357 - val_accuracy: 0.9435 - val_IoU_coef: 0.5357
# Epoch 74/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7605 - accuracy: 0.9705 - IoU_coef: 0.7604 - val_loss: -0.5357 - val_accuracy: 0.9428 - val_IoU_coef: 0.5357
# Epoch 75/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7654 - accuracy: 0.9709 - IoU_coef: 0.7653 - val_loss: -0.5302 - val_accuracy: 0.9430 - val_IoU_coef: 0.5302
# Epoch 76/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7648 - accuracy: 0.9714 - IoU_coef: 0.7649 - val_loss: -0.5374 - val_accuracy: 0.9438 - val_IoU_coef: 0.5374
# Epoch 77/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7586 - accuracy: 0.9696 - IoU_coef: 0.7587 - val_loss: -0.5358 - val_accuracy: 0.9416 - val_IoU_coef: 0.5358
# Epoch 78/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7552 - accuracy: 0.9692 - IoU_coef: 0.7546 - val_loss: -0.5281 - val_accuracy: 0.9384 - val_IoU_coef: 0.5281
# Epoch 79/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7396 - accuracy: 0.9679 - IoU_coef: 0.7396 - val_loss: -0.5199 - val_accuracy: 0.9373 - val_IoU_coef: 0.5199
# Epoch 80/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7260 - accuracy: 0.9650 - IoU_coef: 0.7260 - val_loss: -0.5165 - val_accuracy: 0.9427 - val_IoU_coef: 0.5165
# Epoch 81/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7268 - accuracy: 0.9654 - IoU_coef: 0.7276 - val_loss: -0.5277 - val_accuracy: 0.9419 - val_IoU_coef: 0.5277
# Epoch 82/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7506 - accuracy: 0.9693 - IoU_coef: 0.7498 - val_loss: -0.5304 - val_accuracy: 0.9404 - val_IoU_coef: 0.5304
# Epoch 83/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7428 - accuracy: 0.9672 - IoU_coef: 0.7429 - val_loss: -0.5331 - val_accuracy: 0.9396 - val_IoU_coef: 0.5331
# Epoch 84/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7605 - accuracy: 0.9700 - IoU_coef: 0.7608 - val_loss: -0.5320 - val_accuracy: 0.9391 - val_IoU_coef: 0.5320
# Epoch 85/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7591 - accuracy: 0.9705 - IoU_coef: 0.7591 - val_loss: -0.5341 - val_accuracy: 0.9440 - val_IoU_coef: 0.5341
# Epoch 86/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7677 - accuracy: 0.9711 - IoU_coef: 0.7679 - val_loss: -0.5226 - val_accuracy: 0.9430 - val_IoU_coef: 0.5226
# Epoch 87/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7566 - accuracy: 0.9694 - IoU_coef: 0.7565 - val_loss: -0.5326 - val_accuracy: 0.9426 - val_IoU_coef: 0.5326
# Epoch 88/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7490 - accuracy: 0.9690 - IoU_coef: 0.7479 - val_loss: -0.5271 - val_accuracy: 0.9410 - val_IoU_coef: 0.5271
# Epoch 89/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7211 - accuracy: 0.9642 - IoU_coef: 0.7226 - val_loss: -0.5199 - val_accuracy: 0.9380 - val_IoU_coef: 0.5199
# Epoch 90/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7319 - accuracy: 0.9656 - IoU_coef: 0.7320 - val_loss: -0.5345 - val_accuracy: 0.9409 - val_IoU_coef: 0.5345
# Epoch 91/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7484 - accuracy: 0.9688 - IoU_coef: 0.7484 - val_loss: -0.5332 - val_accuracy: 0.9442 - val_IoU_coef: 0.5332
# Epoch 92/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7610 - accuracy: 0.9700 - IoU_coef: 0.7609 - val_loss: -0.5218 - val_accuracy: 0.9439 - val_IoU_coef: 0.5218
# Epoch 93/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7676 - accuracy: 0.9712 - IoU_coef: 0.7677 - val_loss: -0.5329 - val_accuracy: 0.9432 - val_IoU_coef: 0.5329
# Epoch 94/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7756 - accuracy: 0.9727 - IoU_coef: 0.7750 - val_loss: -0.5269 - val_accuracy: 0.9390 - val_IoU_coef: 0.5269
# Epoch 95/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7474 - accuracy: 0.9681 - IoU_coef: 0.7480 - val_loss: -0.5096 - val_accuracy: 0.9292 - val_IoU_coef: 0.5096
# Epoch 96/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7510 - accuracy: 0.9685 - IoU_coef: 0.7515 - val_loss: -0.5396 - val_accuracy: 0.9424 - val_IoU_coef: 0.5396
# Epoch 97/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7533 - accuracy: 0.9687 - IoU_coef: 0.7533 - val_loss: -0.5196 - val_accuracy: 0.9443 - val_IoU_coef: 0.5196
# Epoch 98/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7432 - accuracy: 0.9673 - IoU_coef: 0.7423 - val_loss: -0.5358 - val_accuracy: 0.9403 - val_IoU_coef: 0.5358
# Epoch 99/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7576 - accuracy: 0.9703 - IoU_coef: 0.7574 - val_loss: -0.5187 - val_accuracy: 0.9334 - val_IoU_coef: 0.5187
# Epoch 100/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7692 - accuracy: 0.9719 - IoU_coef: 0.7693 - val_loss: -0.5299 - val_accuracy: 0.9367 - val_IoU_coef: 0.5299
# Epoch 101/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7687 - accuracy: 0.9709 - IoU_coef: 0.7687 - val_loss: -0.5396 - val_accuracy: 0.9434 - val_IoU_coef: 0.5396
# Epoch 102/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7835 - accuracy: 0.9726 - IoU_coef: 0.7831 - val_loss: -0.5187 - val_accuracy: 0.9440 - val_IoU_coef: 0.5187
# Epoch 103/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7709 - accuracy: 0.9716 - IoU_coef: 0.7709 - val_loss: -0.5333 - val_accuracy: 0.9450 - val_IoU_coef: 0.5333
# Epoch 104/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7628 - accuracy: 0.9709 - IoU_coef: 0.7634 - val_loss: -0.5127 - val_accuracy: 0.9316 - val_IoU_coef: 0.5127
# Epoch 105/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7370 - accuracy: 0.9674 - IoU_coef: 0.7378 - val_loss: -0.5349 - val_accuracy: 0.9395 - val_IoU_coef: 0.5349
# Epoch 106/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7438 - accuracy: 0.9671 - IoU_coef: 0.7435 - val_loss: -0.5185 - val_accuracy: 0.9442 - val_IoU_coef: 0.5185
# Epoch 107/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7487 - accuracy: 0.9678 - IoU_coef: 0.7491 - val_loss: -0.5297 - val_accuracy: 0.9440 - val_IoU_coef: 0.5297
# Epoch 108/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7764 - accuracy: 0.9723 - IoU_coef: 0.7763 - val_loss: -0.5359 - val_accuracy: 0.9395 - val_IoU_coef: 0.5359
# Epoch 109/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7851 - accuracy: 0.9743 - IoU_coef: 0.7851 - val_loss: -0.5348 - val_accuracy: 0.9394 - val_IoU_coef: 0.5348
# Epoch 110/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7920 - accuracy: 0.9746 - IoU_coef: 0.7918 - val_loss: -0.5411 - val_accuracy: 0.9438 - val_IoU_coef: 0.5411
# Epoch 111/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7949 - accuracy: 0.9748 - IoU_coef: 0.7949 - val_loss: -0.5283 - val_accuracy: 0.9430 - val_IoU_coef: 0.5283
# Epoch 112/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7838 - accuracy: 0.9739 - IoU_coef: 0.7843 - val_loss: -0.5378 - val_accuracy: 0.9406 - val_IoU_coef: 0.5378
# Epoch 113/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7749 - accuracy: 0.9719 - IoU_coef: 0.7750 - val_loss: -0.5348 - val_accuracy: 0.9402 - val_IoU_coef: 0.5348
# Epoch 114/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7653 - accuracy: 0.9699 - IoU_coef: 0.7650 - val_loss: -0.5286 - val_accuracy: 0.9426 - val_IoU_coef: 0.5286
# Epoch 115/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7666 - accuracy: 0.9716 - IoU_coef: 0.7666 - val_loss: -0.5335 - val_accuracy: 0.9397 - val_IoU_coef: 0.5335
# Epoch 116/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7917 - accuracy: 0.9747 - IoU_coef: 0.7919 - val_loss: -0.5387 - val_accuracy: 0.9428 - val_IoU_coef: 0.5387
# Epoch 117/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.8022 - accuracy: 0.9758 - IoU_coef: 0.8023 - val_loss: -0.5388 - val_accuracy: 0.9431 - val_IoU_coef: 0.5388
# Epoch 118/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.8135 - accuracy: 0.9779 - IoU_coef: 0.8135 - val_loss: -0.5391 - val_accuracy: 0.9416 - val_IoU_coef: 0.5391
# Epoch 119/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7978 - accuracy: 0.9751 - IoU_coef: 0.7982 - val_loss: -0.5357 - val_accuracy: 0.9400 - val_IoU_coef: 0.5357
# Epoch 120/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7986 - accuracy: 0.9750 - IoU_coef: 0.7985 - val_loss: -0.5338 - val_accuracy: 0.9417 - val_IoU_coef: 0.5338
# Epoch 121/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.7852 - accuracy: 0.9737 - IoU_coef: 0.7852 - val_loss: -0.5303 - val_accuracy: 0.9427 - val_IoU_coef: 0.5303
# Epoch 122/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7803 - accuracy: 0.9730 - IoU_coef: 0.7801 - val_loss: -0.5322 - val_accuracy: 0.9391 - val_IoU_coef: 0.5322
# Epoch 123/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7901 - accuracy: 0.9744 - IoU_coef: 0.7905 - val_loss: -0.5393 - val_accuracy: 0.9438 - val_IoU_coef: 0.5393
# Epoch 124/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.8061 - accuracy: 0.9766 - IoU_coef: 0.8062 - val_loss: -0.5334 - val_accuracy: 0.9438 - val_IoU_coef: 0.5334
# Epoch 125/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.8002 - accuracy: 0.9753 - IoU_coef: 0.8004 - val_loss: -0.5398 - val_accuracy: 0.9426 - val_IoU_coef: 0.5398
# Epoch 126/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.8121 - accuracy: 0.9770 - IoU_coef: 0.8123 - val_loss: -0.5359 - val_accuracy: 0.9411 - val_IoU_coef: 0.5359
# Epoch 127/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.8030 - accuracy: 0.9764 - IoU_coef: 0.8030 - val_loss: -0.5398 - val_accuracy: 0.9430 - val_IoU_coef: 0.5398
# Epoch 128/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.8012 - accuracy: 0.9757 - IoU_coef: 0.8017 - val_loss: -0.5338 - val_accuracy: 0.9412 - val_IoU_coef: 0.5338
# Epoch 129/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.7931 - accuracy: 0.9747 - IoU_coef: 0.7929 - val_loss: -0.5311 - val_accuracy: 0.9392 - val_IoU_coef: 0.5311
# Epoch 130/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7961 - accuracy: 0.9754 - IoU_coef: 0.7966 - val_loss: -0.5314 - val_accuracy: 0.9440 - val_IoU_coef: 0.5314
# Epoch 131/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7996 - accuracy: 0.9751 - IoU_coef: 0.8001 - val_loss: -0.5364 - val_accuracy: 0.9436 - val_IoU_coef: 0.5364
# Epoch 132/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.8149 - accuracy: 0.9773 - IoU_coef: 0.8151 - val_loss: -0.5351 - val_accuracy: 0.9419 - val_IoU_coef: 0.5351
# Epoch 133/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.8141 - accuracy: 0.9779 - IoU_coef: 0.8141 - val_loss: -0.5400 - val_accuracy: 0.9433 - val_IoU_coef: 0.5400
# Epoch 134/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.8160 - accuracy: 0.9778 - IoU_coef: 0.8164 - val_loss: -0.5361 - val_accuracy: 0.9430 - val_IoU_coef: 0.5361
# Epoch 135/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.8086 - accuracy: 0.9767 - IoU_coef: 0.8090 - val_loss: -0.5341 - val_accuracy: 0.9417 - val_IoU_coef: 0.5341
# Epoch 136/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.8084 - accuracy: 0.9771 - IoU_coef: 0.8082 - val_loss: -0.5369 - val_accuracy: 0.9430 - val_IoU_coef: 0.5369
# Epoch 137/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.7920 - accuracy: 0.9741 - IoU_coef: 0.7927 - val_loss: -0.5295 - val_accuracy: 0.9442 - val_IoU_coef: 0.5295
# Epoch 138/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.8070 - accuracy: 0.9762 - IoU_coef: 0.8073 - val_loss: -0.5393 - val_accuracy: 0.9416 - val_IoU_coef: 0.5393
# Epoch 139/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.8127 - accuracy: 0.9778 - IoU_coef: 0.8127 - val_loss: -0.5416 - val_accuracy: 0.9422 - val_IoU_coef: 0.5416
# Epoch 140/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.8201 - accuracy: 0.9783 - IoU_coef: 0.8202 - val_loss: -0.5394 - val_accuracy: 0.9442 - val_IoU_coef: 0.5394
# Epoch 141/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.8204 - accuracy: 0.9782 - IoU_coef: 0.8208 - val_loss: -0.5361 - val_accuracy: 0.9436 - val_IoU_coef: 0.5361
# Epoch 142/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.8223 - accuracy: 0.9790 - IoU_coef: 0.8226 - val_loss: -0.5364 - val_accuracy: 0.9406 - val_IoU_coef: 0.5364
# Epoch 143/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.8068 - accuracy: 0.9762 - IoU_coef: 0.8070 - val_loss: -0.5406 - val_accuracy: 0.9425 - val_IoU_coef: 0.5406
# Epoch 144/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.8123 - accuracy: 0.9768 - IoU_coef: 0.8128 - val_loss: -0.5350 - val_accuracy: 0.9408 - val_IoU_coef: 0.5350
# Epoch 145/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.8146 - accuracy: 0.9780 - IoU_coef: 0.8146 - val_loss: -0.5350 - val_accuracy: 0.9405 - val_IoU_coef: 0.5350
# Epoch 146/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.8214 - accuracy: 0.9786 - IoU_coef: 0.8218 - val_loss: -0.5351 - val_accuracy: 0.9440 - val_IoU_coef: 0.5351
# Epoch 147/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.8234 - accuracy: 0.9786 - IoU_coef: 0.8237 - val_loss: -0.5333 - val_accuracy: 0.9435 - val_IoU_coef: 0.5333
# Epoch 148/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.8278 - accuracy: 0.9797 - IoU_coef: 0.8282 - val_loss: -0.5407 - val_accuracy: 0.9416 - val_IoU_coef: 0.5407
# Epoch 149/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.8192 - accuracy: 0.9780 - IoU_coef: 0.8198 - val_loss: -0.5359 - val_accuracy: 0.9391 - val_IoU_coef: 0.5359
# Epoch 150/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.8216 - accuracy: 0.9781 - IoU_coef: 0.8216 - val_loss: -0.5352 - val_accuracy: 0.9411 - val_IoU_coef: 0.5352

# %%
test_image_list = glob.glob(TEST_IMAGE_PATH + '/*.JPG')
test_image_list.sort()

test_vessel_mask_list = glob.glob(TEST_VESSEL_MASK_PATH + '/*.jpg')
test_vessel_mask_list.sort()

# %%
test_img_number = random.randint(0, len(test_image_list)-1)

test_img = cv2.imread(test_image_list[test_img_number])
test_gt = cv2.imread(test_vessel_mask_list[test_img_number], cv2.IMREAD_GRAYSCALE)

test_img_preprocess = preprocess_img(test_img, PATCH_SIZE)
test_gt = preprocess_mask(test_gt, PATCH_SIZE)

test_patches = patchify(test_img_preprocess, (PATCH_SIZE, PATCH_SIZE), step=PATCH_SIZE)
predicted_patches = []

for i in range(test_patches.shape[0]):
      for j in range(test_patches.shape[1]):
          single_patch = test_patches[i,j,:,:]
          single_patch_norm = (single_patch.astype('float32')) / 255.
          single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
          single_patch_input = np.expand_dims(single_patch_norm, 0)
          single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8) 
          predicted_patches.append(single_patch_prediction)

predicted_patches = np.array(predicted_patches)
predicted_patches_reshaped = np.reshape(predicted_patches, (test_patches.shape[0], test_patches.shape[1], PATCH_SIZE, PATCH_SIZE))
reconstructed_image = unpatchify(predicted_patches_reshaped, test_gt.shape)
reconstructed_image = cv2.resize(reconstructed_image, (PATCH_SIZE, PATCH_SIZE))
test_gt = cv2.resize(test_gt, (PATCH_SIZE, PATCH_SIZE))

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title(test_image_list[test_img_number])
plt.imshow(cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB))
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_gt, cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(reconstructed_image, cmap='gray')
# Out:
# 1/1 [==============================] - 4s 4s/step
# 1/1 [==============================] - 0s 23ms/step
