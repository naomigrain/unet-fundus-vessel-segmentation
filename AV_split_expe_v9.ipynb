# %%
# !pip install patchify

import os
import glob
import cv2
import numpy as np
import skimage.io
from matplotlib import pyplot as plt
from patchify import patchify, unpatchify
from PIL import Image
import tensorflow as tf
import random

np.random.seed(0)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.8/dist-packages (from patchify) (1.22.4)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3

# %%
PATH = '/content/drive/MyDrive/AV_split/'
TRAIN_PATH = PATH+'train/'
TRAIN_IMAGE_PATH = TRAIN_PATH + 'images/'
TRAIN_VESSEL_MASK_PATH = TRAIN_PATH + 'GT_vessel/'

TEST_PATH = PATH+'test/'
TEST_IMAGE_PATH = TEST_PATH + 'images/'
TEST_VESSEL_MASK_PATH = TEST_PATH + 'GT_vessel/'

TARGET_SIZE = 512
PATCH_SIZE = 512

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def clahe_equalized(imgs):    
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))    
    imgs_equalized = clahe.apply(imgs)

    return imgs_equalized

def preprocess_img(image, patch_size):
    image = image[70:970, 200:1255]

    image = image[:,:,1]
    image = clahe_equalized(image)

    SIZE_X = (image.shape[1]//patch_size)*patch_size 
    SIZE_Y = (image.shape[0]//patch_size)*patch_size     
    image = cv2.resize(image, (SIZE_X, SIZE_Y))
    
    image = np.array(image)

    return image

# %%
def preprocess_mask(mask, patch_size):
    thresh = 128
    mask = cv2.threshold(mask, thresh, 255, cv2.THRESH_BINARY)[1]

    mask = mask[70:970, 200:1255]
    
    SIZE_X = (mask.shape[1]//patch_size)*patch_size 
    SIZE_Y = (mask.shape[0]//patch_size)*patch_size     
    mask = cv2.resize(mask, (SIZE_X, SIZE_Y))
  
    mask = 255 - mask

    return mask

# %%
def create_patch_image_list(preprocessed_img, patch_size, type):
    patches_img = patchify(preprocessed_img, (patch_size,patch_size), step=patch_size) 
    img_patches_list = []

    for i in range(patches_img.shape[0]):
        for j in range(patches_img.shape[1]):
            single_patched_img = patches_img[i,j,:,:]
            single_patched_img = (single_patched_img).astype('float32') / 255.
            if type == "MASK":
                single_patched_img[single_patched_img > 0.5] = 1
                single_patched_img[single_patched_img <= 0.5] = 0
            img_patches_list.append(single_patched_img) 

    unpatched_img = unpatchify(patches_img, preprocessed_img.shape)

    return img_patches_list, unpatched_img

# %%
train_image_list = glob.glob(TRAIN_IMAGE_PATH + '/*.JPG')
train_image_list.sort()

train_vessel_mask_list = glob.glob(TRAIN_VESSEL_MASK_PATH + '/*.jpg')
train_vessel_mask_list.sort()

# %%
image = cv2.imread(train_image_list[10])

preprocessed_image = preprocess_img(image, PATCH_SIZE)
patched_image, unpatchifed_image = create_patch_image_list(preprocessed_image, PATCH_SIZE, "IMAGE")
patched_image = np.array(patched_image)

print(patched_image.min(), patched_image.max())
print(patched_image.shape)

plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.title(train_image_list[10])
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.subplot(122)
plt.imshow(unpatchifed_image, cmap='gray')

plt.show()

rows = 1
columns = patched_image.shape[0]

fig = plt.figure(figsize=(5, 5))
for i in range(1, (rows * columns + 1)):
    fig.add_subplot(rows, columns, i)
    img = patched_image[i-1]
    plt.imshow(img,cmap='gray')

plt.show()
# Out:
# 0.007843138 0.9843137
# (2, 512, 512)

# %%
vessel_mask = cv2.imread(train_vessel_mask_list[10], cv2.IMREAD_GRAYSCALE)

preprocessed_vessel_mask = preprocess_mask(vessel_mask, PATCH_SIZE)
patched_mask, unpatcified_mask = create_patch_image_list(preprocessed_vessel_mask, PATCH_SIZE, "MASK")
patched_mask = np.array(patched_mask)

plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.title(train_vessel_mask_list[10])
plt.imshow(cv2.cvtColor(vessel_mask, cv2.COLOR_BGR2RGB))
plt.subplot(122)
plt.imshow(unpatcified_mask, cmap='gray')

plt.show()

print(patched_mask.min(), patched_mask.max())
print(patched_mask.shape)
print(np.unique(patched_mask))

rows = 1
columns = patched_image.shape[0]

fig = plt.figure(figsize=(5, 5))
for i in range(1, (rows * columns + 1)):
    fig.add_subplot(rows, columns, i)
    img = patched_mask[i-1]
    plt.imshow(img,cmap='gray')

plt.show()
# Out:
# 0.0 1.0
# (2, 512, 512)
# [0. 1.]

# %%
train_image_dataset = []
train_vessel_mask_dataset = []

for image_name in train_image_list:
    image = cv2.imread(image_name)
    preprocessed_image = preprocess_img(image, PATCH_SIZE)
    patched_image, unpatchifed_image = create_patch_image_list(preprocessed_image, PATCH_SIZE, "IMAGE")
    train_image_dataset += patched_image

for mask_name in train_vessel_mask_list:
    mask = cv2.imread(mask_name, cv2.IMREAD_GRAYSCALE)
    preprocessed_mask = preprocess_mask(mask, PATCH_SIZE)
    patched_mask, unpatcified_mask = create_patch_image_list(preprocessed_mask, PATCH_SIZE, "MASK")
    train_vessel_mask_dataset += patched_mask

train_image_dataset = np.array(train_image_dataset)
train_image_dataset = np.expand_dims(train_image_dataset, axis=-1)
train_vessel_mask_dataset = np.array(train_vessel_mask_dataset)
train_vessel_mask_dataset = np.expand_dims(train_vessel_mask_dataset, axis=-1)

print(train_image_dataset.shape)
print(train_vessel_mask_dataset.shape)
print(train_image_dataset.max(), train_vessel_mask_dataset.max())
print(train_image_dataset.min(), train_vessel_mask_dataset.min())
# Out:
# (50, 512, 512, 1)
# (50, 512, 512, 1)
# 1.0 1.0
# 0.003921569 0.0

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train_image_dataset, train_vessel_mask_dataset, test_size=0.3, random_state=0)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (35, 512, 512, 1) (35, 512, 512, 1)
# (15, 512, 512, 1) (15, 512, 512, 1)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K

def IoU_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

def IoU_loss(y_true, y_pred):
    return -IoU_coef(y_true, y_pred)

# %%
import tensorflow as tf
from keras.models import Model, load_model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.optimizers import Adam
from keras.layers import Activation, MaxPool2D, Concatenate


def unet(pretrained_weights = None,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    drop4 = Dropout(0.5)(conv4, training=True)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    conv5 = BatchNormalization()(conv5)
    drop5 = Dropout(0.5)(conv5, training=True)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)

    model = tf.keras.Model(inputs = inputs, outputs = conv10)

    model.compile(optimizer = Adam(lr = 1e-4), loss = IoU_loss, metrics = ['accuracy', IoU_coef])
    

    if(pretrained_weights):
    	  model=keras.models.load_model(pretrained_weights)

    return model

# %%
model = unet(input_size=(PATCH_SIZE, PATCH_SIZE, 1))
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
history = model.fit(x_train, y_train, 
                    verbose = 1,
                    batch_size = 3,
                    validation_data = (x_test, y_test), 
                    shuffle = False,
                    epochs = 150,
                    steps_per_epoch = 10)
# Out:
# Epoch 1/150
# 10/10 [==============================] - 40s 1s/step - loss: -0.1314 - accuracy: 0.3667 - IoU_coef: 0.1314 - val_loss: -0.0915 - val_accuracy: 0.7860 - val_IoU_coef: 0.0915
# Epoch 2/150
# 10/10 [==============================] - 26s 3s/step - loss: -0.1565 - accuracy: 0.7531 - IoU_coef: 0.1564 - val_loss: -0.0930 - val_accuracy: 0.8151 - val_IoU_coef: 0.0930
# Epoch 3/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1608 - accuracy: 0.8228 - IoU_coef: 0.1608 - val_loss: -0.0925 - val_accuracy: 0.8893 - val_IoU_coef: 0.0925
# Epoch 4/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1618 - accuracy: 0.8365 - IoU_coef: 0.1618 - val_loss: -0.0924 - val_accuracy: 0.8929 - val_IoU_coef: 0.0924
# Epoch 5/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1687 - accuracy: 0.8532 - IoU_coef: 0.1686 - val_loss: -0.0931 - val_accuracy: 0.8915 - val_IoU_coef: 0.0931
# Epoch 6/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1689 - accuracy: 0.8607 - IoU_coef: 0.1689 - val_loss: -0.0914 - val_accuracy: 0.8914 - val_IoU_coef: 0.0914
# Epoch 7/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1654 - accuracy: 0.8675 - IoU_coef: 0.1654 - val_loss: -0.0927 - val_accuracy: 0.8898 - val_IoU_coef: 0.0927
# Epoch 8/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1693 - accuracy: 0.8813 - IoU_coef: 0.1694 - val_loss: -0.0914 - val_accuracy: 0.8928 - val_IoU_coef: 0.0914
# Epoch 9/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1698 - accuracy: 0.8799 - IoU_coef: 0.1699 - val_loss: -0.0917 - val_accuracy: 0.8917 - val_IoU_coef: 0.0917
# Epoch 10/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1694 - accuracy: 0.8897 - IoU_coef: 0.1696 - val_loss: -0.0987 - val_accuracy: 0.8937 - val_IoU_coef: 0.0987
# Epoch 11/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1748 - accuracy: 0.8893 - IoU_coef: 0.1748 - val_loss: -0.0942 - val_accuracy: 0.8947 - val_IoU_coef: 0.0942
# Epoch 12/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1744 - accuracy: 0.8905 - IoU_coef: 0.1744 - val_loss: -0.0934 - val_accuracy: 0.8888 - val_IoU_coef: 0.0934
# Epoch 13/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1696 - accuracy: 0.8927 - IoU_coef: 0.1696 - val_loss: -0.1005 - val_accuracy: 0.8935 - val_IoU_coef: 0.1005
# Epoch 14/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1720 - accuracy: 0.8909 - IoU_coef: 0.1722 - val_loss: -0.1071 - val_accuracy: 0.8819 - val_IoU_coef: 0.1071
# Epoch 15/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1725 - accuracy: 0.8820 - IoU_coef: 0.1726 - val_loss: -0.1032 - val_accuracy: 0.8925 - val_IoU_coef: 0.1032
# Epoch 16/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1720 - accuracy: 0.8928 - IoU_coef: 0.1723 - val_loss: -0.0999 - val_accuracy: 0.8918 - val_IoU_coef: 0.0999
# Epoch 17/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1785 - accuracy: 0.8999 - IoU_coef: 0.1785 - val_loss: -0.1067 - val_accuracy: 0.8939 - val_IoU_coef: 0.1067
# Epoch 18/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1789 - accuracy: 0.9025 - IoU_coef: 0.1790 - val_loss: -0.1108 - val_accuracy: 0.8964 - val_IoU_coef: 0.1108
# Epoch 19/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1742 - accuracy: 0.9033 - IoU_coef: 0.1742 - val_loss: -0.1213 - val_accuracy: 0.8936 - val_IoU_coef: 0.1213
# Epoch 20/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1775 - accuracy: 0.9119 - IoU_coef: 0.1777 - val_loss: -0.1235 - val_accuracy: 0.8793 - val_IoU_coef: 0.1235
# Epoch 21/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1775 - accuracy: 0.9068 - IoU_coef: 0.1777 - val_loss: -0.1197 - val_accuracy: 0.8914 - val_IoU_coef: 0.1197
# Epoch 22/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1771 - accuracy: 0.9133 - IoU_coef: 0.1774 - val_loss: -0.1119 - val_accuracy: 0.8989 - val_IoU_coef: 0.1119
# Epoch 23/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1817 - accuracy: 0.9074 - IoU_coef: 0.1818 - val_loss: -0.1269 - val_accuracy: 0.8841 - val_IoU_coef: 0.1269
# Epoch 24/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1815 - accuracy: 0.9117 - IoU_coef: 0.1816 - val_loss: -0.1285 - val_accuracy: 0.8899 - val_IoU_coef: 0.1285
# Epoch 25/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1763 - accuracy: 0.9073 - IoU_coef: 0.1763 - val_loss: -0.1283 - val_accuracy: 0.8944 - val_IoU_coef: 0.1283
# Epoch 26/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1796 - accuracy: 0.9180 - IoU_coef: 0.1798 - val_loss: -0.1178 - val_accuracy: 0.8992 - val_IoU_coef: 0.1178
# Epoch 27/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1797 - accuracy: 0.9153 - IoU_coef: 0.1800 - val_loss: -0.1281 - val_accuracy: 0.8983 - val_IoU_coef: 0.1281
# Epoch 28/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1793 - accuracy: 0.9156 - IoU_coef: 0.1796 - val_loss: -0.1310 - val_accuracy: 0.9042 - val_IoU_coef: 0.1310
# Epoch 29/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1839 - accuracy: 0.9178 - IoU_coef: 0.1840 - val_loss: -0.1335 - val_accuracy: 0.8936 - val_IoU_coef: 0.1335
# Epoch 30/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1843 - accuracy: 0.9195 - IoU_coef: 0.1844 - val_loss: -0.1333 - val_accuracy: 0.9003 - val_IoU_coef: 0.1333
# Epoch 31/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1792 - accuracy: 0.9195 - IoU_coef: 0.1792 - val_loss: -0.1374 - val_accuracy: 0.8979 - val_IoU_coef: 0.1374
# Epoch 32/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1825 - accuracy: 0.9231 - IoU_coef: 0.1827 - val_loss: -0.1372 - val_accuracy: 0.8995 - val_IoU_coef: 0.1372
# Epoch 33/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1824 - accuracy: 0.9223 - IoU_coef: 0.1826 - val_loss: -0.1312 - val_accuracy: 0.9063 - val_IoU_coef: 0.1312
# Epoch 34/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1816 - accuracy: 0.9228 - IoU_coef: 0.1819 - val_loss: -0.1372 - val_accuracy: 0.9060 - val_IoU_coef: 0.1372
# Epoch 35/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1864 - accuracy: 0.9234 - IoU_coef: 0.1866 - val_loss: -0.1386 - val_accuracy: 0.9096 - val_IoU_coef: 0.1386
# Epoch 36/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1869 - accuracy: 0.9262 - IoU_coef: 0.1870 - val_loss: -0.1395 - val_accuracy: 0.9016 - val_IoU_coef: 0.1395
# Epoch 37/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1815 - accuracy: 0.9285 - IoU_coef: 0.1815 - val_loss: -0.1394 - val_accuracy: 0.9060 - val_IoU_coef: 0.1394
# Epoch 38/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1846 - accuracy: 0.9293 - IoU_coef: 0.1848 - val_loss: -0.1449 - val_accuracy: 0.9012 - val_IoU_coef: 0.1449
# Epoch 39/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1844 - accuracy: 0.9279 - IoU_coef: 0.1847 - val_loss: -0.1435 - val_accuracy: 0.9111 - val_IoU_coef: 0.1435
# Epoch 40/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1839 - accuracy: 0.9291 - IoU_coef: 0.1841 - val_loss: -0.1418 - val_accuracy: 0.9144 - val_IoU_coef: 0.1418
# Epoch 41/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1879 - accuracy: 0.9288 - IoU_coef: 0.1881 - val_loss: -0.1441 - val_accuracy: 0.9173 - val_IoU_coef: 0.1441
# Epoch 42/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1889 - accuracy: 0.9337 - IoU_coef: 0.1890 - val_loss: -0.1480 - val_accuracy: 0.9016 - val_IoU_coef: 0.1480
# Epoch 43/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1837 - accuracy: 0.9337 - IoU_coef: 0.1837 - val_loss: -0.1492 - val_accuracy: 0.9068 - val_IoU_coef: 0.1492
# Epoch 44/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1868 - accuracy: 0.9369 - IoU_coef: 0.1871 - val_loss: -0.1485 - val_accuracy: 0.9089 - val_IoU_coef: 0.1485
# Epoch 45/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1870 - accuracy: 0.9345 - IoU_coef: 0.1872 - val_loss: -0.1473 - val_accuracy: 0.9179 - val_IoU_coef: 0.1473
# Epoch 46/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1859 - accuracy: 0.9363 - IoU_coef: 0.1862 - val_loss: -0.1453 - val_accuracy: 0.9216 - val_IoU_coef: 0.1453
# Epoch 47/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1897 - accuracy: 0.9311 - IoU_coef: 0.1898 - val_loss: -0.1522 - val_accuracy: 0.9093 - val_IoU_coef: 0.1522
# Epoch 48/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1896 - accuracy: 0.9341 - IoU_coef: 0.1898 - val_loss: -0.1482 - val_accuracy: 0.9110 - val_IoU_coef: 0.1482
# Epoch 49/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1839 - accuracy: 0.9351 - IoU_coef: 0.1839 - val_loss: -0.1544 - val_accuracy: 0.8979 - val_IoU_coef: 0.1544
# Epoch 50/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1871 - accuracy: 0.9333 - IoU_coef: 0.1874 - val_loss: -0.1506 - val_accuracy: 0.9154 - val_IoU_coef: 0.1506
# Epoch 51/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1871 - accuracy: 0.9332 - IoU_coef: 0.1873 - val_loss: -0.1498 - val_accuracy: 0.9261 - val_IoU_coef: 0.1498
# Epoch 52/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1869 - accuracy: 0.9369 - IoU_coef: 0.1872 - val_loss: -0.1512 - val_accuracy: 0.9301 - val_IoU_coef: 0.1512
# Epoch 53/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1914 - accuracy: 0.9385 - IoU_coef: 0.1916 - val_loss: -0.1540 - val_accuracy: 0.9224 - val_IoU_coef: 0.1540
# Epoch 54/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1923 - accuracy: 0.9440 - IoU_coef: 0.1925 - val_loss: -0.1550 - val_accuracy: 0.9047 - val_IoU_coef: 0.1550
# Epoch 55/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1866 - accuracy: 0.9430 - IoU_coef: 0.1866 - val_loss: -0.1563 - val_accuracy: 0.9200 - val_IoU_coef: 0.1563
# Epoch 56/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1894 - accuracy: 0.9396 - IoU_coef: 0.1896 - val_loss: -0.1536 - val_accuracy: 0.9291 - val_IoU_coef: 0.1536
# Epoch 57/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1884 - accuracy: 0.9344 - IoU_coef: 0.1887 - val_loss: -0.1540 - val_accuracy: 0.9299 - val_IoU_coef: 0.1540
# Epoch 58/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1876 - accuracy: 0.9372 - IoU_coef: 0.1879 - val_loss: -0.1551 - val_accuracy: 0.9215 - val_IoU_coef: 0.1551
# Epoch 59/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1918 - accuracy: 0.9369 - IoU_coef: 0.1920 - val_loss: -0.1575 - val_accuracy: 0.9014 - val_IoU_coef: 0.1575
# Epoch 60/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1921 - accuracy: 0.9428 - IoU_coef: 0.1923 - val_loss: -0.1585 - val_accuracy: 0.8975 - val_IoU_coef: 0.1585
# Epoch 61/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1865 - accuracy: 0.9374 - IoU_coef: 0.1865 - val_loss: -0.1568 - val_accuracy: 0.9264 - val_IoU_coef: 0.1568
# Epoch 62/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1897 - accuracy: 0.9372 - IoU_coef: 0.1899 - val_loss: -0.1535 - val_accuracy: 0.9379 - val_IoU_coef: 0.1535
# Epoch 63/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1890 - accuracy: 0.9333 - IoU_coef: 0.1893 - val_loss: -0.1567 - val_accuracy: 0.9322 - val_IoU_coef: 0.1567
# Epoch 64/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1878 - accuracy: 0.9404 - IoU_coef: 0.1881 - val_loss: -0.1587 - val_accuracy: 0.8966 - val_IoU_coef: 0.1587
# Epoch 65/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1923 - accuracy: 0.9389 - IoU_coef: 0.1924 - val_loss: -0.1593 - val_accuracy: 0.8903 - val_IoU_coef: 0.1593
# Epoch 66/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1925 - accuracy: 0.9360 - IoU_coef: 0.1926 - val_loss: -0.1589 - val_accuracy: 0.9211 - val_IoU_coef: 0.1589
# Epoch 67/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1873 - accuracy: 0.9358 - IoU_coef: 0.1873 - val_loss: -0.1549 - val_accuracy: 0.9341 - val_IoU_coef: 0.1549
# Epoch 68/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1902 - accuracy: 0.9380 - IoU_coef: 0.1905 - val_loss: -0.1589 - val_accuracy: 0.9209 - val_IoU_coef: 0.1589
# Epoch 69/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1909 - accuracy: 0.9461 - IoU_coef: 0.1911 - val_loss: -0.1599 - val_accuracy: 0.9014 - val_IoU_coef: 0.1599
# Epoch 70/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1895 - accuracy: 0.9437 - IoU_coef: 0.1899 - val_loss: -0.1587 - val_accuracy: 0.9243 - val_IoU_coef: 0.1587
# Epoch 71/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1947 - accuracy: 0.9414 - IoU_coef: 0.1949 - val_loss: -0.1568 - val_accuracy: 0.9344 - val_IoU_coef: 0.1568
# Epoch 72/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1951 - accuracy: 0.9434 - IoU_coef: 0.1953 - val_loss: -0.1582 - val_accuracy: 0.9314 - val_IoU_coef: 0.1582
# Epoch 73/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1894 - accuracy: 0.9490 - IoU_coef: 0.1894 - val_loss: -0.1601 - val_accuracy: 0.9143 - val_IoU_coef: 0.1601
# Epoch 74/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1931 - accuracy: 0.9519 - IoU_coef: 0.1934 - val_loss: -0.1594 - val_accuracy: 0.9257 - val_IoU_coef: 0.1594
# Epoch 75/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1934 - accuracy: 0.9490 - IoU_coef: 0.1936 - val_loss: -0.1572 - val_accuracy: 0.9340 - val_IoU_coef: 0.1572
# Epoch 76/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1926 - accuracy: 0.9528 - IoU_coef: 0.1929 - val_loss: -0.1587 - val_accuracy: 0.9335 - val_IoU_coef: 0.1587
# Epoch 77/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1974 - accuracy: 0.9536 - IoU_coef: 0.1975 - val_loss: -0.1595 - val_accuracy: 0.9242 - val_IoU_coef: 0.1595
# Epoch 78/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1970 - accuracy: 0.9533 - IoU_coef: 0.1972 - val_loss: -0.1590 - val_accuracy: 0.9341 - val_IoU_coef: 0.1590
# Epoch 79/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1913 - accuracy: 0.9488 - IoU_coef: 0.1913 - val_loss: -0.1579 - val_accuracy: 0.9347 - val_IoU_coef: 0.1579
# Epoch 80/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1942 - accuracy: 0.9537 - IoU_coef: 0.1945 - val_loss: -0.1610 - val_accuracy: 0.9226 - val_IoU_coef: 0.1610
# Epoch 81/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1945 - accuracy: 0.9548 - IoU_coef: 0.1948 - val_loss: -0.1601 - val_accuracy: 0.9237 - val_IoU_coef: 0.1601
# Epoch 82/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1932 - accuracy: 0.9528 - IoU_coef: 0.1936 - val_loss: -0.1580 - val_accuracy: 0.9358 - val_IoU_coef: 0.1580
# Epoch 83/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1978 - accuracy: 0.9505 - IoU_coef: 0.1980 - val_loss: -0.1592 - val_accuracy: 0.9285 - val_IoU_coef: 0.1592
# Epoch 84/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1982 - accuracy: 0.9567 - IoU_coef: 0.1984 - val_loss: -0.1608 - val_accuracy: 0.9207 - val_IoU_coef: 0.1608
# Epoch 85/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1922 - accuracy: 0.9546 - IoU_coef: 0.1922 - val_loss: -0.1599 - val_accuracy: 0.9269 - val_IoU_coef: 0.1599
# Epoch 86/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1953 - accuracy: 0.9531 - IoU_coef: 0.1955 - val_loss: -0.1607 - val_accuracy: 0.9277 - val_IoU_coef: 0.1607
# Epoch 87/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1951 - accuracy: 0.9521 - IoU_coef: 0.1953 - val_loss: -0.1567 - val_accuracy: 0.9348 - val_IoU_coef: 0.1567
# Epoch 88/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1939 - accuracy: 0.9561 - IoU_coef: 0.1942 - val_loss: -0.1610 - val_accuracy: 0.9277 - val_IoU_coef: 0.1610
# Epoch 89/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1987 - accuracy: 0.9530 - IoU_coef: 0.1989 - val_loss: -0.1595 - val_accuracy: 0.9249 - val_IoU_coef: 0.1595
# Epoch 90/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1983 - accuracy: 0.9533 - IoU_coef: 0.1984 - val_loss: -0.1595 - val_accuracy: 0.9336 - val_IoU_coef: 0.1595
# Epoch 91/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1932 - accuracy: 0.9532 - IoU_coef: 0.1932 - val_loss: -0.1596 - val_accuracy: 0.9338 - val_IoU_coef: 0.1596
# Epoch 92/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1965 - accuracy: 0.9568 - IoU_coef: 0.1968 - val_loss: -0.1604 - val_accuracy: 0.9297 - val_IoU_coef: 0.1604
# Epoch 93/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1968 - accuracy: 0.9590 - IoU_coef: 0.1971 - val_loss: -0.1618 - val_accuracy: 0.9222 - val_IoU_coef: 0.1618
# Epoch 94/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1959 - accuracy: 0.9607 - IoU_coef: 0.1962 - val_loss: -0.1603 - val_accuracy: 0.9304 - val_IoU_coef: 0.1603
# Epoch 95/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2004 - accuracy: 0.9566 - IoU_coef: 0.2006 - val_loss: -0.1593 - val_accuracy: 0.9320 - val_IoU_coef: 0.1593
# Epoch 96/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1998 - accuracy: 0.9571 - IoU_coef: 0.2000 - val_loss: -0.1612 - val_accuracy: 0.9261 - val_IoU_coef: 0.1612
# Epoch 97/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1941 - accuracy: 0.9579 - IoU_coef: 0.1941 - val_loss: -0.1610 - val_accuracy: 0.9174 - val_IoU_coef: 0.1610
# Epoch 98/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1966 - accuracy: 0.9560 - IoU_coef: 0.1969 - val_loss: -0.1598 - val_accuracy: 0.9329 - val_IoU_coef: 0.1598
# Epoch 99/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1968 - accuracy: 0.9537 - IoU_coef: 0.1970 - val_loss: -0.1612 - val_accuracy: 0.9306 - val_IoU_coef: 0.1612
# Epoch 100/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1960 - accuracy: 0.9597 - IoU_coef: 0.1963 - val_loss: -0.1604 - val_accuracy: 0.9247 - val_IoU_coef: 0.1604
# Epoch 101/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2004 - accuracy: 0.9566 - IoU_coef: 0.2006 - val_loss: -0.1610 - val_accuracy: 0.9305 - val_IoU_coef: 0.1610
# Epoch 102/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2014 - accuracy: 0.9599 - IoU_coef: 0.2016 - val_loss: -0.1609 - val_accuracy: 0.9312 - val_IoU_coef: 0.1609
# Epoch 103/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1955 - accuracy: 0.9614 - IoU_coef: 0.1955 - val_loss: -0.1616 - val_accuracy: 0.9254 - val_IoU_coef: 0.1616
# Epoch 104/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1986 - accuracy: 0.9624 - IoU_coef: 0.1989 - val_loss: -0.1610 - val_accuracy: 0.9300 - val_IoU_coef: 0.1610
# Epoch 105/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1984 - accuracy: 0.9591 - IoU_coef: 0.1987 - val_loss: -0.1585 - val_accuracy: 0.9382 - val_IoU_coef: 0.1585
# Epoch 106/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1973 - accuracy: 0.9606 - IoU_coef: 0.1976 - val_loss: -0.1607 - val_accuracy: 0.9334 - val_IoU_coef: 0.1607
# Epoch 107/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2020 - accuracy: 0.9612 - IoU_coef: 0.2022 - val_loss: -0.1614 - val_accuracy: 0.9255 - val_IoU_coef: 0.1614
# Epoch 108/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2015 - accuracy: 0.9618 - IoU_coef: 0.2017 - val_loss: -0.1618 - val_accuracy: 0.9269 - val_IoU_coef: 0.1618
# Epoch 109/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1956 - accuracy: 0.9558 - IoU_coef: 0.1956 - val_loss: -0.1604 - val_accuracy: 0.9340 - val_IoU_coef: 0.1604
# Epoch 110/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.1991 - accuracy: 0.9619 - IoU_coef: 0.1993 - val_loss: -0.1619 - val_accuracy: 0.9285 - val_IoU_coef: 0.1619
# Epoch 111/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1996 - accuracy: 0.9626 - IoU_coef: 0.1999 - val_loss: -0.1622 - val_accuracy: 0.9247 - val_IoU_coef: 0.1622
# Epoch 112/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1984 - accuracy: 0.9645 - IoU_coef: 0.1987 - val_loss: -0.1617 - val_accuracy: 0.9296 - val_IoU_coef: 0.1617
# Epoch 113/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.2030 - accuracy: 0.9614 - IoU_coef: 0.2031 - val_loss: -0.1624 - val_accuracy: 0.9226 - val_IoU_coef: 0.1624
# Epoch 114/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2030 - accuracy: 0.9640 - IoU_coef: 0.2031 - val_loss: -0.1620 - val_accuracy: 0.9255 - val_IoU_coef: 0.1620
# Epoch 115/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1968 - accuracy: 0.9613 - IoU_coef: 0.1968 - val_loss: -0.1612 - val_accuracy: 0.9352 - val_IoU_coef: 0.1612
# Epoch 116/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1998 - accuracy: 0.9586 - IoU_coef: 0.2001 - val_loss: -0.1613 - val_accuracy: 0.9340 - val_IoU_coef: 0.1613
# Epoch 117/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1997 - accuracy: 0.9621 - IoU_coef: 0.1999 - val_loss: -0.1622 - val_accuracy: 0.9264 - val_IoU_coef: 0.1622
# Epoch 118/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1992 - accuracy: 0.9661 - IoU_coef: 0.1995 - val_loss: -0.1628 - val_accuracy: 0.9277 - val_IoU_coef: 0.1628
# Epoch 119/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.2041 - accuracy: 0.9633 - IoU_coef: 0.2042 - val_loss: -0.1617 - val_accuracy: 0.9297 - val_IoU_coef: 0.1617
# Epoch 120/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2039 - accuracy: 0.9642 - IoU_coef: 0.2041 - val_loss: -0.1617 - val_accuracy: 0.9343 - val_IoU_coef: 0.1617
# Epoch 121/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1983 - accuracy: 0.9638 - IoU_coef: 0.1983 - val_loss: -0.1619 - val_accuracy: 0.9329 - val_IoU_coef: 0.1619
# Epoch 122/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.2013 - accuracy: 0.9657 - IoU_coef: 0.2015 - val_loss: -0.1634 - val_accuracy: 0.9230 - val_IoU_coef: 0.1634
# Epoch 123/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2012 - accuracy: 0.9655 - IoU_coef: 0.2015 - val_loss: -0.1629 - val_accuracy: 0.9206 - val_IoU_coef: 0.1629
# Epoch 124/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1994 - accuracy: 0.9653 - IoU_coef: 0.1998 - val_loss: -0.1627 - val_accuracy: 0.9305 - val_IoU_coef: 0.1627
# Epoch 125/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2041 - accuracy: 0.9598 - IoU_coef: 0.2042 - val_loss: -0.1599 - val_accuracy: 0.9371 - val_IoU_coef: 0.1599
# Epoch 126/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.2039 - accuracy: 0.9604 - IoU_coef: 0.2041 - val_loss: -0.1611 - val_accuracy: 0.9362 - val_IoU_coef: 0.1611
# Epoch 127/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.1982 - accuracy: 0.9646 - IoU_coef: 0.1982 - val_loss: -0.1635 - val_accuracy: 0.9069 - val_IoU_coef: 0.1635
# Epoch 128/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.2014 - accuracy: 0.9669 - IoU_coef: 0.2016 - val_loss: -0.1644 - val_accuracy: 0.9127 - val_IoU_coef: 0.1644
# Epoch 129/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2010 - accuracy: 0.9609 - IoU_coef: 0.2013 - val_loss: -0.1611 - val_accuracy: 0.9377 - val_IoU_coef: 0.1611
# Epoch 130/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2003 - accuracy: 0.9638 - IoU_coef: 0.2006 - val_loss: -0.1584 - val_accuracy: 0.9408 - val_IoU_coef: 0.1584
# Epoch 131/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2049 - accuracy: 0.9624 - IoU_coef: 0.2050 - val_loss: -0.1627 - val_accuracy: 0.9310 - val_IoU_coef: 0.1627
# Epoch 132/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2048 - accuracy: 0.9671 - IoU_coef: 0.2049 - val_loss: -0.1641 - val_accuracy: 0.9037 - val_IoU_coef: 0.1641
# Epoch 133/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.1983 - accuracy: 0.9626 - IoU_coef: 0.1983 - val_loss: -0.1633 - val_accuracy: 0.9235 - val_IoU_coef: 0.1633
# Epoch 134/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.2011 - accuracy: 0.9568 - IoU_coef: 0.2014 - val_loss: -0.1593 - val_accuracy: 0.9417 - val_IoU_coef: 0.1593
# Epoch 135/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2006 - accuracy: 0.9568 - IoU_coef: 0.2009 - val_loss: -0.1646 - val_accuracy: 0.9186 - val_IoU_coef: 0.1646
# Epoch 136/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2005 - accuracy: 0.9665 - IoU_coef: 0.2008 - val_loss: -0.1647 - val_accuracy: 0.9116 - val_IoU_coef: 0.1647
# Epoch 137/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2055 - accuracy: 0.9630 - IoU_coef: 0.2056 - val_loss: -0.1638 - val_accuracy: 0.9293 - val_IoU_coef: 0.1638
# Epoch 138/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.2064 - accuracy: 0.9663 - IoU_coef: 0.2065 - val_loss: -0.1626 - val_accuracy: 0.9348 - val_IoU_coef: 0.1626
# Epoch 139/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.2008 - accuracy: 0.9678 - IoU_coef: 0.2008 - val_loss: -0.1622 - val_accuracy: 0.9358 - val_IoU_coef: 0.1622
# Epoch 140/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2040 - accuracy: 0.9703 - IoU_coef: 0.2042 - val_loss: -0.1636 - val_accuracy: 0.9312 - val_IoU_coef: 0.1636
# Epoch 141/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.2041 - accuracy: 0.9699 - IoU_coef: 0.2043 - val_loss: -0.1628 - val_accuracy: 0.9335 - val_IoU_coef: 0.1628
# Epoch 142/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2024 - accuracy: 0.9700 - IoU_coef: 0.2028 - val_loss: -0.1617 - val_accuracy: 0.9378 - val_IoU_coef: 0.1617
# Epoch 143/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.2070 - accuracy: 0.9654 - IoU_coef: 0.2072 - val_loss: -0.1619 - val_accuracy: 0.9353 - val_IoU_coef: 0.1619
# Epoch 144/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.2064 - accuracy: 0.9668 - IoU_coef: 0.2066 - val_loss: -0.1636 - val_accuracy: 0.9277 - val_IoU_coef: 0.1636
# Epoch 145/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.2008 - accuracy: 0.9674 - IoU_coef: 0.2008 - val_loss: -0.1637 - val_accuracy: 0.9343 - val_IoU_coef: 0.1637
# Epoch 146/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.2042 - accuracy: 0.9663 - IoU_coef: 0.2045 - val_loss: -0.1618 - val_accuracy: 0.9355 - val_IoU_coef: 0.1618
# Epoch 147/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.2037 - accuracy: 0.9664 - IoU_coef: 0.2040 - val_loss: -0.1624 - val_accuracy: 0.9354 - val_IoU_coef: 0.1624
# Epoch 148/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.2031 - accuracy: 0.9703 - IoU_coef: 0.2034 - val_loss: -0.1639 - val_accuracy: 0.9331 - val_IoU_coef: 0.1639
# Epoch 149/150
# 10/10 [==============================] - 12s 1s/step - loss: -0.2084 - accuracy: 0.9697 - IoU_coef: 0.2086 - val_loss: -0.1626 - val_accuracy: 0.9351 - val_IoU_coef: 0.1626
# Epoch 150/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2082 - accuracy: 0.9705 - IoU_coef: 0.2084 - val_loss: -0.1629 - val_accuracy: 0.9351 - val_IoU_coef: 0.1629

# %%
test_image_list = glob.glob(TEST_IMAGE_PATH + '/*.JPG')
test_image_list.sort()

test_vessel_mask_list = glob.glob(TEST_VESSEL_MASK_PATH + '/*.jpg')
test_vessel_mask_list.sort()

# %%
test_img_number = random.randint(0, len(test_image_list)-1)

test_img = cv2.imread(train_image_list[test_img_number])
test_gt = cv2.imread(train_vessel_mask_list[test_img_number], cv2.IMREAD_GRAYSCALE)

test_img_preprocess = preprocess_img(test_img, PATCH_SIZE)
test_gt = preprocess_mask(test_gt, PATCH_SIZE)

test_patches = patchify(test_img_preprocess, (PATCH_SIZE, PATCH_SIZE), step=PATCH_SIZE)
predicted_patches = []

for i in range(test_patches.shape[0]):
      for j in range(test_patches.shape[1]):
          single_patch = test_patches[i,j,:,:]
          single_patch_norm = (single_patch.astype('float32')) / 255.
          single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
          single_patch_input = np.expand_dims(single_patch_norm, 0)
          single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8) 
          predicted_patches.append(single_patch_prediction)

predicted_patches = np.array(predicted_patches)
predicted_patches_reshaped = np.reshape(predicted_patches, (test_patches.shape[0], test_patches.shape[1], PATCH_SIZE, PATCH_SIZE))
reconstructed_image = unpatchify(predicted_patches_reshaped, test_gt.shape)
reconstructed_image = cv2.resize(reconstructed_image, (PATCH_SIZE, PATCH_SIZE))
test_gt = cv2.resize(test_gt, (PATCH_SIZE, PATCH_SIZE))

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title(test_image_list[test_img_number])
plt.imshow(cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB))
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(test_gt, cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(reconstructed_image, cmap='gray')
# Out:
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
