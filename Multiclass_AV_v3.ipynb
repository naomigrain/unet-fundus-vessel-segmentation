# %% [markdown]
# **VESSEL SEGMENTATION**

# %%
# !pip install patchify

import os
import glob
import cv2
import numpy as np
import skimage.io
from matplotlib import pyplot as plt
from patchify import patchify, unpatchify
from PIL import Image
import tensorflow as tf
import random

np.random.seed(0)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.9/dist-packages (from patchify) (1.22.4)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3

# %%
PATH = '/content/drive/MyDrive/AV_split/'
TRAIN_PATH = PATH+'train_vessel/'
TRAIN_IMAGE_PATH = TRAIN_PATH + 'images/'
TRAIN_VESSEL_MASK_PATH = TRAIN_PATH + 'GT_vessel/'

TEST_PATH = PATH+'test/'
TEST_IMAGE_PATH = TEST_PATH + 'images/'
TEST_VESSEL_MASK_PATH = TEST_PATH + 'GT_vessel/'

PATCH_SIZE = 512
SAVE_MODEL = PATH + 'model/'
SAVE_VESSEL_MODEL_NAME = SAVE_MODEL + 'unet-vessel.h5'
SAVE_PREDICTED_VESSEL = PATH + 'predicted_vessel/'

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def clahe_equalized(image):    
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))    
    image_equalized = clahe.apply(image)

    return image_equalized

def preprocess_image(image, patch_size):
    image = image[70:970, 200:1255]

    image = image[:,:,1]
    image = clahe_equalized(image)

    SIZE_X = (image.shape[1]//patch_size)*patch_size 
    SIZE_Y = (image.shape[0]//patch_size)*patch_size     
    image = cv2.resize(image, (SIZE_X, SIZE_Y))
    
    image = image / 255.
    image = np.array(image)

    return image

# %%
def preprocess_vessel_mask(mask, patch_size):
    thresh = 128
    mask = cv2.threshold(mask, thresh, 255, cv2.THRESH_BINARY)[1]

    mask = mask[70:970, 200:1255]
    
    SIZE_X = (mask.shape[1]//patch_size)*patch_size 
    SIZE_Y = (mask.shape[0]//patch_size)*patch_size     
    mask = cv2.resize(mask, (SIZE_X, SIZE_Y))
  
    mask = 255 - mask
    mask = mask / 255.

    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0

    return mask

# %%
def image_to_patch(image_path, image_type, image_preprocessing, patch_size):
    image_dataset = unpatched_image = []

    if image_type == "IMAGE":
        image = cv2.imread(image_path)
    if image_type == "VESSEL_MASK":
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    image = image_preprocessing(image, patch_size)
    patches_image = patchify(image, (patch_size, patch_size), step=patch_size)
    unpatched_image = unpatchify(patches_image, image.shape)
    
    for i in range(patches_image.shape[0]):
        for j in range(patches_image.shape[1]):
            single_patch = patches_image[i,j,:,:]
            single_patch = (single_patch).astype('float32')
            image_dataset.append(single_patch)

    return image_dataset, unpatched_image

# %%
train_image_list = glob.glob(TRAIN_IMAGE_PATH + '/*.JPG')
train_image_list.sort()

train_vessel_mask_list = glob.glob(TRAIN_VESSEL_MASK_PATH + '/*.jpg')
train_vessel_mask_list.sort()

# %%
image_path = train_image_list[10]

original_image = cv2.imread(image_path)
patched_image_list, unpatched_image = image_to_patch(image_path, "IMAGE", preprocess_image, PATCH_SIZE)
patched_image = np.array(patched_image_list)

print(patched_image.min(), patched_image.max())
print(patched_image.shape)

plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.title(image_path)
plt.imshow(cv2.cvtColor(original_image, cv2.COLOR_BGR2RGB))
plt.subplot(122)
plt.imshow(unpatched_image, cmap='gray')

plt.show()

rows = 1
columns = patched_image.shape[0]

fig = plt.figure(figsize=(5, 5))
for i in range(1, (rows * columns + 1)):
    fig.add_subplot(rows, columns, i)
    img = patched_image[i-1]
    plt.imshow(img,cmap='gray')

plt.show()
# Out:
# 0.007843138 0.9843137
# (2, 512, 512)

# %%
vessel_mask_path = train_vessel_mask_list[10]
original_vessel_mask = cv2.imread(vessel_mask_path, cv2.IMREAD_GRAYSCALE)

patched_mask_list, unpatcified_mask = image_to_patch(vessel_mask_path, "VESSEL_MASK", preprocess_vessel_mask, PATCH_SIZE)
patched_mask = np.array(patched_mask_list)

plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.title(vessel_mask_path)
plt.imshow(cv2.cvtColor(original_vessel_mask, cv2.COLOR_BGR2RGB))
plt.subplot(122)
plt.imshow(unpatcified_mask, cmap='gray')

plt.show()

print(patched_mask.min(), patched_mask.max())
print(patched_mask.shape)
print(np.unique(patched_mask))

rows = 1
columns = patched_image.shape[0]

fig = plt.figure(figsize=(5, 5))
for i in range(1, (rows * columns + 1)):
    fig.add_subplot(rows, columns, i)
    img = patched_mask[i-1]
    plt.imshow(img,cmap='gray')

plt.show()
# Out:
# 0.0 1.0
# (2, 512, 512)
# [0. 1.]

# %%
train_image_dataset = []
train_vessel_mask_dataset = []

for image_path in train_image_list:
    patched_image, unpatched_image = image_to_patch(image_path, "IMAGE", preprocess_image, PATCH_SIZE)
    train_image_dataset += patched_image

for vessel_mask_path in train_vessel_mask_list:
    patched_mask, unpatched_mask = image_to_patch(vessel_mask_path, "VESSEL_MASK", preprocess_vessel_mask, PATCH_SIZE)
    train_vessel_mask_dataset += patched_mask

train_image_dataset = np.array(train_image_dataset)
train_image_dataset = np.expand_dims(train_image_dataset, axis=-1)
train_vessel_mask_dataset = np.array(train_vessel_mask_dataset)
train_vessel_mask_dataset = np.expand_dims(train_vessel_mask_dataset, axis=-1)

print(train_image_dataset.shape)
print(train_vessel_mask_dataset.shape)
print(train_image_dataset.max(), train_vessel_mask_dataset.max())
print(train_image_dataset.min(), train_vessel_mask_dataset.min())
# Out:
# (72, 512, 512, 1)
# (72, 512, 512, 1)
# 1.0 1.0
# 0.003921569 0.0

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train_image_dataset, train_vessel_mask_dataset, test_size=0.3, random_state=0)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (50, 512, 512, 1) (50, 512, 512, 1)
# (22, 512, 512, 1) (22, 512, 512, 1)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K

def IoU_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

def IoU_loss(y_true, y_pred):
    return -IoU_coef(y_true, y_pred)

# %%
import tensorflow as tf
from keras.models import Model, load_model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.optimizers import Adam
from keras.layers import Activation, MaxPool2D, Concatenate

def unet(pretrained_weights = None,input_size = (512,512,1)):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    drop4 = Dropout(0.5)(conv4, training=True)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    conv5 = BatchNormalization()(conv5)
    drop5 = Dropout(0.5)(conv5, training=True)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
   
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)

    model = tf.keras.Model(inputs = inputs, outputs = conv10)

    model.compile(optimizer = Adam(lr = 1e-4), loss = IoU_loss, metrics = ['accuracy', IoU_coef])
    

    if(pretrained_weights):
    	  model=keras.models.load_model(pretrained_weights)

    return model

# %%
model = unet(input_size=(PATCH_SIZE, PATCH_SIZE, 1))
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
history = model.fit(x_train, y_train, 
                    verbose = 1,
                    batch_size = 3,
                    validation_data = (x_test, y_test), 
                    shuffle = False,
                    epochs = 150,
                    steps_per_epoch = 10)
# Out:
# Epoch 1/150
# 10/10 [==============================] - 49s 2s/step - loss: -0.1666 - accuracy: 0.8804 - IoU_coef: 0.1666 - val_loss: -0.0643 - val_accuracy: 0.8815 - val_IoU_coef: 0.0652
# Epoch 2/150
# 10/10 [==============================] - 27s 3s/step - loss: -0.2430 - accuracy: 0.8990 - IoU_coef: 0.2424 - val_loss: -0.0840 - val_accuracy: 0.8890 - val_IoU_coef: 0.0858
# Epoch 3/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.2771 - accuracy: 0.9117 - IoU_coef: 0.2771 - val_loss: -0.0916 - val_accuracy: 0.8871 - val_IoU_coef: 0.0935
# Epoch 4/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.2789 - accuracy: 0.9082 - IoU_coef: 0.2780 - val_loss: -0.0950 - val_accuracy: 0.8863 - val_IoU_coef: 0.0964
# Epoch 5/150
# 10/10 [==============================] - 14s 1s/step - loss: -0.2912 - accuracy: 0.9121 - IoU_coef: 0.2912 - val_loss: -0.0805 - val_accuracy: 0.8927 - val_IoU_coef: 0.0813
# Epoch 6/150
# 10/10 [==============================] - 13s 1s/step - loss: -0.3032 - accuracy: 0.9180 - IoU_coef: 0.3018 - val_loss: -0.0200 - val_accuracy: 0.8904 - val_IoU_coef: 0.0195
# Epoch 7/150
# 10/10 [==============================] - ETA: 0s - loss: -0.2945 - accuracy: 0.9145 - IoU_coef: 0.2937
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-03869772a908> in <module>
# ----> 1 history = model.fit(x_train, y_train,
#       2                     verbose = 1,
#       3                     batch_size = 3,
#       4                     validation_data = (x_test, y_test),
#       5                     shuffle = False,
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1692                             steps_per_execution=self._steps_per_execution,
#    1693                         )
# -> 1694                     val_logs = self.evaluate(
#    1695                         x=val_x,
#    1696                         y=val_y,
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict, **kwargs)
#    2038                         ):
#    2039                             callbacks.on_test_batch_begin(step)
# -> 2040                             tmp_logs = self.test_function(iterator)
#    2041                             if data_handler.should_sync:
#    2042                                 context.async_wait()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     878
#     879       with OptionalXlaContext(self._jit_compile):
# --> 880         result = self._call(*args, **kwds)
#     881
#     882       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     917       # In this case we have not created variables on the first call. So we can
#     918       # run the first trace but we should fail if variables are created.
# --> 919       results = self._variable_creation_fn(*args, **kwds)
#     920       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     921         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     132       (concrete_function,
#     133        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 134     return concrete_function._call_flat(
#     135         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     136
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     376       with _InterpolateFunctionError(self):
#     377         if cancellation_manager is None:
# --> 378           outputs = execute.execute(
#     379               str(self.signature.name),
#     380               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
test_image_list = glob.glob(TEST_IMAGE_PATH + '/*.JPG')
test_image_list.sort()

test_vessel_mask_list = glob.glob(TEST_VESSEL_MASK_PATH + '/*.jpg')
test_vessel_mask_list.sort()

# %%
test_image_list = glob.glob(TEST_IMAGE_PATH + '/*.JPG')
test_image_list.sort()

test_vessel_mask_list = glob.glob(TEST_VESSEL_MASK_PATH + '/*.jpg')
test_vessel_mask_list.sort()

# %%
from datetime import datetime 

test_image_number = random.randint(0, len(test_image_list)-1)

reconstructed_image = []
test_img = cv2.imread(test_image_list[test_image_number])
gt = cv2.imread(test_vessel_mask_list[test_image_number])

predicted_patches = []
start = datetime.now()   

test = preprocess_image(test_img, PATCH_SIZE)
patches = patchify(test, (PATCH_SIZE, PATCH_SIZE), step=PATCH_SIZE) 

for i in range(patches.shape[0]):
      for j in range(patches.shape[1]):
          single_patch = patches[i,j,:,:]
          single_patch_norm = (single_patch.astype('float32')) 
          single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
          single_patch_input = np.expand_dims(single_patch_norm, 0)
          single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8)
          predicted_patches.append(single_patch_prediction)
          
predicted_patches = np.array(predicted_patches)
predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], PATCH_SIZE, PATCH_SIZE))

reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape) 
reconstructed_image = cv2.resize(reconstructed_image, (512, 512))

stop = datetime.now()
print('Execution time: ',(stop-start)) #computation time

plt.figure(figsize=(16, 8))
plt.subplot(231)
plt.title(test_image_list[test_image_number])
plt.imshow(cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB))
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(gt, cmap='gray')
plt.subplot(233)
plt.title('Prediction on test image')
plt.imshow(reconstructed_image, cmap='gray')
plt.show()
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# Execution time:  0:00:00.396116

# %%
if not os.path.exists(SAVE_MODEL):
    os.makedirs(SAVE_MODEL)

model.save(SAVE_VESSEL_MODEL_NAME)

# %% [markdown]
# **PREDICT THE NEXT 20 DATASET**

# %%
PATH = '/content/drive/MyDrive/AV_split/'

TRAIN_PATH = PATH+'train_av/'
TRAIN_IMAGE_PATH = TRAIN_PATH + 'images/'
TRAIN_VESSEL_MASK_PATH = TRAIN_PATH + 'GT_vessel/'
TRAIN_ARTERY_MASK_PATH = TRAIN_PATH + 'GT_artery/'
TRAIN_VEIN_MASK_PATH = TRAIN_PATH + 'GT_vein/'

TEST_PATH = PATH+'test/'
TEST_IMAGE_PATH = TEST_PATH + 'images/'
TEST_VESSEL_MASK_PATH = TEST_PATH + 'GT_vessel/'
TEST_ARTERY_MASK_PATH = TEST_PATH + 'GT_artery/'
TEST_VEIN_MASK_PATH = TEST_PATH + 'GT_vein/'

PATCH_SIZE = 512

VEIN_COLOR = [0, 0, 255]      
ARTERY_COLOR = [255, 0, 0]     
BLACK_BG_COLOR = [0, 0, 0]
VESSEL_COLOR = [255, 255, 255]

SAVE_AV_MODEL_NAME = SAVE_MODEL + 'model/'

# %%
train_av_image_paths = glob.glob(TRAIN_IMAGE_PATH + "/*.JPG")
train_av_image_paths.sort()

train_av_vessel_paths = glob.glob(TRAIN_VESSEL_MASK_PATH + "/*.jpg")
train_av_vessel_paths.sort()

train_av_artery_paths = glob.glob(TRAIN_ARTERY_MASK_PATH + "/*.jpg")
train_av_artery_paths.sort()

train_av_vein_paths = glob.glob(TRAIN_VEIN_MASK_PATH + "/*.jpg")
train_av_vein_paths.sort()

predicted_vessel_dataset = []
gt_vessel_dataset = []

# %%
from keras.models import load_model
from tensorflow.keras.utils import get_custom_objects

get_custom_objects().update({'IoU_loss': IoU_loss})
get_custom_objects().update({'IoU_coef': IoU_coef})

model = load_model(SAVE_VESSEL_MODEL_NAME)

# %%
if not os.path.exists(SAVE_PREDICTED_VESSEL):
    os.makedirs(SAVE_PREDICTED_VESSEL)

# %%
from pathlib import Path    

for image_path, vessel_path in zip(train_av_image_paths, train_av_vessel_paths):
      image_patch_list, _ = image_to_patch(image_path, "IMAGE", preprocess_image, PATCH_SIZE)
      gt_vessel = cv2.imread(vessel_path)
      gt_vessel = preprocess_vessel_mask(gt_vessel, PATCH_SIZE)

      predicted_patches = []

      for patch in image_patch_list:
          patch = np.array(patch)
          patch = patch.astype(np.float32)
          patch = np.expand_dims(np.array(patch), axis=-1)
          single_patch_input = np.expand_dims(patch, 0)
          single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8)
          predicted_patches.append(single_patch_prediction)

      predicted_patches = np.array(predicted_patches)
      predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], PATCH_SIZE, PATCH_SIZE))
      reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape)

      resized_image = cv2.resize(reconstructed_image, (512, 512)) * 255
      save_to_path = SAVE_PREDICTED_VESSEL + Path(image_path).name
      cv2.imwrite(save_to_path, resized_image)

      predicted_vessel_dataset.append(reconstructed_image)
      gt_vessel_dataset.append(gt_vessel)
  
predicted_vessel_dataset = np.array(predicted_vessel_dataset)
# Out:
# 1/1 [==============================] - 0s 335ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 69ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
for i in range(1, 4):
    plt.figure(figsize=(16, 8))
    plt.subplot(121)
    plt.title(train_av_image_paths[i])
    plt.imshow(predicted_vessel_dataset[i], cmap = 'gray')
    plt.subplot(122)
    plt.title('Testing Label')
    plt.imshow(gt_vessel_dataset[i], cmap = 'gray')
    plt.show()

# %% [markdown]
# **TRAIN PREDICTED VESSEL TO ARTERY VEIN**

# %%
def vessel_image_to_patch(image, patch_size):
    image_dataset = unpatched_image = []

    image = (image).astype('uint8')
    rgb_image = cv2.cvtColor(image, cv2.COLOR_GRAY2RGB) * 255

    patches_image = patchify(rgb_image, (patch_size, patch_size, 3), step=patch_size)
    unpatched_image = unpatchify(patches_image, rgb_image.shape)
    
    for i in range(patches_image.shape[0]):
        for j in range(patches_image.shape[1]):
            single_patch = patches_image[i,j,:,:]
            single_patch = (single_patch).astype('float32') / 255.
            image_dataset.append(single_patch[0])

    return image_dataset, unpatched_image

# %%
def preprocess_vessel_mask(mask, patch_size):
    thresh = 128
    mask = cv2.threshold(mask, thresh, 255, cv2.THRESH_BINARY)[1]

    mask = mask[70:970, 200:1255]
    
    SIZE_X = (mask.shape[1]//patch_size)*patch_size 
    SIZE_Y = (mask.shape[0]//patch_size)*patch_size     

    mask = cv2.resize(mask, (SIZE_X, SIZE_Y))
  
    mask = 255 - mask
    mask = mask / 255

    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0

    return mask

def preprocess_vein_mask(image, patch_size):
    mask = preprocess_vessel_mask(image, patch_size)

    mask = (mask).astype('uint8')
    mask = cv2.cvtColor(mask, cv2.COLOR_GRAY2RGB) * 255

    mask[np.all(mask == VESSEL_COLOR, axis=-1)] = VEIN_COLOR

    return (mask).astype('float32')

def preprocess_artery_mask(image, patch_size):
    mask = preprocess_vessel_mask(image, patch_size)

    mask = (mask).astype('uint8')
    mask = cv2.cvtColor(mask, cv2.COLOR_GRAY2RGB) * 255

    mask[np.all(mask == VESSEL_COLOR, axis=-1)] = ARTERY_COLOR

    return (mask).astype('float32')

def merge_and_mask_labeling(vein_mask, artery_mask):
    result = cv2.add(vein_mask, artery_mask)

    mask_label = np.zeros(result.shape, dtype=np.uint8)
    mask_label[np.all(result == ARTERY_COLOR, axis=-1)] = 1
    mask_label[np.all(result == VEIN_COLOR, axis=-1)] = 2                                   

    return result, mask_label[:,:,0]                                            

def mask_to_patch(vein_path, artery_path, patch_size, visualize = False):
    mask_dataset = []

    vein_image = cv2.imread(vein_path, cv2.IMREAD_GRAYSCALE)
    vein_mask = preprocess_vein_mask(vein_image, patch_size)

    artery_image = cv2.imread(artery_path, cv2.IMREAD_GRAYSCALE)
    artery_mask = preprocess_artery_mask(artery_image, patch_size)

    if visualize:
        merged_mask, _ = merge_and_mask_labeling(vein_mask, artery_mask)
    else:
        _, merged_mask = merge_and_mask_labeling(vein_mask, artery_mask)

    patches_mask = patchify(merged_mask, (patch_size, patch_size), step=patch_size)
    unpatched_mask = unpatchify(patches_mask, merged_mask.shape)
    
    for i in range(patches_mask.shape[0]):
        for j in range(patches_mask.shape[1]):
            single_patch = patches_mask[i,j,:,:]
            single_patch = (single_patch).astype('float32')
            mask_dataset.append(single_patch)

    return mask_dataset, unpatched_mask

# %%
train_image_dataset = []
train_mask_dataset = []

for image_path in predicted_vessel_dataset:
    patched_image, predicted_vessel_dataset = vessel_image_to_patch(image_path, PATCH_SIZE)
    train_image_dataset += patched_image

for (vein_mask_path, artery_mask_path) in zip(train_av_vein_paths, train_av_artery_paths):
    patched_mask, unpatched_mask = mask_to_patch(vein_mask_path, artery_mask_path, PATCH_SIZE, visualize = False)
    train_mask_dataset += patched_mask

train_image_dataset = np.array(train_image_dataset)
train_mask_dataset = np.array(train_mask_dataset)

print(train_image_dataset.shape)
print(train_mask_dataset.shape)
print(train_image_dataset.max(), train_mask_dataset.max())
print(train_image_dataset.min(), train_mask_dataset.min())
# Out:
# (40, 512, 512, 3)
# (40, 512, 512)
# 1.0 2.0
# 0.0 0.0

# %%
from tensorflow.keras.utils import to_categorical

n_classes = len(np.unique(train_mask_dataset))
mask_categories = to_categorical(train_mask_dataset, num_classes=n_classes)

print(np.unique(mask_categories))
print(mask_categories.shape)
# Out:
# [0. 1.]
# (40, 512, 512, 3)

# %%
rows = 3
columns = 2

fig = plt.figure(figsize=(5, 5))
for i in range(1, (rows * columns + 1)):
    plt.figure(figsize=(12, 6))

    plt.subplot(121)
    plt.imshow(train_image_dataset[i-1])

    plt.subplot(122)
    plt.imshow(mask_categories[i-1])
    
    plt.show()
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(train_image_dataset, mask_categories, test_size=0.2, random_state=0)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)

print(np.unique(x_train), np.unique(x_test))
print(np.unique(y_train), np.unique(y_test))
# Out:
# (32, 512, 512, 3) (32, 512, 512, 3)
# (8, 512, 512, 3) (8, 512, 512, 3)
# [0. 1.] [0. 1.]
# [0. 1.] [0. 1.]

# %%
IMG_HEIGHT = x_train.shape[1]
IMG_WIDTH  = x_train.shape[2]
IMG_CHANNELS = x_train.shape[3]

print(IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)
# Out:
# 512 512 3

# %%
import tensorflow as tf
from keras.models import Model, load_model
from keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D, concatenate, Conv2DTranspose, BatchNormalization, Dropout, Lambda
from keras.optimizers import Adam
from keras.layers import Activation, MaxPool2D, Concatenate

def dice_coef(y_true, y_pred, smooth = 1):
    intersection = K.sum(y_true * y_pred, axis = [1,2,3])
    union = K.sum(y_true, axis = [1,2,3]) + K.sum(y_pred, axis = [1,2,3])
    return K.mean( (2. * intersection + smooth) / (union + smooth), axis = 0)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def unet_multi(pretrained_weights = None, input_size = (512,512,3), n_class = 3):
    inputs = tf.keras.Input(shape=input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv2D(64, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2,padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv2D(128, 3, activation = 'relu', dilation_rate=2, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    conv4 = BatchNormalization()(conv4)
    drop4 = Dropout(0.5)(conv4, training=True)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    conv5 = BatchNormalization()(conv5)
    drop5 = Dropout(0.5)(conv5, training=True)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)
    

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)
    

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)
    

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
       
    conv10 = Conv2D(n_class, (1,1), activation = 'softmax')(conv9)
    
 
    model = tf.keras.Model(inputs = inputs, outputs = conv10)

    model.compile(optimizer = Adam(lr = 0.0001), loss = ['binary_crossentropy'], metrics = ['accuracy'])    

    if(pretrained_weights):
    	model = keras.models.load_model(pretrained_weights)

    return model

# %%
model = unet_multi(n_class = n_classes)
# Out:
# /usr/local/lib/python3.9/dist-packages/keras/optimizers/optimizer_v2/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
model_checkpoint = tf.keras.callbacks.ModelCheckpoint('unet_DB1_multi.hdf5', monitor = 'loss', verbose = 0)

model = unet_multi(n_class = n_classes)
history = model.fit(x_train, y_train, 
                    batch_size = 3, 
                    verbose = 1, 
                    epochs = 150, 
                    validation_data = (x_test, y_test), 
                    steps_per_epoch = 10,
                    shuffle = False,
                    callbacks = [model_checkpoint])
# Out:
# Epoch 1/150
# 10/10 [==============================] - 17s 1s/step - loss: 0.4067 - accuracy: 0.7403 - val_loss: 0.3119 - val_accuracy: 0.8874
# Epoch 2/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.2002 - accuracy: 0.8855 - val_loss: 0.3857 - val_accuracy: 0.8960
# Epoch 3/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.1839 - accuracy: 0.8951 - val_loss: 0.3503 - val_accuracy: 0.8961
# Epoch 4/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1773 - accuracy: 0.8957 - val_loss: 0.3075 - val_accuracy: 0.8998
# Epoch 5/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1735 - accuracy: 0.8969 - val_loss: 0.2342 - val_accuracy: 0.9048
# Epoch 6/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1749 - accuracy: 0.8950 - val_loss: 0.1855 - val_accuracy: 0.9032
# Epoch 7/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1724 - accuracy: 0.8966 - val_loss: 0.1755 - val_accuracy: 0.8964
# Epoch 8/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.1698 - accuracy: 0.8981 - val_loss: 0.1751 - val_accuracy: 0.8905
# Epoch 9/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1694 - accuracy: 0.8976 - val_loss: 0.1817 - val_accuracy: 0.8878
# Epoch 10/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1670 - accuracy: 0.8996 - val_loss: 0.1897 - val_accuracy: 0.8869
# Epoch 11/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1669 - accuracy: 0.8985 - val_loss: 0.1933 - val_accuracy: 0.8871
# Epoch 12/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1652 - accuracy: 0.8993 - val_loss: 0.1906 - val_accuracy: 0.8881
# Epoch 13/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1653 - accuracy: 0.8995 - val_loss: 0.1974 - val_accuracy: 0.8876
# Epoch 14/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1624 - accuracy: 0.9004 - val_loss: 0.2137 - val_accuracy: 0.8870
# Epoch 15/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1604 - accuracy: 0.9010 - val_loss: 0.2554 - val_accuracy: 0.8861
# Epoch 16/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1593 - accuracy: 0.9014 - val_loss: 0.3739 - val_accuracy: 0.8852
# Epoch 17/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1599 - accuracy: 0.8997 - val_loss: 0.2789 - val_accuracy: 0.8865
# Epoch 18/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1563 - accuracy: 0.9012 - val_loss: 0.2025 - val_accuracy: 0.8938
# Epoch 19/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1527 - accuracy: 0.9025 - val_loss: 0.2475 - val_accuracy: 0.8885
# Epoch 20/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1530 - accuracy: 0.9011 - val_loss: 0.3625 - val_accuracy: 0.8859
# Epoch 21/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1502 - accuracy: 0.9032 - val_loss: 0.3384 - val_accuracy: 0.8865
# Epoch 22/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1519 - accuracy: 0.9034 - val_loss: 0.2574 - val_accuracy: 0.8891
# Epoch 23/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1475 - accuracy: 0.9047 - val_loss: 0.2159 - val_accuracy: 0.8994
# Epoch 24/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1438 - accuracy: 0.9081 - val_loss: 0.2601 - val_accuracy: 0.8982
# Epoch 25/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1385 - accuracy: 0.9105 - val_loss: 0.2368 - val_accuracy: 0.9028
# Epoch 26/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1375 - accuracy: 0.9123 - val_loss: 0.2743 - val_accuracy: 0.9008
# Epoch 27/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1372 - accuracy: 0.9142 - val_loss: 0.2880 - val_accuracy: 0.9002
# Epoch 28/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1370 - accuracy: 0.9150 - val_loss: 0.2782 - val_accuracy: 0.8965
# Epoch 29/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1316 - accuracy: 0.9184 - val_loss: 0.2375 - val_accuracy: 0.9042
# Epoch 30/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1248 - accuracy: 0.9222 - val_loss: 0.2999 - val_accuracy: 0.9035
# Epoch 31/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1235 - accuracy: 0.9228 - val_loss: 0.2437 - val_accuracy: 0.9060
# Epoch 32/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1204 - accuracy: 0.9241 - val_loss: 0.2568 - val_accuracy: 0.9051
# Epoch 33/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1232 - accuracy: 0.9216 - val_loss: 0.2876 - val_accuracy: 0.9048
# Epoch 34/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1223 - accuracy: 0.9229 - val_loss: 0.2212 - val_accuracy: 0.9043
# Epoch 35/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1178 - accuracy: 0.9256 - val_loss: 0.3064 - val_accuracy: 0.9035
# Epoch 36/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.1120 - accuracy: 0.9280 - val_loss: 0.2957 - val_accuracy: 0.9044
# Epoch 37/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1097 - accuracy: 0.9303 - val_loss: 0.2921 - val_accuracy: 0.9039
# Epoch 38/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1088 - accuracy: 0.9302 - val_loss: 0.2782 - val_accuracy: 0.9063
# Epoch 39/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1058 - accuracy: 0.9318 - val_loss: 0.2776 - val_accuracy: 0.9041
# Epoch 40/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.1035 - accuracy: 0.9333 - val_loss: 0.3006 - val_accuracy: 0.9045
# Epoch 41/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0998 - accuracy: 0.9359 - val_loss: 0.2957 - val_accuracy: 0.9027
# Epoch 42/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0980 - accuracy: 0.9369 - val_loss: 0.3303 - val_accuracy: 0.9056
# Epoch 43/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0991 - accuracy: 0.9369 - val_loss: 0.3030 - val_accuracy: 0.9052
# Epoch 44/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0974 - accuracy: 0.9379 - val_loss: 0.3048 - val_accuracy: 0.9039
# Epoch 45/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0976 - accuracy: 0.9369 - val_loss: 0.2584 - val_accuracy: 0.9051
# Epoch 46/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0973 - accuracy: 0.9368 - val_loss: 0.2967 - val_accuracy: 0.9040
# Epoch 47/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0945 - accuracy: 0.9385 - val_loss: 0.2699 - val_accuracy: 0.9062
# Epoch 48/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0915 - accuracy: 0.9406 - val_loss: 0.2750 - val_accuracy: 0.9037
# Epoch 49/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0873 - accuracy: 0.9432 - val_loss: 0.2820 - val_accuracy: 0.9018
# Epoch 50/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0844 - accuracy: 0.9447 - val_loss: 0.3012 - val_accuracy: 0.9029
# Epoch 51/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0810 - accuracy: 0.9467 - val_loss: 0.2790 - val_accuracy: 0.9044
# Epoch 52/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.0778 - accuracy: 0.9487 - val_loss: 0.2714 - val_accuracy: 0.9042
# Epoch 53/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0771 - accuracy: 0.9490 - val_loss: 0.2973 - val_accuracy: 0.9038
# Epoch 54/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0745 - accuracy: 0.9507 - val_loss: 0.2917 - val_accuracy: 0.9026
# Epoch 55/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0731 - accuracy: 0.9518 - val_loss: 0.2828 - val_accuracy: 0.9011
# Epoch 56/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0728 - accuracy: 0.9520 - val_loss: 0.2945 - val_accuracy: 0.9021
# Epoch 57/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0745 - accuracy: 0.9508 - val_loss: 0.3034 - val_accuracy: 0.9027
# Epoch 58/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0720 - accuracy: 0.9525 - val_loss: 0.2822 - val_accuracy: 0.9034
# Epoch 59/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0748 - accuracy: 0.9505 - val_loss: 0.2875 - val_accuracy: 0.9048
# Epoch 60/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0749 - accuracy: 0.9509 - val_loss: 0.3105 - val_accuracy: 0.9030
# Epoch 61/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0762 - accuracy: 0.9498 - val_loss: 0.2608 - val_accuracy: 0.9023
# Epoch 62/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0759 - accuracy: 0.9504 - val_loss: 0.2467 - val_accuracy: 0.9033
# Epoch 63/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0756 - accuracy: 0.9504 - val_loss: 0.2585 - val_accuracy: 0.9006
# Epoch 64/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0769 - accuracy: 0.9492 - val_loss: 0.2881 - val_accuracy: 0.8949
# Epoch 65/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0785 - accuracy: 0.9481 - val_loss: 0.2931 - val_accuracy: 0.8916
# Epoch 66/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0811 - accuracy: 0.9472 - val_loss: 0.2648 - val_accuracy: 0.9009
# Epoch 67/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.0788 - accuracy: 0.9487 - val_loss: 0.2317 - val_accuracy: 0.8993
# Epoch 68/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0804 - accuracy: 0.9475 - val_loss: 0.2457 - val_accuracy: 0.9016
# Epoch 69/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0739 - accuracy: 0.9517 - val_loss: 0.2568 - val_accuracy: 0.9010
# Epoch 70/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0684 - accuracy: 0.9550 - val_loss: 0.2459 - val_accuracy: 0.9028
# Epoch 71/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.0639 - accuracy: 0.9581 - val_loss: 0.2638 - val_accuracy: 0.9044
# Epoch 72/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0616 - accuracy: 0.9594 - val_loss: 0.2700 - val_accuracy: 0.9024
# Epoch 73/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0602 - accuracy: 0.9604 - val_loss: 0.3002 - val_accuracy: 0.8946
# Epoch 74/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.0650 - accuracy: 0.9571 - val_loss: 0.2851 - val_accuracy: 0.8979
# Epoch 75/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0724 - accuracy: 0.9525 - val_loss: 0.2673 - val_accuracy: 0.9031
# Epoch 76/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0783 - accuracy: 0.9483 - val_loss: 0.2454 - val_accuracy: 0.9004
# Epoch 77/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0727 - accuracy: 0.9520 - val_loss: 0.2504 - val_accuracy: 0.9092
# Epoch 78/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0681 - accuracy: 0.9551 - val_loss: 0.2743 - val_accuracy: 0.9030
# Epoch 79/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0621 - accuracy: 0.9592 - val_loss: 0.2975 - val_accuracy: 0.8964
# Epoch 80/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0584 - accuracy: 0.9616 - val_loss: 0.2879 - val_accuracy: 0.9019
# Epoch 81/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0558 - accuracy: 0.9634 - val_loss: 0.2777 - val_accuracy: 0.9050
# Epoch 82/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0535 - accuracy: 0.9648 - val_loss: 0.2873 - val_accuracy: 0.9020
# Epoch 83/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0525 - accuracy: 0.9655 - val_loss: 0.3014 - val_accuracy: 0.9049
# Epoch 84/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0512 - accuracy: 0.9663 - val_loss: 0.3063 - val_accuracy: 0.9038
# Epoch 85/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0537 - accuracy: 0.9647 - val_loss: 0.2971 - val_accuracy: 0.9024
# Epoch 86/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0540 - accuracy: 0.9644 - val_loss: 0.3100 - val_accuracy: 0.9040
# Epoch 87/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0550 - accuracy: 0.9637 - val_loss: 0.2912 - val_accuracy: 0.9056
# Epoch 88/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0514 - accuracy: 0.9661 - val_loss: 0.2800 - val_accuracy: 0.9054
# Epoch 89/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.0504 - accuracy: 0.9668 - val_loss: 0.3029 - val_accuracy: 0.9053
# Epoch 90/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0472 - accuracy: 0.9690 - val_loss: 0.3363 - val_accuracy: 0.9034
# Epoch 91/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0454 - accuracy: 0.9703 - val_loss: 0.3191 - val_accuracy: 0.9041
# Epoch 92/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0465 - accuracy: 0.9694 - val_loss: 0.3161 - val_accuracy: 0.9038
# Epoch 93/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0471 - accuracy: 0.9690 - val_loss: 0.3252 - val_accuracy: 0.9039
# Epoch 94/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0466 - accuracy: 0.9694 - val_loss: 0.3146 - val_accuracy: 0.8998
# Epoch 95/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0469 - accuracy: 0.9692 - val_loss: 0.3085 - val_accuracy: 0.9021
# Epoch 96/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0478 - accuracy: 0.9687 - val_loss: 0.3070 - val_accuracy: 0.9042
# Epoch 97/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0487 - accuracy: 0.9679 - val_loss: 0.3110 - val_accuracy: 0.9046
# Epoch 98/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0478 - accuracy: 0.9685 - val_loss: 0.3222 - val_accuracy: 0.9056
# Epoch 99/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0495 - accuracy: 0.9675 - val_loss: 0.3345 - val_accuracy: 0.9062
# Epoch 100/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.0497 - accuracy: 0.9673 - val_loss: 0.3023 - val_accuracy: 0.8972
# Epoch 101/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0500 - accuracy: 0.9671 - val_loss: 0.2907 - val_accuracy: 0.8990
# Epoch 102/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0527 - accuracy: 0.9652 - val_loss: 0.3089 - val_accuracy: 0.9039
# Epoch 103/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0508 - accuracy: 0.9666 - val_loss: 0.2862 - val_accuracy: 0.9038
# Epoch 104/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0506 - accuracy: 0.9666 - val_loss: 0.2876 - val_accuracy: 0.9008
# Epoch 105/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0482 - accuracy: 0.9685 - val_loss: 0.3430 - val_accuracy: 0.8968
# Epoch 106/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0450 - accuracy: 0.9707 - val_loss: 0.3205 - val_accuracy: 0.9007
# Epoch 107/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0437 - accuracy: 0.9714 - val_loss: 0.3396 - val_accuracy: 0.9079
# Epoch 108/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0435 - accuracy: 0.9715 - val_loss: 0.3236 - val_accuracy: 0.9038
# Epoch 109/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0425 - accuracy: 0.9723 - val_loss: 0.3497 - val_accuracy: 0.9051
# Epoch 110/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0421 - accuracy: 0.9726 - val_loss: 0.3250 - val_accuracy: 0.9039
# Epoch 111/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.0411 - accuracy: 0.9731 - val_loss: 0.3470 - val_accuracy: 0.9018
# Epoch 112/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0406 - accuracy: 0.9734 - val_loss: 0.3344 - val_accuracy: 0.9037
# Epoch 113/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0423 - accuracy: 0.9723 - val_loss: 0.3078 - val_accuracy: 0.9019
# Epoch 114/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0467 - accuracy: 0.9693 - val_loss: 0.3061 - val_accuracy: 0.9016
# Epoch 115/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0494 - accuracy: 0.9675 - val_loss: 0.3062 - val_accuracy: 0.9004
# Epoch 116/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0548 - accuracy: 0.9636 - val_loss: 0.2668 - val_accuracy: 0.9043
# Epoch 117/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0480 - accuracy: 0.9685 - val_loss: 0.3031 - val_accuracy: 0.9025
# Epoch 118/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0454 - accuracy: 0.9704 - val_loss: 0.3368 - val_accuracy: 0.9003
# Epoch 119/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0430 - accuracy: 0.9719 - val_loss: 0.3736 - val_accuracy: 0.9074
# Epoch 120/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0398 - accuracy: 0.9741 - val_loss: 0.3707 - val_accuracy: 0.9065
# Epoch 121/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0387 - accuracy: 0.9747 - val_loss: 0.3519 - val_accuracy: 0.9057
# Epoch 122/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.0391 - accuracy: 0.9744 - val_loss: 0.3466 - val_accuracy: 0.9057
# Epoch 123/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0417 - accuracy: 0.9727 - val_loss: 0.3262 - val_accuracy: 0.8985
# Epoch 124/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.0419 - accuracy: 0.9724 - val_loss: 0.3133 - val_accuracy: 0.9009
# Epoch 125/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0427 - accuracy: 0.9719 - val_loss: 0.3556 - val_accuracy: 0.9004
# Epoch 126/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0425 - accuracy: 0.9722 - val_loss: 0.3160 - val_accuracy: 0.9029
# Epoch 127/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0412 - accuracy: 0.9730 - val_loss: 0.3504 - val_accuracy: 0.8943
# Epoch 128/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0415 - accuracy: 0.9730 - val_loss: 0.3712 - val_accuracy: 0.9029
# Epoch 129/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0398 - accuracy: 0.9741 - val_loss: 0.3987 - val_accuracy: 0.9058
# Epoch 130/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0409 - accuracy: 0.9732 - val_loss: 0.3774 - val_accuracy: 0.9063
# Epoch 131/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0405 - accuracy: 0.9735 - val_loss: 0.3483 - val_accuracy: 0.9069
# Epoch 132/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0436 - accuracy: 0.9714 - val_loss: 0.2921 - val_accuracy: 0.9017
# Epoch 133/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0442 - accuracy: 0.9712 - val_loss: 0.2988 - val_accuracy: 0.8972
# Epoch 134/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0456 - accuracy: 0.9701 - val_loss: 0.2884 - val_accuracy: 0.8971
# Epoch 135/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0463 - accuracy: 0.9698 - val_loss: 0.2937 - val_accuracy: 0.9021
# Epoch 136/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0469 - accuracy: 0.9695 - val_loss: 0.3354 - val_accuracy: 0.9069
# Epoch 137/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0443 - accuracy: 0.9710 - val_loss: 0.3451 - val_accuracy: 0.9068
# Epoch 138/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.0468 - accuracy: 0.9694 - val_loss: 0.3409 - val_accuracy: 0.9082
# Epoch 139/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0435 - accuracy: 0.9718 - val_loss: 0.3091 - val_accuracy: 0.9005
# Epoch 140/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0389 - accuracy: 0.9748 - val_loss: 0.3293 - val_accuracy: 0.9005
# Epoch 141/150
# 10/10 [==============================] - 14s 1s/step - loss: 0.0364 - accuracy: 0.9764 - val_loss: 0.3735 - val_accuracy: 0.9054
# Epoch 142/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0338 - accuracy: 0.9780 - val_loss: 0.3676 - val_accuracy: 0.9035
# Epoch 143/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0339 - accuracy: 0.9779 - val_loss: 0.3664 - val_accuracy: 0.9030
# Epoch 144/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0331 - accuracy: 0.9785 - val_loss: 0.3740 - val_accuracy: 0.9022
# Epoch 145/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0343 - accuracy: 0.9778 - val_loss: 0.3776 - val_accuracy: 0.9061
# Epoch 146/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0327 - accuracy: 0.9787 - val_loss: 0.4013 - val_accuracy: 0.9074
# Epoch 147/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0340 - accuracy: 0.9779 - val_loss: 0.3848 - val_accuracy: 0.9047
# Epoch 148/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0326 - accuracy: 0.9789 - val_loss: 0.3891 - val_accuracy: 0.9026
# Epoch 149/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0345 - accuracy: 0.9775 - val_loss: 0.3797 - val_accuracy: 0.9065
# Epoch 150/150
# 10/10 [==============================] - 13s 1s/step - loss: 0.0337 - accuracy: 0.9781 - val_loss: 0.3748 - val_accuracy: 0.9038

# %%
# IOU
y_pred = model.predict(x_test)
y_pred_argmax = np.argmax(y_pred, axis=3)
y_test_argmax = np.argmax(y_test, axis=3)

# Using built in keras function for IoU
from tensorflow.keras.metrics import MeanIoU

n_classes = len(np.unique(train_mask_dataset))
IOU_keras = MeanIoU(num_classes=n_classes)  
IOU_keras.update_state(y_test_argmax, y_pred_argmax)
print("Mean IoU =", IOU_keras.result().numpy())
# Out:
# 1/1 [==============================] - 12s 12s/step
# Mean IoU = 0.44433105

# %%
import random

test_img_number = random.randint(0, len(x_test))
test_img = x_test[test_img_number]
ground_truth = y_test_argmax[test_img_number]

test_img_input = np.expand_dims(test_img, 0)
prediction = (model.predict(test_img_input))
predicted_img = np.argmax(prediction, axis=3)[0,:,:]

print(predicted_img.shape)
print(np.unique(predicted_img))

plt.figure(figsize=(12, 8))
plt.subplot(231)
plt.title('Testing Image')
plt.imshow(test_img)
plt.subplot(232)
plt.title('Testing Label')
plt.imshow(ground_truth)
plt.subplot(233)
plt.title('Prediction on Test Image')
plt.imshow(predicted_img)
plt.show()
# Out:
# 1/1 [==============================] - 0s 76ms/step
# (512, 512)
# [0 1 2]

# %%
from keras.models import load_model

if not os.path.exists(SAVE_MODEL):
      os.makedirs(SAVE_MODEL)

model.save(SAVE_AV_MODEL_NAME)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 23). These functions will not be directly callable after loading.

# %% [markdown]
# **TESTING FROM RAW IMAGE**

# %%
test_image_list = glob.glob(TEST_IMAGE_PATH + '/*.JPG')
test_image_list.sort()

test_vein_mask_list = glob.glob(TEST_VEIN_MASK_PATH + '/*.jpg')
test_vein_mask_list.sort()

test_artery_mask_list = glob.glob(TEST_ARTERY_MASK_PATH + '/*.jpg')
test_artery_mask_list.sort()

# %%
from datetime import datetime
from tensorflow.keras.utils import get_custom_objects
from keras.models import load_model

test_image_number = random.randint(0, len(test_image_list)-1)
test_image_path = test_image_list[test_image_number]
test_image = cv2.imread(test_image_path)

# load vessel model
get_custom_objects().update({'IoU_loss': IoU_loss})
get_custom_objects().update({'IoU_coef': IoU_coef})
vessel_model = load_model(SAVE_VESSEL_MODEL_NAME)

get_custom_objects().update({'dice_coef': dice_coef})
get_custom_objects().update({'dice_coef_loss': dice_coef_loss})
av_model = load_model(SAVE_AV_MODEL_NAME)

# predict the vessel
predicted_patches = []
start = datetime.now()   

test = preprocess_image(test_image, PATCH_SIZE)
patches = patchify(test, (PATCH_SIZE, PATCH_SIZE), step=PATCH_SIZE) 

for i in range(patches.shape[0]):
      for j in range(patches.shape[1]):
          single_patch = patches[i,j,:,:]
          single_patch_norm = (single_patch.astype('float32')) 
          single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
          single_patch_input = np.expand_dims(single_patch_norm, 0)
          single_patch_prediction = (vessel_model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8)
          predicted_patches.append(single_patch_prediction)
          
predicted_patches = np.array(predicted_patches)
predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], PATCH_SIZE, PATCH_SIZE))

reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape) 

# predict the artery vein
vessel_dataset, unpatched_vessel = vessel_image_to_patch(reconstructed_image, PATCH_SIZE)
predicted_av_list = []

for test_vessel in vessel_dataset:
    test_img_input = np.expand_dims(test_vessel, 0)
    prediction = (av_model.predict(test_img_input))
    predicted_av = np.argmax(prediction, axis=3)[0,:,:]
    predicted_av_list.append(predicted_av)

plt.figure(figsize=(12, 6))
plt.subplot(121)
plt.title('Original image')
plt.imshow(cv2.cvtColor(test_image, cv2.COLOR_BGR2RGB))
plt.subplot(122)
plt.title('Predicted vessel mask')
plt.imshow(reconstructed_image)

plt.show()

rows = 1
columns = 2

fig = plt.figure(figsize=(12, 6))
for i in range(1, (rows * columns + 1)):
    fig.add_subplot(rows, columns, i)
    img = predicted_av_list[i-1]
    plt.imshow(img)

plt.show()
# Out:
# 1/1 [==============================] - 11s 11s/step
# 1/1 [==============================] - 8s 8s/step
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f10db8635e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 11s 11s/step
# 1/1 [==============================] - 11s 11s/step
